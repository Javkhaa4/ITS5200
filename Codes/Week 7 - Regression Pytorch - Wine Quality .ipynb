# %% [markdown]
# ## Libraries

# %%
## !pip install pandas
## !pip install mlxtend

# %%
import numpy as np
import torch
import pandas as pd
## pandas lib could work csv file

import sklearn
import random
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
import matplotlib.pyplot as plt

from mlxtend.plotting import heatmap
from sklearn.model_selection import train_test_split 
from torch.utils.data import TensorDataset, DataLoader

## standard metrics in regression
## coefficeint in determination
from sklearn.metrics import r2_score

# %%
import xgboost as xgb

# %% [markdown]
# ## Parameters

# %%
batch_size = 16
learning_rate = 0.005
N_Epochs = 100

epsilon = 0.0001

# %% [markdown]
# ## Read data

# %%
path_data = 'data/winequality-white.csv'

WINE_raw_data = pd.read_csv (path_data, delimiter = ";")

## WINE_raw_data -d csv file iig duudaj ugj bn.

# %%
WINE_raw_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## headers_list

headers_list = WINE_raw_data.columns.values.tolist ()
##csv file iin header deer bga medeelliig avj list helberluu shiljuulj label hiihdee ashiglahad beldej bna

headers_list
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
headers_list2 = ['density',
 'pH',
 'sulphates',
 'alcohol',
 'quality']

# %% [markdown]
# ## Data Analysis
#
# * Correlation Matrix

# %%
cm = np.corrcoef ( WINE_raw_data[headers_list].values.T  )
hm = heatmap (cm, row_names = headers_list, column_names = headers_list, figsize= (20,10))
## heatmap in doorhi turlii medeelliig haruuldag function.
## if value was 1, those values have positive correlation 
## if value was -1, those values have negative correlation
## if value was 0, there is no correlation between 2 values
## doorhi uzuulsen medeellees quality bolon alcohol 2 iin hoorondin hamaaral hamgiin undur bga gesen medeelel harj boloh n, column quality iin hamgiin undur utga avsan n 0.44 alcohol bn

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Process Data

# %%
## Convert Pandas to Numpy
## CSV filed bsan datag Pandas aar unshij avsan bsanaa Numpy ruu hurvuulj deer n ajillahad beldej bn

WINE_raw_data_np = WINE_raw_data.to_numpy()

# %%
WINE_raw_data_np
# Out:
# array([[ 7.  ,  0.27,  0.36, ...,  0.45,  8.8 ,  6.  ],
#        [ 6.3 ,  0.3 ,  0.34, ...,  0.49,  9.5 ,  6.  ],
#        [ 8.1 ,  0.28,  0.4 , ...,  0.44, 10.1 ,  6.  ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  0.46,  9.4 ,  6.  ],
#        [ 5.5 ,  0.29,  0.3 , ...,  0.38, 12.8 ,  7.  ],
#        [ 6.  ,  0.21,  0.38, ...,  0.32, 11.8 ,  6.  ]])

# %%
WINE_raw_data_np.shape
# Out:
# (4898, 12)

# %%
## indexing data

X = WINE_raw_data_np [:, :-1]
## , buh row iig avna. columns aas suuliin negiig songoj avna (slicing)

y = WINE_raw_data_np [:,11:12]

# %%
print (X.shape)
print (y.shape)
# Out:
# (4898, 11)
# (4898, 1)

# %%
random_seed = int (random.random() *100) ## 42

# %%
## split X and y

## ????????

X_train, X_test, y_train, y_test = train_test_split (X, y, test_size = 0.2, random_state = random_seed)

# %%
print (X_train.shape)
print (X_test.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# (3918, 11)
# (980, 11)
# (3918, 1)
# (980, 1)

# %% [markdown]
# ## Fix in case float64 error

# %%
y_test.dtype ## sometimes torch gives you problem because of data had different data type
# Out:
# dtype('float64')

# %%
## fix data type

X_train = X_train.astype (np.float32)
X_test = X_test.astype (np.float32)
y_train = y_train.astype (np.float32)
y_test = y_test.astype (np.float32)

# %%
X_train.dtype
X_test.dtype
y_train.dtype
y_test.dtype
# Out:
# dtype('float32')

# %%
## convert data to torch from Numpy

X_train_tr = torch.from_numpy (X_train)
X_test_tr  = torch.from_numpy (X_test)
y_train_tr = torch.from_numpy (y_train)
y_test_tr  = torch.from_numpy (y_test)

# %% [markdown]
# ## Normalization
#
# * Normalization
# * Standardization (*)

# %%
## X_scaled = (X - x_means)/X_standard_dev

x_means      = X_train_tr.mean (0, keepdim = True )
x_deviations = X_train_tr.std (0, keepdim = True ) + epsilon

# %%
x_means
# Out:
# tensor([[6.8566e+00, 2.7671e-01, 3.3420e-01, 6.3712e+00, 4.5989e-02, 3.5417e+01,
#          1.3811e+02, 9.9402e-01, 3.1890e+00, 4.8992e-01, 1.0511e+01]])

# %%
x_deviations
# Out:
# tensor([[8.5174e-01, 9.9408e-02, 1.2052e-01, 5.0040e+00, 2.2860e-02, 1.7124e+01,
#          4.2675e+01, 3.0325e-03, 1.5108e-01, 1.1463e-01, 1.2281e+00]])

# %% [markdown]
# ## Create the DataLoader

# %%
train_ds = TensorDataset ( X_train_tr, y_train_tr )

# %%
train_dl = DataLoader (train_ds, batch_size , shuffle=True )

## surgah ugugdluu shuffle hiij holij surgahdaa dahin ashiglana.

# %%
train_dl

# %% [markdown]
# ## Neural Network Architectures

# %%
## Linear Regression

class LinRegNet (nn.Module):
    ## nn class is neural network class
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()
        
        self.x_means      = x_means       ##
        self.x_deviations = x_deviations
        
        self.linear1 = nn.Linear (11,1)
        ## 11,1 those values depend on data.
        
    ## perform inference
    def forward (self, x):
        
        x = (x - self.x_means)/ self.x_deviations
        
        y_pred = self.linear1(x)
        
        ## return torch.round (y_pred)
        return y_pred

# %% [markdown]
# ## Training Loop

# %%
def training_loop (N_Epochs, model, loss_fn, opt):
    
    for epoch in range (N_Epochs):
        for xb, yb in train_dl:
            
            y_pred = model (xb)
            loss = loss_fn (y_pred, yb)
            
            opt.zero_grad ()
            loss.backward ()
            opt.step ()
        if epoch % 20 == 0:
            print (epoch, "loss=", loss)

# %%
## model = LinRegNet ( x_means, x_deviations )
model = LinRegNet ( x_means, x_deviations )

opt = torch.optim.Adam ( model.parameters(), lr =learning_rate )
## optimazation - gradient descent

loss_fn = F.mse_loss 
## belen loss function iig duudaj bn. MSE

training_loop (N_Epochs, model, loss_fn, opt)
# Out:
# 0 loss= tensor(25.1693, grad_fn=<MseLossBackward0>)
# 20 loss= tensor(0.2891, grad_fn=<MseLossBackward0>)
# 40 loss= tensor(0.4109, grad_fn=<MseLossBackward0>)
# 60 loss= tensor(0.4408, grad_fn=<MseLossBackward0>)
# 80 loss= tensor(0.4860, grad_fn=<MseLossBackward0>)

# %% [markdown]
# ## Evaluate Model

# %%
y_pred_test = model ( X_test_tr )

# %%
y_pred_test.shape
# Out:
# torch.Size([980, 1])

# %%
## r2_score is predicted x

## y_pred_test

# %%
print ( "Testing R**2: ", r2_score ( y_test_tr.numpy(), y_pred_test.detach().numpy() ) )

## range 0 - 1, best is 1
# Out:
# Testing R**2:  0.2565579905759914

# %%
y_pred_test.shape
# Out:
# torch.Size([980, 1])

# %%
y_test_tr.shape
# Out:
# torch.Size([980, 1])

# %%
len(X_test_tr)
# Out:
# 980

# %%
list_preds = []
list_reals = []

for i in range (len(X_test_tr)):
    print ("******************")
    print ("pred, real")
    np_real =   y_test_tr[i].detach().numpy()
    np_pred = y_pred_test[i].detach().numpy()
    print (np_pred[0],",", np_real[0])
    list_preds.append (  np_pred[0] )
    list_reals.append (  np_real[0] )
# Out:
# ******************
# pred, real
# 6.4308257 , 6.0
# ******************
# pred, real
# 6.2730827 , 6.0
# ******************
# pred, real
# 6.54881 , 6.0
# ******************
# pred, real
# 5.2805815 , 5.0
# ******************
# pred, real
# 5.978732 , 6.0
# ******************
# pred, real
# 5.5763903 , 6.0
# ******************
# pred, real
# 5.738648 , 5.0
# ******************
# pred, real
# 6.131055 , 7.0
# ******************
# pred, real
# 5.2179956 , 6.0
# ******************
# pred, real
# 6.707179 , 8.0
# ******************
# pred, real
# 5.891451 , 6.0
# ******************
# pred, real
# 5.8658137 , 5.0
# ******************
# pred, real
# 5.4663486 , 5.0
# ******************
# pred, real
# 6.256951 , 7.0
# ******************
# pred, real
# 5.549924 , 6.0
# ******************
# pred, real
# 5.2119746 , 5.0
# ******************
# pred, real
# 6.203864 , 7.0
# ******************
# pred, real
# 5.6412234 , 6.0
# ******************
# pred, real
# 6.478699 , 6.0
# ******************
# pred, real
# 5.113166 , 4.0
# ******************
# pred, real
# 5.903047 , 5.0
# ******************
# pred, real
# 5.7424884 , 7.0
# ******************
# pred, real
# 5.817322 , 6.0
# ******************
# pred, real
# 5.984399 , 5.0
# ******************
# pred, real
# 6.3279996 , 7.0
# ******************
# pred, real
# 5.8763285 , 5.0
# ******************
# pred, real
# 5.5792866 , 5.0
# ******************
# pred, real
# 6.093519 , 5.0
# ******************
# pred, real
# 5.687043 , 8.0
# ******************
# pred, real
# 5.787635 , 6.0
# ******************
# pred, real
# 5.989173 , 6.0
# ******************
# pred, real
# 6.1383877 , 7.0
# ******************
# pred, real
# 6.1922245 , 8.0
# ******************
# pred, real
# 5.863937 , 4.0
# ******************
# pred, real
# 5.026505 , 5.0
# ******************
# pred, real
# 4.909686 , 4.0
# ******************
# pred, real
# 6.006524 , 5.0
# ******************
# pred, real
# 6.0923376 , 6.0
# ******************
# pred, real
# 5.576889 , 4.0
# ******************
# pred, real
# 5.896819 , 6.0
# ******************
# pred, real
# 5.9677825 , 6.0
# ******************
# pred, real
# 5.429813 , 5.0
# ******************
# pred, real
# 6.3925023 , 6.0
# ******************
# pred, real
# 5.3902082 , 4.0
# ******************
# pred, real
# 5.8121266 , 6.0
# ******************
# pred, real
# 5.85628 , 6.0
# ******************
# pred, real
# 6.086177 , 6.0
# ******************
# pred, real
# 6.076004 , 7.0
# ******************
# pred, real
# 6.3150253 , 7.0
# ******************
# pred, real
# 6.293464 , 6.0
# ******************
# pred, real
# 5.4356394 , 5.0
# ******************
# pred, real
# 5.8319426 , 6.0
# ******************
# pred, real
# 5.9488087 , 7.0
# ******************
# pred, real
# 5.549647 , 5.0
# ******************
# pred, real
# 5.7447762 , 5.0
# ******************
# pred, real
# 5.5256696 , 6.0
# ******************
# pred, real
# 6.150148 , 7.0
# ******************
# pred, real
# 5.1202536 , 5.0
# ******************
# pred, real
# 5.6519823 , 6.0
# ******************
# pred, real
# 6.262832 , 4.0
# ******************
# pred, real
# 6.399802 , 7.0
# ******************
# pred, real
# 5.8023653 , 5.0
# ******************
# pred, real
# 6.27755 , 8.0
# ******************
# pred, real
# 6.601022 , 7.0
# ******************
# pred, real
# 5.579189 , 5.0
# ******************
# pred, real
# 6.5045996 , 6.0
# ******************
# pred, real
# 5.95235 , 6.0
# ******************
# pred, real
# 6.303732 , 5.0
# ******************
# pred, real
# 5.03882 , 5.0
# ******************
# pred, real
# 5.5218363 , 6.0
# ******************
# pred, real
# 5.696238 , 6.0
# ******************
# pred, real
# 5.540414 , 6.0
# ******************
# pred, real
# 6.020801 , 6.0
# ******************
# pred, real
# 5.14493 , 6.0
# ******************
# pred, real
# 5.6532993 , 6.0
# ******************
# pred, real
# 5.68069 , 7.0
# ******************
# pred, real
# 5.728984 , 6.0
# ******************
# pred, real
# 5.798764 , 5.0
# ******************
# pred, real
# 5.5331593 , 6.0
# ******************
# pred, real
# 5.9664416 , 6.0
# ******************
# pred, real
# 5.857712 , 7.0
# ******************
# pred, real
# 5.2633 , 6.0
# ******************
# pred, real
# 6.2668986 , 7.0
# ******************
# pred, real
# 5.903047 , 5.0
# ******************
# pred, real
# 6.3042536 , 6.0
# ******************
# pred, real
# 5.7103634 , 5.0
# ******************
# pred, real
# 6.1236773 , 5.0
# ******************
# pred, real
# 5.992484 , 6.0
# ******************
# pred, real
# 5.5873294 , 8.0
# ******************
# pred, real
# 5.6119905 , 5.0
# ******************
# pred, real
# 5.3714137 , 6.0
# ******************
# pred, real
# 6.80403 , 8.0
# ******************
# pred, real
# 5.2563295 , 5.0
# ******************
# pred, real
# 5.6415043 , 6.0
# ******************
# pred, real
# 5.774717 , 4.0
# ******************
# pred, real
# 5.411998 , 3.0
# ******************
# pred, real
# 6.0324807 , 5.0
# ******************
# pred, real
# 5.94272 , 7.0
# ******************
# pred, real
# 5.5726895 , 5.0
# ******************
# pred, real
# 6.107264 , 6.0
# ******************
# pred, real
# 5.7148504 , 5.0
# ******************
# pred, real
# 5.519804 , 7.0
# ******************
# pred, real
# 6.5727673 , 7.0
# ******************
# pred, real
# 6.346822 , 6.0
# ******************
# pred, real
# 6.594861 , 6.0
# ******************
# pred, real
# 6.034011 , 6.0
# ******************
# pred, real
# 5.734144 , 6.0
# ******************
# pred, real
# 5.640444 , 6.0
# ******************
# pred, real
# 6.439807 , 6.0
# ******************
# pred, real
# 6.480673 , 6.0
# ******************
# pred, real
# 5.285395 , 5.0
# ******************
# pred, real
# 6.356376 , 6.0
# ******************
# pred, real
# 6.134931 , 6.0
# ******************
# pred, real
# 5.74507 , 6.0
# ******************
# pred, real
# 6.0200047 , 6.0
# ******************
# pred, real
# 5.997633 , 6.0
# ******************
# pred, real
# 6.385874 , 7.0
# ******************
# pred, real
# 6.3546352 , 8.0
# ******************
# pred, real
# 5.437483 , 6.0
# ******************
# pred, real
# 5.4544663 , 4.0
# ******************
# pred, real
# 5.9026217 , 6.0
# ******************
# pred, real
# 6.4761624 , 7.0
# ******************
# pred, real
# 5.1312046 , 6.0
# ******************
# pred, real
# 6.62462 , 7.0
# ******************
# pred, real
# 6.712987 , 6.0
# ******************
# pred, real
# 6.6570306 , 6.0
# ******************
# pred, real
# 6.5578003 , 7.0
# ******************
# pred, real
# 6.290965 , 7.0
# ******************
# pred, real
# 5.5828185 , 6.0
# ******************
# pred, real
# 5.3641057 , 5.0
# ******************
# pred, real
# 6.2529044 , 8.0
# ******************
# pred, real
# 6.020247 , 6.0
# ******************
# pred, real
# 5.7979608 , 6.0
# ******************
# pred, real
# 6.169569 , 5.0
# ******************
# pred, real
# 5.6842403 , 7.0
# ******************
# pred, real
# 6.1845794 , 7.0
# ******************
# pred, real
# 5.7659593 , 6.0
# ******************
# pred, real
# 5.7791953 , 6.0
# ******************
# pred, real
# 6.3599844 , 6.0
# ******************
# pred, real
# 5.731096 , 4.0
# ******************
# pred, real
# 6.5658016 , 7.0
# ******************
# pred, real
# 5.660137 , 5.0
# ******************
# pred, real
# 6.4068046 , 6.0
# ******************
# pred, real
# 5.7729897 , 5.0
# ******************
# pred, real
# 5.022731 , 5.0
# ******************
# pred, real
# 5.9087334 , 6.0
# ******************
# pred, real
# 6.468104 , 6.0
# ******************
# pred, real
# 5.784675 , 5.0
# ******************
# pred, real
# 5.2550716 , 6.0
# ******************
# pred, real
# 6.340527 , 7.0
# ******************
# pred, real
# 6.6624207 , 7.0
# ******************
# pred, real
# 5.9598584 , 7.0
# ******************
# pred, real
# 5.9116898 , 6.0
# ******************
# pred, real
# 6.1973763 , 5.0
# ******************
# pred, real
# 5.9250536 , 6.0
# ******************
# pred, real
# 5.8586164 , 7.0
# ******************
# pred, real
# 5.465249 , 5.0
# ******************
# pred, real
# 5.3758435 , 6.0
# ******************
# pred, real
# 6.384087 , 6.0
# ******************
# pred, real
# 5.922044 , 7.0
# ******************
# pred, real
# 5.496748 , 6.0
# ******************
# pred, real
# 5.9092007 , 5.0
# ******************
# pred, real
# 5.2826443 , 5.0
# ******************
# pred, real
# 5.4177556 , 5.0
# ******************
# pred, real
# 6.0337343 , 6.0
# ******************
# pred, real
# 6.059856 , 8.0
# ******************
# pred, real
# 6.058602 , 6.0
# ******************
# pred, real
# 5.8654 , 6.0
# ******************
# pred, real
# 6.243738 , 8.0
# ******************
# pred, real
# 6.4835005 , 7.0
# ******************
# pred, real
# 4.5911746 , 5.0
# ******************
# pred, real
# 4.649984 , 4.0
# ******************
# pred, real
# 4.9483523 , 6.0
# ******************
# pred, real
# 6.536617 , 6.0
# ******************
# pred, real
# 6.5789404 , 7.0
# ******************
# pred, real
# 6.021632 , 5.0
# ******************
# pred, real
# 5.806327 , 6.0
# ******************
# pred, real
# 5.052704 , 4.0
# ******************
# pred, real
# 5.8559694 , 7.0
# ******************
# pred, real
# 5.6100254 , 7.0
# ******************
# pred, real
# 6.968647 , 7.0
# ******************
# pred, real
# 5.5444508 , 6.0
# ******************
# pred, real
# 5.973635 , 7.0
# ******************
# pred, real
# 6.4842606 , 6.0
# ******************
# pred, real
# 6.3925223 , 6.0
# ******************
# pred, real
# 5.470654 , 5.0
# ******************
# pred, real
# 5.0275254 , 5.0
# ******************
# pred, real
# 5.0655193 , 5.0
# ******************
# pred, real
# 5.876471 , 6.0
# ******************
# pred, real
# 5.9868584 , 6.0
# ******************
# pred, real
# 6.327858 , 7.0
# ******************
# pred, real
# 5.8438473 , 7.0
# ******************
# pred, real
# 6.329696 , 6.0
# ******************
# pred, real
# 5.953999 , 6.0
# ******************
# pred, real
# 6.0546775 , 6.0
# ******************
# pred, real
# 5.672189 , 6.0
# ******************
# pred, real
# 5.941234 , 5.0
# ******************
# pred, real
# 5.862778 , 6.0
# ******************
# pred, real
# 6.259199 , 7.0
# ******************
# pred, real
# 5.635041 , 7.0
# ******************
# pred, real
# 5.791345 , 5.0
# ******************
# pred, real
# 6.375471 , 6.0
# ******************
# pred, real
# 6.6845603 , 6.0
# ******************
# pred, real
# 6.177493 , 7.0
# ******************
# pred, real
# 6.451981 , 5.0
# ******************
# pred, real
# 6.1529756 , 6.0
# ******************
# pred, real
# 5.978879 , 6.0
# ******************
# pred, real
# 5.456125 , 5.0
# ******************
# pred, real
# 5.6284833 , 7.0
# ******************
# pred, real
# 5.2864165 , 5.0
# ******************
# pred, real
# 5.9576344 , 5.0
# ******************
# pred, real
# 6.1110663 , 6.0
# ******************
# pred, real
# 5.4705887 , 5.0
# ******************
# pred, real
# 6.7296834 , 6.0
# ******************
# pred, real
# 6.560493 , 5.0
# ******************
# pred, real
# 5.4172215 , 5.0
# ******************
# pred, real
# 6.54922 , 8.0
# ******************
# pred, real
# 5.996934 , 6.0
# ******************
# pred, real
# 5.4462605 , 5.0
# ******************
# pred, real
# 5.3759933 , 5.0
# ******************
# pred, real
# 4.929482 , 6.0
# ******************
# pred, real
# 4.948726 , 5.0
# ******************
# pred, real
# 6.4904175 , 7.0
# ******************
# pred, real
# 5.5931835 , 5.0
# ******************
# pred, real
# 7.0400333 , 7.0
# ******************
# pred, real
# 6.344451 , 6.0
# ******************
# pred, real
# 5.435234 , 5.0
# ******************
# pred, real
# 5.8023653 , 5.0
# ******************
# pred, real
# 5.930364 , 6.0
# ******************
# pred, real
# 5.893814 , 6.0
# ******************
# pred, real
# 5.383883 , 5.0
# ******************
# pred, real
# 5.668067 , 5.0
# ******************
# pred, real
# 5.4610023 , 6.0
# ******************
# pred, real
# 5.395169 , 5.0
# ******************
# pred, real
# 5.392964 , 5.0
# ******************
# pred, real
# 5.620856 , 7.0
# ******************
# pred, real
# 6.473183 , 6.0
# ******************
# pred, real
# 5.7659593 , 6.0
# ******************
# pred, real
# 5.359806 , 5.0
# ******************
# pred, real
# 6.401837 , 6.0
# ******************
# pred, real
# 5.659922 , 5.0
# ******************
# pred, real
# 5.4932494 , 5.0
# ******************
# pred, real
# 5.6587768 , 6.0
# ******************
# pred, real
# 6.064483 , 6.0
# ******************
# pred, real
# 5.777303 , 5.0
# ******************
# pred, real
# 6.792637 , 7.0
# ******************
# pred, real
# 5.661435 , 6.0
# ******************
# pred, real
# 5.5826645 , 5.0
# ******************
# pred, real
# 6.570487 , 6.0
# ******************
# pred, real
# 5.5160203 , 6.0
# ******************
# pred, real
# 5.6153574 , 5.0
# ******************
# pred, real
# 5.3664527 , 5.0
# ******************
# pred, real
# 5.6432548 , 6.0
# ******************
# pred, real
# 5.709901 , 5.0
# ******************
# pred, real
# 6.0716867 , 7.0
# ******************
# pred, real
# 5.533693 , 7.0
# ******************
# pred, real
# 5.625358 , 4.0
# ******************
# pred, real
# 5.858842 , 5.0
# ******************
# pred, real
# 6.767043 , 7.0
# ******************
# pred, real
# 6.258581 , 7.0
# ******************
# pred, real
# 5.886851 , 6.0
# ******************
# pred, real
# 6.361969 , 6.0
# ******************
# pred, real
# 5.597204 , 5.0
# ******************
# pred, real
# 6.3379407 , 8.0
# ******************
# pred, real
# 5.7627187 , 8.0
# ******************
# pred, real
# 5.775274 , 6.0
# ******************
# pred, real
# 5.8822346 , 5.0
# ******************
# pred, real
# 5.4964023 , 5.0
# ******************
# pred, real
# 5.8014493 , 7.0
# ******************
# pred, real
# 5.776612 , 6.0
# ******************
# pred, real
# 5.686905 , 4.0
# ******************
# pred, real
# 6.201206 , 6.0
# ******************
# pred, real
# 6.1434135 , 8.0
# ******************
# pred, real
# 5.6842403 , 7.0
# ******************
# pred, real
# 5.768279 , 5.0
# ******************
# pred, real
# 5.7476115 , 5.0
# ******************
# pred, real
# 6.4168167 , 6.0
# ******************
# pred, real
# 6.601088 , 7.0
# ******************
# pred, real
# 5.9711895 , 7.0
# ******************
# pred, real
# 6.270144 , 6.0
# ******************
# pred, real
# 5.247277 , 5.0
# ******************
# pred, real
# 5.476774 , 6.0
# ******************
# pred, real
# 5.803631 , 6.0
# ******************
# pred, real
# 6.3380733 , 6.0
# ******************
# pred, real
# 5.134851 , 5.0
# ******************
# pred, real
# 5.510629 , 5.0
# ******************
# pred, real
# 5.6600375 , 6.0
# ******************
# pred, real
# 6.4172163 , 7.0
# ******************
# pred, real
# 6.314743 , 8.0
# ******************
# pred, real
# 5.866164 , 5.0
# ******************
# pred, real
# 6.387777 , 5.0
# ******************
# pred, real
# 6.453526 , 6.0
# ******************
# pred, real
# 5.6111193 , 6.0
# ******************
# pred, real
# 6.4409847 , 7.0
# ******************
# pred, real
# 6.1582046 , 6.0
# ******************
# pred, real
# 6.191729 , 6.0
# ******************
# pred, real
# 4.951103 , 5.0
# ******************
# pred, real
# 6.1395326 , 8.0
# ******************
# pred, real
# 5.4958906 , 5.0
# ******************
# pred, real
# 5.7878046 , 6.0
# ******************
# pred, real
# 6.013132 , 6.0
# ******************
# pred, real
# 4.487925 , 5.0
# ******************
# pred, real
# 5.4632645 , 5.0
# ******************
# pred, real
# 6.329883 , 6.0
# ******************
# pred, real
# 5.3183928 , 5.0
# ******************
# pred, real
# 5.50992 , 5.0
# ******************
# pred, real
# 5.50693 , 6.0
# ******************
# pred, real
# 5.7670665 , 6.0
# ******************
# pred, real
# 6.1490383 , 6.0
# ******************
# pred, real
# 5.6380296 , 6.0
# ******************
# pred, real
# 5.4139905 , 5.0
# ******************
# pred, real
# 5.0355563 , 5.0
# ******************
# pred, real
# 4.813509 , 6.0
# ******************
# pred, real
# 6.309176 , 8.0
# ******************
# pred, real
# 5.6424804 , 5.0
# ******************
# pred, real
# 5.7896767 , 6.0
# ******************
# pred, real
# 6.136458 , 6.0
# ******************
# pred, real
# 6.067897 , 6.0
# ******************
# pred, real
# 5.9732065 , 5.0
# ******************
# pred, real
# 5.4210234 , 4.0
# ******************
# pred, real
# 6.431985 , 8.0
# ******************
# pred, real
# 4.2725315 , 5.0
# ******************
# pred, real
# 5.713386 , 6.0
# ******************
# pred, real
# 4.9748273 , 4.0
# ******************
# pred, real
# 5.2734113 , 5.0
# ******************
# pred, real
# 5.964216 , 8.0
# ******************
# pred, real
# 5.5472016 , 5.0
# ******************
# pred, real
# 6.429923 , 6.0
# ******************
# pred, real
# 5.6095533 , 6.0
# ******************
# pred, real
# 5.7861648 , 6.0
# ******************
# pred, real
# 6.115595 , 7.0
# ******************
# pred, real
# 5.596786 , 5.0
# ******************
# pred, real
# 5.720868 , 5.0
# ******************
# pred, real
# 5.833821 , 6.0
# ******************
# pred, real
# 5.6018972 , 5.0
# ******************
# pred, real
# 6.6706486 , 7.0
# ******************
# pred, real
# 5.6841745 , 5.0
# ******************
# pred, real
# 6.2899 , 7.0
# ******************
# pred, real
# 5.886115 , 5.0
# ******************
# pred, real
# 6.2551613 , 7.0
# ******************
# pred, real
# 5.858273 , 5.0
# ******************
# pred, real
# 5.808534 , 6.0
# ******************
# pred, real
# 5.983748 , 5.0
# ******************
# pred, real
# 6.5532746 , 6.0
# ******************
# pred, real
# 6.0808163 , 6.0
# ******************
# pred, real
# 5.054147 , 5.0
# ******************
# pred, real
# 6.3163657 , 6.0
# ******************
# pred, real
# 6.169039 , 8.0
# ******************
# pred, real
# 5.8493977 , 7.0
# ******************
# pred, real
# 5.734158 , 6.0
# ******************
# pred, real
# 5.74711 , 7.0
# ******************
# pred, real
# 6.144499 , 6.0
# ******************
# pred, real
# 5.6695065 , 6.0
# ******************
# pred, real
# 5.6464195 , 5.0
# ******************
# pred, real
# 6.2463226 , 6.0
# ******************
# pred, real
# 5.602692 , 7.0
# ******************
# pred, real
# 5.8899007 , 6.0
# ******************
# pred, real
# 4.476534 , 5.0
# ******************
# pred, real
# 6.3258905 , 7.0
# ******************
# pred, real
# 4.7474775 , 4.0
# ******************
# pred, real
# 6.260119 , 6.0
# ******************
# pred, real
# 6.0260925 , 7.0
# ******************
# pred, real
# 5.1541057 , 5.0
# ******************
# pred, real
# 5.879697 , 6.0
# ******************
# pred, real
# 5.5717173 , 6.0
# ******************
# pred, real
# 5.440192 , 5.0
# ******************
# pred, real
# 5.8762307 , 5.0
# ******************
# pred, real
# 6.4087396 , 6.0
# ******************
# pred, real
# 5.446732 , 5.0
# ******************
# pred, real
# 4.784478 , 4.0
# ******************
# pred, real
# 5.5873294 , 8.0
# ******************
# pred, real
# 5.854188 , 6.0
# ******************
# pred, real
# 6.5516067 , 6.0
# ******************
# pred, real
# 5.6428356 , 5.0
# ******************
# pred, real
# 5.4202566 , 6.0
# ******************
# pred, real
# 4.876887 , 5.0
# ******************
# pred, real
# 6.327161 , 6.0
# ******************
# pred, real
# 5.419686 , 5.0
# ******************
# pred, real
# 6.6245174 , 9.0
# ******************
# pred, real
# 5.6082582 , 5.0
# ******************
# pred, real
# 5.7001834 , 6.0
# ******************
# pred, real
# 6.3577566 , 5.0
# ******************
# pred, real
# 5.7843633 , 7.0
# ******************
# pred, real
# 5.63113 , 5.0
# ******************
# pred, real
# 6.1258407 , 6.0
# ******************
# pred, real
# 5.4544134 , 6.0
# ******************
# pred, real
# 5.7032003 , 6.0
# ******************
# pred, real
# 6.122194 , 8.0
# ******************
# pred, real
# 2.2183201 , 6.0
# ******************
# pred, real
# 6.618091 , 6.0
# ******************
# pred, real
# 6.629555 , 6.0
# ******************
# pred, real
# 5.834484 , 8.0
# ******************
# pred, real
# 5.8586793 , 5.0
# ******************
# pred, real
# 5.272611 , 5.0
# ******************
# pred, real
# 6.1551623 , 6.0
# ******************
# pred, real
# 6.303732 , 5.0
# ******************
# pred, real
# 6.3158927 , 8.0
# ******************
# pred, real
# 6.2496343 , 6.0
# ******************
# pred, real
# 6.387712 , 6.0
# ******************
# pred, real
# 6.090291 , 6.0
# ******************
# pred, real
# 6.0920563 , 6.0
# ******************
# pred, real
# 4.599388 , 5.0
# ******************
# pred, real
# 6.843607 , 7.0
# ******************
# pred, real
# 5.844642 , 6.0
# ******************
# pred, real
# 6.121781 , 7.0
# ******************
# pred, real
# 5.2716436 , 5.0
# ******************
# pred, real
# 6.0343313 , 8.0
# ******************
# pred, real
# 5.02425 , 3.0
# ******************
# pred, real
# 6.121755 , 6.0
# ******************
# pred, real
# 5.743377 , 5.0
# ******************
# pred, real
# 5.347728 , 6.0
# ******************
# pred, real
# 6.0058765 , 6.0
# ******************
# pred, real
# 5.250832 , 6.0
# ******************
# pred, real
# 6.375299 , 6.0
# ******************
# pred, real
# 5.411604 , 6.0
# ******************
# pred, real
# 5.54273 , 5.0
# ******************
# pred, real
# 5.8366375 , 6.0
# ******************
# pred, real
# 6.045419 , 6.0
# ******************
# pred, real
# 6.1216908 , 5.0
# ******************
# pred, real
# 6.3494487 , 8.0
# ******************
# pred, real
# 6.2682853 , 6.0
# ******************
# pred, real
# 5.8011265 , 6.0
# ******************
# pred, real
# 5.489514 , 5.0
# ******************
# pred, real
# 5.92441 , 6.0
# ******************
# pred, real
# 6.4404287 , 6.0
# ******************
# pred, real
# 5.605297 , 7.0
# ******************
# pred, real
# 6.7959886 , 5.0
# ******************
# pred, real
# 5.9663596 , 6.0
# ******************
# pred, real
# 5.9724627 , 6.0
# ******************
# pred, real
# 5.551246 , 5.0
# ******************
# pred, real
# 6.071111 , 6.0
# ******************
# pred, real
# 5.7580957 , 6.0
# ******************
# pred, real
# 6.418895 , 7.0
# ******************
# pred, real
# 4.947581 , 5.0
# ******************
# pred, real
# 5.808115 , 6.0
# ******************
# pred, real
# 6.3334694 , 6.0
# ******************
# pred, real
# 6.0486107 , 6.0
# ******************
# pred, real
# 5.6199336 , 4.0
# ******************
# pred, real
# 5.5545044 , 6.0
# ******************
# pred, real
# 6.020705 , 6.0
# ******************
# pred, real
# 6.485307 , 6.0
# ******************
# pred, real
# 5.9880395 , 5.0
# ******************
# pred, real
# 5.898058 , 4.0
# ******************
# pred, real
# 5.938396 , 5.0
# ******************
# pred, real
# 6.045011 , 6.0
# ******************
# pred, real
# 5.823465 , 5.0
# ******************
# pred, real
# 5.9809623 , 5.0
# ******************
# pred, real
# 5.2747383 , 4.0
# ******************
# pred, real
# 5.2518215 , 6.0
# ******************
# pred, real
# 5.783069 , 6.0
# ******************
# pred, real
# 5.6110077 , 5.0
# ******************
# pred, real
# 5.7641206 , 6.0
# ******************
# pred, real
# 5.8147492 , 5.0
# ******************
# pred, real
# 6.347086 , 6.0
# ******************
# pred, real
# 4.879995 , 5.0
# ******************
# pred, real
# 6.1335053 , 6.0
# ******************
# pred, real
# 5.57385 , 6.0
# ******************
# pred, real
# 4.9427195 , 6.0
# ******************
# pred, real
# 5.8940187 , 6.0
# ******************
# pred, real
# 6.8553104 , 7.0
# ******************
# pred, real
# 6.7627244 , 7.0
# ******************
# pred, real
# 5.544961 , 5.0
# ******************
# pred, real
# 6.014192 , 6.0
# ******************
# pred, real
# 5.9360623 , 5.0
# ******************
# pred, real
# 5.937182 , 5.0
# ******************
# pred, real
# 5.971291 , 5.0
# ******************
# pred, real
# 5.8220305 , 7.0
# ******************
# pred, real
# 5.9189234 , 6.0
# ******************
# pred, real
# 4.5955386 , 4.0
# ******************
# pred, real
# 5.8650756 , 5.0
# ******************
# pred, real
# 5.9666004 , 6.0
# ******************
# pred, real
# 6.3433857 , 5.0
# ******************
# pred, real
# 6.352504 , 6.0
# ******************
# pred, real
# 5.671401 , 6.0
# ******************
# pred, real
# 5.731682 , 4.0
# ******************
# pred, real
# 5.623909 , 6.0
# ******************
# pred, real
# 6.296603 , 7.0
# ******************
# pred, real
# 6.318205 , 6.0
# ******************
# pred, real
# 6.4964013 , 7.0
# ******************
# pred, real
# 5.146537 , 5.0
# ******************
# pred, real
# 6.0491333 , 6.0
# ******************
# pred, real
# 6.3354497 , 6.0
# ******************
# pred, real
# 5.1167803 , 6.0
# ******************
# pred, real
# 5.694486 , 5.0
# ******************
# pred, real
# 5.368046 , 5.0
# ******************
# pred, real
# 6.284366 , 8.0
# ******************
# pred, real
# 6.6099143 , 7.0
# ******************
# pred, real
# 4.967243 , 4.0
# ******************
# pred, real
# 6.2419057 , 6.0
# ******************
# pred, real
# 6.180832 , 5.0
# ******************
# pred, real
# 4.951103 , 5.0
# ******************
# pred, real
# 5.514321 , 5.0
# ******************
# pred, real
# 6.2657046 , 7.0
# ******************
# pred, real
# 6.556289 , 6.0
# ******************
# pred, real
# 5.6258063 , 7.0
# ******************
# pred, real
# 5.883239 , 6.0
# ******************
# pred, real
# 5.7280173 , 6.0
# ******************
# pred, real
# 5.5942287 , 6.0
# ******************
# pred, real
# 5.8252254 , 6.0
# ******************
# pred, real
# 6.667596 , 7.0
# ******************
# pred, real
# 6.1896696 , 5.0
# ******************
# pred, real
# 6.2077436 , 6.0
# ******************
# pred, real
# 5.58801 , 5.0
# ******************
# pred, real
# 6.0679326 , 6.0
# ******************
# pred, real
# 5.756991 , 5.0
# ******************
# pred, real
# 5.9880395 , 6.0
# ******************
# pred, real
# 5.948393 , 6.0
# ******************
# pred, real
# 6.1540275 , 6.0
# ******************
# pred, real
# 6.4216294 , 7.0
# ******************
# pred, real
# 5.6110773 , 6.0
# ******************
# pred, real
# 6.0947943 , 7.0
# ******************
# pred, real
# 6.2325616 , 6.0
# ******************
# pred, real
# 5.6828575 , 5.0
# ******************
# pred, real
# 6.310567 , 7.0
# ******************
# pred, real
# 5.557729 , 4.0
# ******************
# pred, real
# 5.933267 , 5.0
# ******************
# pred, real
# 5.3799148 , 5.0
# ******************
# pred, real
# 5.681009 , 5.0
# ******************
# pred, real
# 5.7168746 , 5.0
# ******************
# pred, real
# 6.307829 , 6.0
# ******************
# pred, real
# 6.3512583 , 5.0
# ******************
# pred, real
# 5.625724 , 6.0
# ******************
# pred, real
# 5.5522413 , 5.0
# ******************
# pred, real
# 6.4078174 , 7.0
# ******************
# pred, real
# 6.792637 , 7.0
# ******************
# pred, real
# 5.9880395 , 6.0
# ******************
# pred, real
# 5.7006536 , 7.0
# ******************
# pred, real
# 5.768384 , 5.0
# ******************
# pred, real
# 6.0695753 , 6.0
# ******************
# pred, real
# 5.8678923 , 6.0
# ******************
# pred, real
# 7.079937 , 6.0
# ******************
# pred, real
# 6.8918467 , 7.0
# ******************
# pred, real
# 6.8366647 , 7.0
# ******************
# pred, real
# 4.640501 , 5.0
# ******************
# pred, real
# 6.2280316 , 6.0
# ******************
# pred, real
# 5.7384453 , 5.0
# ******************
# pred, real
# 5.7364964 , 5.0
# ******************
# pred, real
# 6.1663384 , 7.0
# ******************
# pred, real
# 6.270392 , 6.0
# ******************
# pred, real
# 6.655117 , 6.0
# ******************
# pred, real
# 5.876358 , 6.0
# ******************
# pred, real
# 6.596528 , 7.0
# ******************
# pred, real
# 5.265977 , 4.0
# ******************
# pred, real
# 5.7556787 , 7.0
# ******************
# pred, real
# 5.5160203 , 6.0
# ******************
# pred, real
# 6.0435643 , 6.0
# ******************
# pred, real
# 6.4139767 , 6.0
# ******************
# pred, real
# 6.253424 , 5.0
# ******************
# pred, real
# 6.6225576 , 7.0
# ******************
# pred, real
# 6.1278973 , 7.0
# ******************
# pred, real
# 5.8194084 , 5.0
# ******************
# pred, real
# 6.4950943 , 6.0
# ******************
# pred, real
# 6.4262033 , 6.0
# ******************
# pred, real
# 5.622075 , 5.0
# ******************
# pred, real
# 6.3887534 , 6.0
# ******************
# pred, real
# 5.3846974 , 7.0
# ******************
# pred, real
# 5.89446 , 6.0
# ******************
# pred, real
# 5.5177226 , 6.0
# ******************
# pred, real
# 5.04494 , 5.0
# ******************
# pred, real
# 5.571045 , 5.0
# ******************
# pred, real
# 5.8274665 , 5.0
# ******************
# pred, real
# 5.7635617 , 6.0
# ******************
# pred, real
# 6.166541 , 5.0
# ******************
# pred, real
# 5.6876354 , 5.0
# ******************
# pred, real
# 5.742687 , 7.0
# ******************
# pred, real
# 6.3582478 , 6.0
# ******************
# pred, real
# 6.4216294 , 7.0
# ******************
# pred, real
# 5.587871 , 5.0
# ******************
# pred, real
# 6.2355347 , 7.0
# ******************
# pred, real
# 6.6025352 , 7.0
# ******************
# pred, real
# 5.973626 , 6.0
# ******************
# pred, real
# 5.272611 , 5.0
# ******************
# pred, real
# 6.8301525 , 7.0
# ******************
# pred, real
# 5.1421876 , 5.0
# ******************
# pred, real
# 5.659086 , 6.0
# ******************
# pred, real
# 6.043402 , 6.0
# ******************
# pred, real
# 6.1191206 , 6.0
# ******************
# pred, real
# 6.0936813 , 6.0
# ******************
# pred, real
# 5.9142146 , 5.0
# ******************
# pred, real
# 5.931336 , 6.0
# ******************
# pred, real
# 6.2345953 , 6.0
# ******************
# pred, real
# 5.7505245 , 7.0
# ******************
# pred, real
# 5.575078 , 5.0
# ******************
# pred, real
# 5.3650475 , 5.0
# ******************
# pred, real
# 5.653844 , 5.0
# ******************
# pred, real
# 5.6873226 , 7.0
# ******************
# pred, real
# 5.7522936 , 4.0
# ******************
# pred, real
# 6.0397696 , 5.0
# ******************
# pred, real
# 6.4796567 , 6.0
# ******************
# pred, real
# 5.279287 , 5.0
# ******************
# pred, real
# 6.2064643 , 6.0
# ******************
# pred, real
# 5.393808 , 5.0
# ******************
# pred, real
# 6.086855 , 7.0
# ******************
# pred, real
# 5.5917087 , 6.0
# ******************
# pred, real
# 5.893394 , 6.0
# ******************
# pred, real
# 6.108687 , 7.0
# ******************
# pred, real
# 6.506964 , 6.0
# ******************
# pred, real
# 5.5777025 , 5.0
# ******************
# pred, real
# 5.480112 , 6.0
# ******************
# pred, real
# 6.208082 , 6.0
# ******************
# pred, real
# 6.07955 , 6.0
# ******************
# pred, real
# 6.1174097 , 6.0
# ******************
# pred, real
# 5.5877256 , 6.0
# ******************
# pred, real
# 6.5346227 , 7.0
# ******************
# pred, real
# 5.5009174 , 5.0
# ******************
# pred, real
# 6.099601 , 6.0
# ******************
# pred, real
# 6.1434135 , 8.0
# ******************
# pred, real
# 6.2191195 , 7.0
# ******************
# pred, real
# 6.2109885 , 6.0
# ******************
# pred, real
# 6.2371674 , 7.0
# ******************
# pred, real
# 5.5441613 , 4.0
# ******************
# pred, real
# 5.381865 , 5.0
# ******************
# pred, real
# 5.389485 , 5.0
# ******************
# pred, real
# 5.5493016 , 6.0
# ******************
# pred, real
# 6.608267 , 7.0
# ******************
# pred, real
# 6.3468413 , 5.0
# ******************
# pred, real
# 5.8668323 , 5.0
# ******************
# pred, real
# 5.5315757 , 5.0
# ******************
# pred, real
# 6.517394 , 7.0
# ******************
# pred, real
# 5.8143973 , 6.0
# ******************
# pred, real
# 6.486641 , 6.0
# ******************
# pred, real
# 6.809752 , 7.0
# ******************
# pred, real
# 5.439819 , 6.0
# ******************
# pred, real
# 5.359932 , 6.0
# ******************
# pred, real
# 5.5236654 , 6.0
# ******************
# pred, real
# 5.521543 , 6.0
# ******************
# pred, real
# 5.6025906 , 7.0
# ******************
# pred, real
# 5.6750197 , 5.0
# ******************
# pred, real
# 5.9787483 , 6.0
# ******************
# pred, real
# 5.727559 , 6.0
# ******************
# pred, real
# 5.921026 , 6.0
# ******************
# pred, real
# 5.4744043 , 6.0
# ******************
# pred, real
# 6.124343 , 6.0
# ******************
# pred, real
# 5.6117916 , 6.0
# ******************
# pred, real
# 5.2491903 , 5.0
# ******************
# pred, real
# 6.3397427 , 6.0
# ******************
# pred, real
# 6.7713785 , 7.0
# ******************
# pred, real
# 5.601413 , 6.0
# ******************
# pred, real
# 5.5441365 , 5.0
# ******************
# pred, real
# 5.8997574 , 6.0
# ******************
# pred, real
# 5.338705 , 5.0
# ******************
# pred, real
# 6.650286 , 8.0
# ******************
# pred, real
# 5.7441387 , 5.0
# ******************
# pred, real
# 6.085461 , 7.0
# ******************
# pred, real
# 6.7029815 , 7.0
# ******************
# pred, real
# 5.383812 , 5.0
# ******************
# pred, real
# 5.8994193 , 5.0
# ******************
# pred, real
# 5.8604527 , 6.0
# ******************
# pred, real
# 5.465144 , 5.0
# ******************
# pred, real
# 6.554595 , 6.0
# ******************
# pred, real
# 5.7273374 , 6.0
# ******************
# pred, real
# 5.283916 , 5.0
# ******************
# pred, real
# 5.5630755 , 6.0
# ******************
# pred, real
# 5.628143 , 5.0
# ******************
# pred, real
# 6.522471 , 7.0
# ******************
# pred, real
# 5.816547 , 6.0
# ******************
# pred, real
# 5.350615 , 6.0
# ******************
# pred, real
# 5.22129 , 5.0
# ******************
# pred, real
# 5.93888 , 7.0
# ******************
# pred, real
# 6.8136897 , 7.0
# ******************
# pred, real
# 5.4550986 , 4.0
# ******************
# pred, real
# 6.476717 , 6.0
# ******************
# pred, real
# 6.4774103 , 5.0
# ******************
# pred, real
# 5.3784957 , 6.0
# ******************
# pred, real
# 5.5763903 , 6.0
# ******************
# pred, real
# 5.713386 , 6.0
# ******************
# pred, real
# 6.294108 , 7.0
# ******************
# pred, real
# 5.224903 , 6.0
# ******************
# pred, real
# 6.794894 , 6.0
# ******************
# pred, real
# 5.834609 , 6.0
# ******************
# pred, real
# 4.7928267 , 4.0
# ******************
# pred, real
# 5.9080276 , 6.0
# ******************
# pred, real
# 5.543764 , 5.0
# ******************
# pred, real
# 5.415401 , 5.0
# ******************
# pred, real
# 5.648777 , 6.0
# ******************
# pred, real
# 4.9750485 , 5.0
# ******************
# pred, real
# 5.140147 , 5.0
# ******************
# pred, real
# 5.7110186 , 6.0
# ******************
# pred, real
# 6.835431 , 7.0
# ******************
# pred, real
# 6.6923714 , 7.0
# ******************
# pred, real
# 5.481695 , 5.0
# ******************
# pred, real
# 4.8732176 , 4.0
# ******************
# pred, real
# 6.3771086 , 6.0
# ******************
# pred, real
# 5.1205707 , 5.0
# ******************
# pred, real
# 6.00208 , 6.0
# ******************
# pred, real
# 5.212263 , 6.0
# ******************
# pred, real
# 5.6514134 , 6.0
# ******************
# pred, real
# 6.360524 , 6.0
# ******************
# pred, real
# 6.000003 , 7.0
# ******************
# pred, real
# 5.708681 , 7.0
# ******************
# pred, real
# 5.0112715 , 5.0
# ******************
# pred, real
# 6.6883926 , 7.0
# ******************
# pred, real
# 4.695836 , 5.0
# ******************
# pred, real
# 5.580231 , 5.0
# ******************
# pred, real
# 6.103222 , 6.0
# ******************
# pred, real
# 5.4821544 , 6.0
# ******************
# pred, real
# 6.146291 , 5.0
# ******************
# pred, real
# 5.9311914 , 5.0
# ******************
# pred, real
# 5.3730283 , 6.0
# ******************
# pred, real
# 5.9528584 , 6.0
# ******************
# pred, real
# 6.121093 , 7.0
# ******************
# pred, real
# 5.772996 , 5.0
# ******************
# pred, real
# 5.690094 , 5.0
# ******************
# pred, real
# 5.641071 , 5.0
# ******************
# pred, real
# 5.231404 , 6.0
# ******************
# pred, real
# 5.896672 , 6.0
# ******************
# pred, real
# 5.5148544 , 5.0
# ******************
# pred, real
# 5.7746224 , 6.0
# ******************
# pred, real
# 5.771745 , 6.0
# ******************
# pred, real
# 6.6889644 , 7.0
# ******************
# pred, real
# 5.613352 , 6.0
# ******************
# pred, real
# 6.183423 , 6.0
# ******************
# pred, real
# 5.679961 , 6.0
# ******************
# pred, real
# 6.4205933 , 6.0
# ******************
# pred, real
# 6.169569 , 5.0
# ******************
# pred, real
# 5.9134707 , 6.0
# ******************
# pred, real
# 5.6100254 , 7.0
# ******************
# pred, real
# 5.4339256 , 6.0
# ******************
# pred, real
# 5.893394 , 6.0
# ******************
# pred, real
# 6.2813134 , 7.0
# ******************
# pred, real
# 5.432559 , 5.0
# ******************
# pred, real
# 6.532849 , 6.0
# ******************
# pred, real
# 6.056421 , 5.0
# ******************
# pred, real
# 6.097366 , 6.0
# ******************
# pred, real
# 6.1100144 , 6.0
# ******************
# pred, real
# 6.2441983 , 7.0
# ******************
# pred, real
# 5.7199078 , 6.0
# ******************
# pred, real
# 6.248281 , 6.0
# ******************
# pred, real
# 6.2599764 , 6.0
# ******************
# pred, real
# 6.090437 , 6.0
# ******************
# pred, real
# 5.0991273 , 5.0
# ******************
# pred, real
# 6.3346653 , 8.0
# ******************
# pred, real
# 6.17742 , 6.0
# ******************
# pred, real
# 5.3949375 , 6.0
# ******************
# pred, real
# 6.2337418 , 7.0
# ******************
# pred, real
# 5.387649 , 5.0
# ******************
# pred, real
# 5.1081877 , 5.0
# ******************
# pred, real
# 5.4323936 , 4.0
# ******************
# pred, real
# 5.439215 , 6.0
# ******************
# pred, real
# 5.7059994 , 5.0
# ******************
# pred, real
# 5.6011233 , 5.0
# ******************
# pred, real
# 6.8381815 , 6.0
# ******************
# pred, real
# 6.76188 , 6.0
# ******************
# pred, real
# 5.3799148 , 5.0
# ******************
# pred, real
# 6.0102 , 6.0
# ******************
# pred, real
# 5.242418 , 6.0
# ******************
# pred, real
# 5.2530646 , 5.0
# ******************
# pred, real
# 6.1524944 , 6.0
# ******************
# pred, real
# 5.719033 , 5.0
# ******************
# pred, real
# 6.0071797 , 6.0
# ******************
# pred, real
# 5.990682 , 6.0
# ******************
# pred, real
# 5.811349 , 5.0
# ******************
# pred, real
# 5.69672 , 6.0
# ******************
# pred, real
# 6.685531 , 7.0
# ******************
# pred, real
# 6.2098846 , 5.0
# ******************
# pred, real
# 5.754096 , 6.0
# ******************
# pred, real
# 5.7185555 , 6.0
# ******************
# pred, real
# 5.3275213 , 6.0
# ******************
# pred, real
# 5.830032 , 6.0
# ******************
# pred, real
# 6.1191206 , 6.0
# ******************
# pred, real
# 5.7336087 , 6.0
# ******************
# pred, real
# 5.4593077 , 4.0
# ******************
# pred, real
# 6.416974 , 6.0
# ******************
# pred, real
# 4.3702297 , 5.0
# ******************
# pred, real
# 6.1969686 , 5.0
# ******************
# pred, real
# 6.4201055 , 7.0
# ******************
# pred, real
# 6.177519 , 7.0
# ******************
# pred, real
# 5.6048384 , 6.0
# ******************
# pred, real
# 5.637163 , 5.0
# ******************
# pred, real
# 6.0288167 , 8.0
# ******************
# pred, real
# 5.849779 , 7.0
# ******************
# pred, real
# 5.553833 , 6.0
# ******************
# pred, real
# 6.4578032 , 6.0
# ******************
# pred, real
# 5.4291916 , 4.0
# ******************
# pred, real
# 6.159129 , 4.0
# ******************
# pred, real
# 5.2917805 , 5.0
# ******************
# pred, real
# 5.663568 , 6.0
# ******************
# pred, real
# 6.1090355 , 6.0
# ******************
# pred, real
# 5.703734 , 6.0
# ******************
# pred, real
# 5.598872 , 6.0
# ******************
# pred, real
# 6.5740914 , 8.0
# ******************
# pred, real
# 6.1303844 , 6.0
# ******************
# pred, real
# 6.0766783 , 6.0
# ******************
# pred, real
# 6.4493713 , 6.0
# ******************
# pred, real
# 5.1360874 , 5.0
# ******************
# pred, real
# 5.4963226 , 6.0
# ******************
# pred, real
# 5.408857 , 4.0
# ******************
# pred, real
# 5.991887 , 7.0
# ******************
# pred, real
# 5.9326434 , 3.0
# ******************
# pred, real
# 5.77051 , 6.0
# ******************
# pred, real
# 6.3963213 , 6.0
# ******************
# pred, real
# 5.9202156 , 5.0
# ******************
# pred, real
# 5.7535276 , 7.0
# ******************
# pred, real
# 6.304833 , 3.0
# ******************
# pred, real
# 5.3356533 , 6.0
# ******************
# pred, real
# 6.2526994 , 7.0
# ******************
# pred, real
# 5.91485 , 5.0
# ******************
# pred, real
# 6.057578 , 7.0
# ******************
# pred, real
# 5.114788 , 5.0
# ******************
# pred, real
# 5.538614 , 6.0
# ******************
# pred, real
# 5.1829596 , 5.0
# ******************
# pred, real
# 5.640032 , 6.0
# ******************
# pred, real
# 6.1196637 , 6.0
# ******************
# pred, real
# 5.291834 , 4.0
# ******************
# pred, real
# 6.099766 , 6.0
# ******************
# pred, real
# 6.00208 , 6.0
# ******************
# pred, real
# 5.312189 , 6.0
# ******************
# pred, real
# 5.648145 , 5.0
# ******************
# pred, real
# 5.7148705 , 6.0
# ******************
# pred, real
# 5.5160203 , 6.0
# ******************
# pred, real
# 6.3792844 , 7.0
# ******************
# pred, real
# 6.0469327 , 7.0
# ******************
# pred, real
# 5.519849 , 6.0
# ******************
# pred, real
# 5.3695774 , 5.0
# ******************
# pred, real
# 5.2032313 , 5.0
# ******************
# pred, real
# 5.6958075 , 7.0
# ******************
# pred, real
# 5.519804 , 7.0
# ******************
# pred, real
# 5.7529106 , 6.0
# ******************
# pred, real
# 6.2438154 , 6.0
# ******************
# pred, real
# 5.7704353 , 6.0
# ******************
# pred, real
# 5.8520684 , 5.0
# ******************
# pred, real
# 6.005472 , 6.0
# ******************
# pred, real
# 5.2985125 , 6.0
# ******************
# pred, real
# 6.175523 , 7.0
# ******************
# pred, real
# 5.3155828 , 5.0
# ******************
# pred, real
# 6.625867 , 6.0
# ******************
# pred, real
# 5.9719353 , 7.0
# ******************
# pred, real
# 5.0998955 , 6.0
# ******************
# pred, real
# 5.975825 , 5.0
# ******************
# pred, real
# 5.578278 , 6.0
# ******************
# pred, real
# 5.7773414 , 6.0
# ******************
# pred, real
# 6.0669155 , 5.0
# ******************
# pred, real
# 5.298894 , 5.0
# ******************
# pred, real
# 5.622179 , 4.0
# ******************
# pred, real
# 6.0389285 , 6.0
# ******************
# pred, real
# 6.535982 , 7.0
# ******************
# pred, real
# 6.5290217 , 6.0
# ******************
# pred, real
# 6.2700276 , 6.0
# ******************
# pred, real
# 5.8162646 , 6.0
# ******************
# pred, real
# 5.588641 , 5.0
# ******************
# pred, real
# 5.9720054 , 6.0
# ******************
# pred, real
# 6.2287555 , 7.0
# ******************
# pred, real
# 5.878046 , 6.0
# ******************
# pred, real
# 5.819584 , 5.0
# ******************
# pred, real
# 5.601413 , 6.0
# ******************
# pred, real
# 5.6600356 , 6.0
# ******************
# pred, real
# 5.406473 , 6.0
# ******************
# pred, real
# 6.9055986 , 7.0
# ******************
# pred, real
# 5.5102262 , 5.0
# ******************
# pred, real
# 6.6699877 , 7.0
# ******************
# pred, real
# 4.915063 , 5.0
# ******************
# pred, real
# 5.9490914 , 6.0
# ******************
# pred, real
# 5.982533 , 6.0
# ******************
# pred, real
# 6.4153895 , 6.0
# ******************
# pred, real
# 5.7746396 , 7.0
# ******************
# pred, real
# 6.2813616 , 6.0
# ******************
# pred, real
# 6.546582 , 6.0
# ******************
# pred, real
# 6.524275 , 7.0
# ******************
# pred, real
# 5.782094 , 6.0
# ******************
# pred, real
# 6.1501036 , 6.0
# ******************
# pred, real
# 5.231166 , 5.0
# ******************
# pred, real
# 5.523728 , 7.0
# ******************
# pred, real
# 5.316228 , 4.0
# ******************
# pred, real
# 5.2859144 , 6.0
# ******************
# pred, real
# 5.668844 , 5.0
# ******************
# pred, real
# 5.4274583 , 5.0
# ******************
# pred, real
# 5.86967 , 6.0
# ******************
# pred, real
# 6.515853 , 6.0
# ******************
# pred, real
# 6.0896144 , 6.0
# ******************
# pred, real
# 5.899756 , 7.0
# ******************
# pred, real
# 6.9103746 , 8.0
# ******************
# pred, real
# 5.8783755 , 5.0
# ******************
# pred, real
# 6.322478 , 6.0
# ******************
# pred, real
# 5.5528 , 5.0
# ******************
# pred, real
# 5.767813 , 6.0
# ******************
# pred, real
# 6.063869 , 6.0
# ******************
# pred, real
# 5.8619804 , 5.0
# ******************
# pred, real
# 5.679469 , 5.0
# ******************
# pred, real
# 6.26703 , 7.0
# ******************
# pred, real
# 6.1089983 , 5.0
# ******************
# pred, real
# 5.924917 , 6.0
# ******************
# pred, real
# 5.7190146 , 7.0
# ******************
# pred, real
# 5.2108297 , 5.0
# ******************
# pred, real
# 6.411432 , 6.0
# ******************
# pred, real
# 5.6432757 , 6.0
# ******************
# pred, real
# 6.175877 , 6.0
# ******************
# pred, real
# 5.927785 , 7.0
# ******************
# pred, real
# 4.5275273 , 4.0
# ******************
# pred, real
# 5.7381186 , 6.0
# ******************
# pred, real
# 5.613263 , 5.0
# ******************
# pred, real
# 5.890747 , 5.0
# ******************
# pred, real
# 6.3554916 , 6.0
# ******************
# pred, real
# 5.2351217 , 5.0
# ******************
# pred, real
# 5.818693 , 6.0
# ******************
# pred, real
# 5.9542556 , 6.0
# ******************
# pred, real
# 6.0677238 , 6.0
# ******************
# pred, real
# 5.473917 , 6.0
# ******************
# pred, real
# 5.519854 , 5.0
# ******************
# pred, real
# 6.239267 , 5.0
# ******************
# pred, real
# 5.2612376 , 6.0
# ******************
# pred, real
# 6.3411164 , 5.0
# ******************
# pred, real
# 6.009412 , 6.0
# ******************
# pred, real
# 5.8672047 , 6.0
# ******************
# pred, real
# 5.091344 , 6.0
# ******************
# pred, real
# 5.479376 , 5.0
# ******************
# pred, real
# 5.5528 , 5.0
# ******************
# pred, real
# 5.9052444 , 6.0
# ******************
# pred, real
# 6.0486155 , 7.0
# ******************
# pred, real
# 5.285395 , 5.0
# ******************
# pred, real
# 5.519804 , 7.0
# ******************
# pred, real
# 4.9649944 , 6.0
# ******************
# pred, real
# 5.830497 , 6.0
# ******************
# pred, real
# 6.1290674 , 7.0
# ******************
# pred, real
# 6.335517 , 7.0
# ******************
# pred, real
# 7.323774 , 8.0
# ******************
# pred, real
# 6.603718 , 6.0
# ******************
# pred, real
# 6.3319182 , 6.0
# ******************
# pred, real
# 5.6992154 , 6.0
# ******************
# pred, real
# 6.1261306 , 6.0
# ******************
# pred, real
# 6.7564564 , 7.0
# ******************
# pred, real
# 6.1870327 , 5.0
# ******************
# pred, real
# 4.87047 , 6.0
# ******************
# pred, real
# 5.8473864 , 7.0
# ******************
# pred, real
# 6.4025245 , 6.0
# ******************
# pred, real
# 5.1113887 , 5.0
# ******************
# pred, real
# 6.1651998 , 6.0
# ******************
# pred, real
# 5.986232 , 5.0
# ******************
# pred, real
# 5.335919 , 5.0
# ******************
# pred, real
# 5.6025906 , 7.0
# ******************
# pred, real
# 5.776612 , 6.0
# ******************
# pred, real
# 6.0373244 , 6.0
# ******************
# pred, real
# 5.8498225 , 5.0
# ******************
# pred, real
# 5.6949387 , 6.0
# ******************
# pred, real
# 6.358928 , 6.0
# ******************
# pred, real
# 6.1832504 , 7.0
# ******************
# pred, real
# 6.031007 , 6.0
# ******************
# pred, real
# 5.68069 , 7.0
# ******************
# pred, real
# 5.6799564 , 6.0
# ******************
# pred, real
# 5.915818 , 6.0
# ******************
# pred, real
# 6.0590506 , 5.0
# ******************
# pred, real
# 5.771882 , 6.0
# ******************
# pred, real
# 5.7834506 , 4.0
# ******************
# pred, real
# 5.701282 , 4.0
# ******************
# pred, real
# 5.857256 , 6.0
# ******************
# pred, real
# 6.3633194 , 7.0
# ******************
# pred, real
# 5.278497 , 6.0
# ******************
# pred, real
# 5.7454877 , 5.0
# ******************
# pred, real
# 5.380171 , 6.0
# ******************
# pred, real
# 5.395169 , 5.0
# ******************
# pred, real
# 5.9755754 , 6.0
# ******************
# pred, real
# 6.1129956 , 8.0
# ******************
# pred, real
# 6.638979 , 7.0
# ******************
# pred, real
# 6.4835005 , 7.0
# ******************
# pred, real
# 6.094009 , 6.0
# ******************
# pred, real
# 5.6558995 , 6.0
# ******************
# pred, real
# 5.640444 , 6.0
# ******************
# pred, real
# 5.9701457 , 6.0
# ******************
# pred, real
# 5.580805 , 6.0
# ******************
# pred, real
# 5.102648 , 5.0
# ******************
# pred, real
# 5.567389 , 5.0
# ******************
# pred, real
# 5.5848436 , 6.0
# ******************
# pred, real
# 6.1514387 , 6.0
# ******************
# pred, real
# 5.653824 , 5.0
# ******************
# pred, real
# 5.0889125 , 5.0
# ******************
# pred, real
# 6.28897 , 7.0
# ******************
# pred, real
# 5.725839 , 5.0
# ******************
# pred, real
# 5.4052296 , 5.0
# ******************
# pred, real
# 5.5936675 , 6.0
# ******************
# pred, real
# 6.258581 , 7.0
# ******************
# pred, real
# 6.0610657 , 6.0
# ******************
# pred, real
# 4.6719747 , 5.0
# ******************
# pred, real
# 5.3887105 , 6.0
# ******************
# pred, real
# 5.340512 , 5.0
# ******************
# pred, real
# 5.64395 , 6.0
# ******************
# pred, real
# 5.6546774 , 6.0
# ******************
# pred, real
# 5.2119746 , 5.0
# ******************
# pred, real
# 4.77542 , 4.0
# ******************
# pred, real
# 6.1116586 , 5.0
# ******************
# pred, real
# 5.8941746 , 6.0
# ******************
# pred, real
# 6.2760468 , 7.0

# %% [markdown]
# ## Visualize test predictions

# %%
def plot_preds_vs_reals (list_preds, list_reals):
    ## 
    plt.figure (figsize = (13, 4))
    plt.plot (list_reals, label = 'real', color = 'r')
    plt.plot (list_preds, label = 'pred')
    plt.show ()

# %%
plot_preds_vs_reals (list_preds, list_reals)

# %% [markdown]
# ## Deploy PyTorch Model

# %%
model.eval ()

dummy_input = torch.randn (1, 11)

input_names = ["input1"]
output_names = ["output1"]

torch.onnx.export(
    model,
    dummy_input,
    "DLnet_WineData.onnx",
    verbose=False,
    input_names = input_names,
    output_names = output_names
)

# %% [markdown]
# ## XGBoost

# %%
regressor = xgb.XGBRegressor (
        
        n_estimators = 100,
        reg_lambda = 1,
        gamma = 0,
        max_depth = 10

)

# %%
regressor.fit (X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
y_pred = regressor.predict (X_test)

# %%
y_pred.shape
# Out:
# (980,)

# %%
y_pred
# Out:
# array([6.0164995, 6.199676 , 6.9482985, 4.9954386, 6.018217 , 5.998553 ,
#        5.6076736, 6.7031236, 5.999892 , 7.174231 , 6.145591 , 6.608299 ,
#        5.007542 , 6.6030703, 5.486235 , 4.907552 , 7.0006227, 5.9992137,
#        6.170984 , 5.6172276, 5.59056  , 7.0009646, 6.2173285, 5.002959 ,
#        6.1679034, 5.9748325, 5.8061476, 5.0112514, 7.998931 , 5.439818 ,
#        6.721923 , 6.495914 , 6.3005714, 5.3529463, 5.0548296, 5.6082106,
#        5.1176896, 5.9970126, 5.5661116, 5.9966583, 6.445813 , 4.999284 ,
#        6.169062 , 3.7190342, 6.8127136, 5.728903 , 5.9994855, 6.377899 ,
#        6.989745 , 6.7587166, 5.005967 , 6.000473 , 7.0004015, 6.1691346,
#        5.533175 , 5.858146 , 6.6455355, 5.0027127, 5.2615523, 6.1107025,
#        7.2659087, 5.0040016, 6.282288 , 7.0016956, 5.0006857, 6.0041194,
#        5.895269 , 5.0029945, 5.3760953, 5.720937 , 5.523804 , 5.7967567,
#        6.0210643, 5.1187444, 6.1852417, 5.7779555, 5.902208 , 6.281936 ,
#        5.4835305, 5.9989514, 5.946366 , 5.9813766, 6.517754 , 5.59056  ,
#        6.283508 , 5.000178 , 5.2752647, 6.0010104, 7.999348 , 5.0016937,
#        5.881718 , 7.988432 , 5.2156014, 5.424635 , 6.2115054, 5.718233 ,
#        5.7428923, 6.9950733, 4.9946675, 5.2882867, 5.7306805, 6.999807 ,
#        7.0279093, 6.387584 , 5.999738 , 6.1381993, 5.850126 , 6.3179235,
#        6.806125 , 6.4676986, 5.2451916, 6.1031437, 5.9721737, 5.507567 ,
#        6.2196546, 6.605723 , 6.920575 , 6.6909485, 5.9660554, 5.214302 ,
#        6.0018272, 6.355726 , 5.2316713, 6.0881076, 7.125228 , 6.000746 ,
#        6.9773555, 7.001148 , 5.667976 , 5.291733 , 7.9990373, 6.23127  ,
#        6.001044 , 5.184642 , 7.00085  , 7.004771 , 5.398348 , 6.3089595,
#        6.2296753, 5.337832 , 7.000846 , 5.0017567, 6.3895574, 5.004332 ,
#        6.0078855, 6.1134086, 6.236135 , 4.993767 , 5.7200775, 6.3337765,
#        7.0087767, 6.4648247, 5.9362183, 5.0064106, 5.2658286, 6.999931 ,
#        5.124833 , 4.692007 , 6.4608526, 6.4821134, 4.652045 , 5.672902 ,
#        5.0040617, 5.565682 , 6.281456 , 8.002288 , 6.038567 , 5.7742715,
#        6.135261 , 7.208747 , 4.452029 , 3.9993887, 4.720141 , 6.8385115,
#        7.001138 , 6.281669 , 5.802692 , 5.294306 , 5.8057046, 6.2784986,
#        6.735186 , 5.0386024, 5.7640276, 6.420457 , 6.2861953, 6.2165675,
#        5.057491 , 5.3242283, 5.3822937, 5.9870787, 7.0009713, 6.999046 ,
#        6.506097 , 5.829436 , 5.794608 , 6.0017943, 5.8812733, 5.3540487,
#        7.288276 , 6.989998 , 5.6657205, 6.0737634, 6.5058575, 6.732243 ,
#        4.904217 , 5.389828 , 5.688469 , 5.000008 , 6.6763296, 5.425254 ,
#        5.2824154, 6.0117474, 4.9993143, 6.758122 , 6.648028 , 4.7599363,
#        6.7687125, 6.0006347, 5.6662235, 5.7906337, 5.9926324, 4.79171  ,
#        6.9996963, 4.9800563, 6.552578 , 6.384233 , 5.6508756, 5.0040016,
#        5.7046604, 5.9812236, 5.2182264, 5.0082245, 5.998534 , 5.0581217,
#        4.8845615, 6.9977384, 6.985045 , 5.398348 , 5.8089666, 6.001105 ,
#        5.008155 , 5.768574 , 5.6915355, 5.018343 , 4.999177 , 6.4941993,
#        5.997302 , 5.000458 , 5.448835 , 5.9997673, 5.001056 , 5.04988  ,
#        5.474648 , 5.0013175, 6.437437 , 6.999481 , 4.961415 , 4.9989095,
#        6.148302 , 7.000285 , 6.5046616, 6.971897 , 5.045709 , 6.9464493,
#        7.9997344, 6.0008535, 6.266319 , 5.479553 , 5.892361 , 6.315892 ,
#        4.728691 , 7.193614 , 5.957219 , 7.00085  , 5.1178975, 5.844458 ,
#        6.7184434, 6.691433 , 6.9918327, 6.462176 , 5.228753 , 5.1921387,
#        6.0013943, 6.0009837, 5.318135 , 5.6484876, 5.5466695, 6.3022537,
#        6.3043513, 6.1869597, 6.578021 , 6.9964113, 5.6875634, 6.278645 ,
#        6.679141 , 6.275781 , 5.5021667, 7.216509 , 4.9986873, 5.3186793,
#        5.71379  , 5.059122 , 5.0046277, 5.782335 , 4.999663 , 5.0148797,
#        5.998207 , 6.085522 , 6.255825 , 5.9930787, 5.0010223, 4.999849 ,
#        5.998048 , 7.9949555, 5.0686426, 5.18317  , 5.999669 , 5.9939513,
#        5.7113986, 4.8049   , 8.000855 , 4.662528 , 5.9541345, 5.662504 ,
#        5.0007353, 6.368483 , 5.1564717, 5.995045 , 5.6580043, 5.99542  ,
#        7.0014825, 6.0670323, 5.6431613, 6.074903 , 5.001738 , 5.169667 ,
#        5.0288353, 6.9995613, 5.7971454, 6.401334 , 5.2882257, 5.092576 ,
#        6.434472 , 6.22281  , 5.6263614, 5.0076356, 6.1462326, 5.5375867,
#        6.9941697, 5.54605  , 6.316246 , 5.999839 , 5.9999747, 5.4370275,
#        5.5710783, 5.9387784, 5.9785867, 5.089616 , 7.0021987, 4.790359 ,
#        6.0150805, 6.3563   , 4.6356525, 5.997746 , 5.8630695, 5.001086 ,
#        6.0300584, 6.59995  , 6.158313 , 4.4999385, 7.999348 , 5.9089446,
#        6.002323 , 5.0063925, 5.053932 , 5.486944 , 5.995165 , 5.002836 ,
#        7.5090675, 5.2550063, 5.5751705, 5.442855 , 6.2141314, 5.5397143,
#        5.207332 , 5.982915 , 6.0002174, 6.4712324, 3.9742196, 6.58878  ,
#        6.6827555, 7.998522 , 4.7881546, 5.1133785, 5.9274445, 5.0029945,
#        5.8033056, 5.9690757, 5.6988044, 6.036364 , 5.994841 , 5.3270116,
#        6.684047 , 6.0790677, 6.514735 , 5.004535 , 7.9983063, 5.117585 ,
#        5.5863876, 5.009951 , 5.4978695, 5.9988484, 5.9977484, 6.861726 ,
#        5.92037  , 4.963242 , 5.505447 , 6.0030465, 6.053489 , 6.887827 ,
#        6.0030947, 5.7563653, 5.334715 , 6.2869577, 6.0004864, 6.0157156,
#        6.9259233, 6.239333 , 5.7045074, 5.363017 , 5.470383 , 5.920329 ,
#        6.8009267, 4.7534294, 5.531195 , 5.996547 , 5.68742  , 4.560276 ,
#        5.141015 , 6.1384606, 6.0023875, 5.285377 , 5.3043337, 4.9986787,
#        5.338753 , 5.2109685, 4.8184876, 5.143376 , 5.9899893, 5.592129 ,
#        5.356074 , 5.975703 , 4.8467994, 6.001057 , 5.3535094, 5.6045213,
#        5.996316 , 5.9985843, 6.890782 , 6.9999332, 6.998012 , 4.657724 ,
#        6.003457 , 6.117174 , 6.0503964, 5.3806963, 6.0882454, 5.998527 ,
#        4.171192 , 6.1286473, 6.273351 , 4.884939 , 5.9999833, 5.611694 ,
#        5.6842465, 5.335423 , 5.547809 , 6.1338058, 6.915236 , 4.9946456,
#        5.9069185, 5.8458805, 5.3013473, 5.4493594, 5.758278 , 6.438526 ,
#        7.000332 , 4.004827 , 6.6113744, 5.0187173, 5.5021667, 5.4417176,
#        7.061633 , 6.6906705, 6.9999466, 5.4177356, 5.9255843, 6.0013766,
#        6.0127363, 6.56751  , 7.028916 , 6.00096  , 5.5007377, 5.3829956,
#        5.1075716, 6.0003304, 6.5470777, 7.1392903, 7.0833716, 5.9994144,
#        7.008923 , 5.5095186, 5.001094 , 6.988716 , 5.1206512, 5.75302  ,
#        5.0495334, 5.3058815, 5.0007854, 5.999864 , 5.250577 , 5.5768285,
#        4.7097545, 6.386601 , 6.4941993, 6.0003304, 6.5983906, 5.5449533,
#        6.0051126, 6.0510116, 5.8212647, 6.424636 , 7.238225 , 5.1388597,
#        6.974526 , 4.998888 , 5.019341 , 6.1669345, 6.0035133, 7.0444517,
#        6.0017085, 6.753635 , 5.3929505, 6.9986577, 5.9997673, 5.998201 ,
#        6.969573 , 6.938903 , 6.2958403, 6.9938526, 5.699092 , 6.478804 ,
#        6.2195134, 5.680374 , 6.13915  , 6.100816 , 5.9977665, 5.1680884,
#        4.915252 , 5.745737 , 5.670991 , 5.5964   , 5.9385605, 5.4168315,
#        5.626812 , 5.0719767, 7.0833716, 5.0472136, 6.5240097, 5.7270355,
#        6.2507315, 5.1133785, 6.891141 , 5.192362 , 5.9998646, 5.7484493,
#        5.854646 , 6.294204 , 6.0145125, 6.525132 , 6.485946 , 5.092083 ,
#        5.5256624, 4.765329 , 5.5964775, 5.647223 , 5.40672  , 5.6198554,
#        6.3260384, 4.71228  , 6.1570716, 5.5671487, 6.5179796, 5.986874 ,
#        5.9839125, 5.097605 , 6.706302 , 5.169001 , 5.7990966, 6.076716 ,
#        5.9105015, 6.594333 , 5.274903 , 6.9965277, 4.976877 , 6.0003037,
#        5.957219 , 7.146626 , 6.2949104, 7.00046  , 5.548517 , 5.606002 ,
#        5.0947604, 5.690566 , 7.4002075, 6.426241 , 5.000994 , 5.3266006,
#        7.0213284, 6.438355 , 6.459049 , 7.0193033, 5.5628753, 5.1417747,
#        5.6847925, 5.4098363, 6.999862 , 5.731395 , 6.1610885, 5.998716 ,
#        5.9924893, 5.8822975, 6.0137105, 4.7852273, 4.917235 , 5.6909356,
#        6.999724 , 5.9961495, 4.9712677, 6.162358 , 5.014574 , 6.4707985,
#        6.1867895, 6.791534 , 6.8336477, 5.636811 , 5.4338574, 6.5725503,
#        5.1429625, 5.829554 , 5.99397  , 5.1787267, 5.3215337, 5.0652285,
#        5.9112244, 6.016043 , 5.210935 , 5.475462 , 6.3061585, 6.1349125,
#        4.601786 , 6.0057993, 5.3523703, 4.5981736, 5.998553 , 5.9541345,
#        6.517792 , 5.1197944, 6.5368114, 5.4929643, 3.9967573, 5.7287655,
#        5.4957294, 5.1254416, 5.997241 , 5.00712  , 4.9934015, 6.000392 ,
#        6.9985633, 7.0008683, 4.8455195, 4.749148 , 6.4949512, 4.036351 ,
#        5.999777 , 6.000554 , 6.412936 , 6.34388  , 6.339966 , 5.8212967,
#        5.2218847, 7.0017047, 4.93223  , 5.0002136, 5.8025765, 5.2496123,
#        6.444074 , 5.7078195, 5.2046995, 6.009921 , 5.6200085, 3.8606758,
#        5.009928 , 6.4589314, 5.982189 , 5.4895854, 5.5079875, 5.8123617,
#        5.9969115, 6.7408066, 6.3908362, 5.9946866, 5.62222  , 5.9976606,
#        5.184642 , 5.5360646, 6.2784986, 5.9996996, 5.9839125, 6.9996443,
#        5.0066905, 6.139102 , 6.5746517, 5.766236 , 6.7121305, 6.710417 ,
#        6.0003476, 5.997878 , 5.969669 , 6.259945 , 5.504249 , 7.3029547,
#        6.001725 , 4.732062 , 6.0798287, 5.29014  , 5.4054995, 4.006303 ,
#        5.1441684, 5.2721934, 5.4267244, 6.78072  , 6.25395  , 5.0495334,
#        6.2082744, 5.606839 , 4.5945   , 6.0983233, 5.004914 , 6.1374397,
#        5.7845917, 5.971601 , 5.4526467, 6.9884543, 4.9986653, 5.355875 ,
#        5.584266 , 5.9201236, 5.9994736, 5.854646 , 5.8987308, 6.2792444,
#        6.0000844, 5.3055124, 6.449507 , 6.310153 , 6.32602  , 6.6850557,
#        5.00033  , 7.9752665, 5.6599803, 6.0005436, 6.0664682, 4.0145063,
#        4.389579 , 4.915478 , 6.0562735, 6.9827943, 6.231566 , 5.2625585,
#        7.9995303, 6.7627325, 6.0011597, 6.6110806, 5.4517145, 5.413855 ,
#        4.143478 , 6.0224786, 6.9445505, 5.7958393, 6.000165 , 6.558645 ,
#        6.9964404, 5.197203 , 5.995059 , 7.0006723, 4.997334 , 6.998061 ,
#        4.8627043, 5.3290887, 4.9994445, 5.1366735, 6.368184 , 4.5714054,
#        7.0856323, 5.999777 , 5.9959316, 5.736738 , 5.987929 , 5.9997673,
#        5.824646 , 6.996253 , 6.0008883, 4.8967724, 5.8780584, 5.9387035,
#        6.999807 , 5.9863396, 6.4247293, 6.000078 , 5.0013247, 6.0094547,
#        5.994935 , 5.990819 , 5.020178 , 5.999648 , 6.996526 , 5.0464683,
#        5.9387307, 4.368719 , 5.8172693, 4.9250617, 4.9968233, 4.016212 ,
#        5.6720557, 6.2935486, 7.0266376, 6.0298204, 5.4048667, 6.0010653,
#        5.802972 , 6.8687596, 5.9938345, 5.2856   , 5.9961495, 5.9348607,
#        5.484637 , 7.1448326, 5.2122436, 6.999846 , 4.8486757, 5.9977713,
#        6.546429 , 6.2537093, 6.173946 , 6.0181193, 7.228106 , 7.168941 ,
#        5.519724 , 5.100556 , 4.997448 , 5.3490114, 4.004735 , 5.0955467,
#        5.002138 , 4.4769588, 6.612717 , 6.3503194, 5.998713 , 6.987623 ,
#        6.655333 , 5.000366 , 6.003843 , 5.2384562, 5.993804 , 6.1786466,
#        5.334951 , 5.0010524, 5.884194 , 6.0185914, 5.306615 , 5.637272 ,
#        4.869151 , 6.0027957, 5.447436 , 5.5907154, 6.386918 , 4.858925 ,
#        5.998949 , 5.1904025, 5.7505875, 6.010171 , 4.999805 , 6.760634 ,
#        5.8434453, 6.738699 , 5.9999733, 5.2209597, 6.456185 , 4.977124 ,
#        6.1199055, 6.0637884, 5.114828 , 5.994493 , 5.235234 , 5.2384562,
#        6.189868 , 6.6927915, 5.2451916, 6.999807 , 5.1805224, 6.514742 ,
#        6.164645 , 6.9553714, 8.000137 , 7.159219 , 6.703385 , 6.0013647,
#        5.445918 , 6.4249563, 6.879094 , 4.626687 , 6.2975388, 6.7220488,
#        5.7461805, 6.002296 , 5.671149 , 5.0006013, 6.999862 , 6.315892 ,
#        6.0017114, 5.0027413, 5.9993577, 6.2220345, 6.1431546, 5.977023 ,
#        5.7779555, 6.276669 , 6.8509636, 5.007616 , 6.2786965, 4.017448 ,
#        5.5082927, 6.422523 , 7.042892 , 5.7510505, 5.000755 , 5.560825 ,
#        5.0581217, 6.1231604, 7.987838 , 6.9964333, 7.208747 , 5.827645 ,
#        6.007832 , 6.3179235, 5.49211  , 5.2679167, 5.2290864, 4.951533 ,
#        5.4465494, 6.0012603, 5.0041466, 5.312633 , 5.897538 , 5.8019204,
#        5.270751 , 4.7862015, 7.000285 , 6.3838387, 5.559088 , 5.4496636,
#        5.3828993, 5.9976954, 5.640852 , 4.907552 , 4.0022326, 6.6332955,
#        5.4483333, 6.5690775], dtype=float32)

# %%
r2_score (y_test, y_pred)
# Out:
# 0.47171874599083596

# %% [markdown]
# ## Deploy XGBoost Model
#
# * ONIX and GitHub
