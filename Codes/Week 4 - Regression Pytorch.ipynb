# %% [markdown]
# ## Libraries

# %%
## !pip install pandas
## !pip install mlxtend

# %%
import numpy as np
import torch
import pandas as pd
## pandas lib could work csv file

import sklearn
import random
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
import matplotlib.pyplot as plt

from mlxtend.plotting import heatmap
from sklearn.model_selection import train_test_split 
from torch.utils.data import TensorDataset, DataLoader

## standard metrics in regression
## coefficeint in determination
from sklearn.metrics import r2_score

# %% [markdown]
# ## Parameters

# %%
batch_size = 4
learning_rate = 0.001
N_Epochs = 100

epsilon = 0.001

# %% [markdown]
# ## Read data

# %%
path_data = 'data/winequality-white.csv'

WINE_raw_data = pd.read_csv (path_data, delimiter = ";")

## WINE_raw_data -d csv file iig duudaj ugj bn.

# %%
WINE_raw_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## headers_list

headers_list = WINE_raw_data.columns.values.tolist ()
##csv file iin header deer bga medeelliig avj list helberluu shiljuulj label hiihdee ashiglahad beldej bna

headers_list
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
headers_list2 = ['density',
 'pH',
 'sulphates',
 'alcohol',
 'quality']

# %% [markdown]
# ## Data Analysis
#
# * Correlation Matrix

# %%
cm = np.corrcoef ( WINE_raw_data[headers_list].values.T  )
hm = heatmap (cm, row_names = headers_list, column_names = headers_list, figsize= (20,10))
## heatmap in doorhi turlii medeelliig haruuldag function.
## if value was 1, those values have positive correlation 
## if value was -1, those values have negative correlation
## if value was 0, there is no correlation between 2 values
## doorhi uzuulsen medeellees quality bolon alcohol 2 iin hoorondin hamaaral hamgiin undur bga gesen medeelel harj boloh n, column quality iin hamgiin undur utga avsan n 0.44 alcohol bn

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Process Data

# %%
## Convert Pandas to Numpy
## CSV filed bsan datag Pandas aar unshij avsan bsanaa Numpy ruu hurvuulj deer n ajillahad beldej bn

WINE_raw_data_np = WINE_raw_data.to_numpy()

# %%
WINE_raw_data_np
# Out:
# array([[ 7.  ,  0.27,  0.36, ...,  0.45,  8.8 ,  6.  ],
#        [ 6.3 ,  0.3 ,  0.34, ...,  0.49,  9.5 ,  6.  ],
#        [ 8.1 ,  0.28,  0.4 , ...,  0.44, 10.1 ,  6.  ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  0.46,  9.4 ,  6.  ],
#        [ 5.5 ,  0.29,  0.3 , ...,  0.38, 12.8 ,  7.  ],
#        [ 6.  ,  0.21,  0.38, ...,  0.32, 11.8 ,  6.  ]])

# %%
WINE_raw_data_np.shape
# Out:
# (4898, 12)

# %%
## indexing data

X = WINE_raw_data_np [:, :-1]
## , buh row iig avna. columns aas suuliin negiig songoj avna (slicing)

y = WINE_raw_data_np [:,11:12]

# %%
print (X.shape)
print (y.shape)
# Out:
# (4898, 11)
# (4898, 1)

# %%
random_seed = int (random.random() *42) ## 42

# %%
## split X and y

## ????????

X_train, X_test, y_train, y_test = train_test_split (X, y, test_size = 0.2, random_state = random_seed)

# %%
print (X_train.shape)
print (X_test.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# (3918, 11)
# (980, 11)
# (3918, 1)
# (980, 1)

# %% [markdown]
# ## Fix in case float64 error

# %%
y_test.dtype ## sometimes torch gives you problem because of data had different data type
# Out:
# dtype('float64')

# %%
## fix data type

X_train = X_train.astype (np.float32)
X_test = X_test.astype (np.float32)
y_train = y_train.astype (np.float32)
y_test = y_test.astype (np.float32)

# %%
X_train.dtype
X_test.dtype
y_train.dtype
y_test.dtype
# Out:
# dtype('float32')

# %%
## convert data to torch from Numpy

X_train_tr = torch.from_numpy (X_train)
X_test_tr  = torch.from_numpy (X_test)
y_train_tr = torch.from_numpy (y_train)
y_test_tr  = torch.from_numpy (y_test)

# %% [markdown]
# ## Normalization
#
# * Normalization
# * Standardization (*)

# %%
## X_scaled = (X - x_means)/X_standard_dev

x_means      = X_train_tr.mean (0, keepdim = True )
x_deviations = X_train_tr.std (0, keepdim = True ) + epsilon

# %%
x_means
# Out:
# tensor([[6.8562e+00, 2.7853e-01, 3.3524e-01, 6.3740e+00, 4.5757e-02, 3.5291e+01,
#          1.3871e+02, 9.9403e-01, 3.1892e+00, 4.8926e-01, 1.0512e+01]])

# %%
x_deviations
# Out:
# tensor([[8.4559e-01, 1.0145e-01, 1.2197e-01, 4.9902e+00, 2.2926e-02, 1.7038e+01,
#          4.2474e+01, 3.9216e-03, 1.5223e-01, 1.1455e-01, 1.2306e+00]])

# %% [markdown]
# ## Create the DataLoader

# %%
train_ds = TensorDataset ( X_train_tr, y_train_tr )

# %%
train_dl = DataLoader (train_ds, batch_size , shuffle=True )

## surgah ugugdluu shuffle hiij holij surgahdaa dahin ashiglana.

# %%
train_dl

# %% [markdown]
# ## Neural Network Architectures

# %%
## Linear Regression

class LinRegNet (nn.Module):
    ## nn class is neural network class
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()
        
        self.x_means      = x_means       ##
        self.x_deviations = x_deviations
        
        self.linear1 = nn.Linear (11,1)
        ## 11,1 those values depend on data.
        
    ## perform inference
    def forward (self, x):
        
        x = (x - self.x_means)/ self.x_deviations
        
        y_pred = self.linear1(x)
        
        ## return torch.round (y_pred)
        return y_pred

# %% [markdown]
# ## Training Loop

# %%
def training_loop (N_Epochs, model, loss_fn, opt):
    
    for epoch in range (N_Epochs):
        for xb, yb in train_dl:
            
            opt.zero_grad ()
            
            y_pred = model (xb)
            loss = loss_fn (y_pred, yb)
            
            loss.backward ()
            
            opt.step ()
            
        if epoch % 20 == 0:
            print (epoch, "loss=", loss)

# %%
## model = LinRegNet ( x_means, x_deviations )
model = LinRegNet ( x_means, x_deviations )

opt = torch.optim.Adam ( model.parameters(), lr =learning_rate )
## optimazation - gradient descent

loss_fn = F.mse_loss 
## belen loss function iig duudaj bn. MSE

training_loop (N_Epochs, model, loss_fn, opt)
# Out:
# 0 loss= tensor(25.5195, grad_fn=<MseLossBackward0>)
# 20 loss= tensor(0.4547, grad_fn=<MseLossBackward0>)
# 40 loss= tensor(0.8320, grad_fn=<MseLossBackward0>)
# 60 loss= tensor(0.1544, grad_fn=<MseLossBackward0>)
# 80 loss= tensor(0.2946, grad_fn=<MseLossBackward0>)

# %% [markdown]
# ## Evaluate Model

# %%
y_pred_test = model ( X_test_tr )

# %%
y_pred_test.shape
# Out:
# torch.Size([980, 1])

# %%
## r2_score is predicted x

## y_pred_test

# %%
print ( "Testing R**2: ", r2_score ( y_test_tr.numpy(), y_pred_test.detach().numpy() ) )

## range 0 - 1, best is 1
# Out:
# Testing R**2:  0.27195120053877053

# %%
y_pred_test.shape
# Out:
# torch.Size([980, 1])

# %%
y_test_tr.shape
# Out:
# torch.Size([980, 1])

# %%
len(X_test_tr)
# Out:
# 980

# %%
list_preds = []
list_reals = []

for i in range (len(X_test_tr)):
    print ("******************")
    print ("pred, real")
    np_real =   y_test_tr[i].detach().numpy()
    np_pred = y_pred_test[i].detach().numpy()
    print (np_pred[0],",", np_real[0])
    list_preds.append (  np_pred[0] )
    list_reals.append (  np_real[0] )
# Out:
# ******************
# pred, real
# 5.6455784 , 5.0
# ******************
# pred, real
# 6.2829185 , 6.0
# ******************
# pred, real
# 6.7086124 , 6.0
# ******************
# pred, real
# 5.5213614 , 5.0
# ******************
# pred, real
# 5.3191032 , 5.0
# ******************
# pred, real
# 5.2799044 , 5.0
# ******************
# pred, real
# 4.9997935 , 5.0
# ******************
# pred, real
# 5.72338 , 6.0
# ******************
# pred, real
# 6.4768806 , 7.0
# ******************
# pred, real
# 5.1712866 , 5.0
# ******************
# pred, real
# 6.1402774 , 5.0
# ******************
# pred, real
# 6.8278427 , 6.0
# ******************
# pred, real
# 5.488449 , 5.0
# ******************
# pred, real
# 5.630345 , 6.0
# ******************
# pred, real
# 5.6411514 , 5.0
# ******************
# pred, real
# 6.7946415 , 6.0
# ******************
# pred, real
# 6.2633023 , 7.0
# ******************
# pred, real
# 6.0515666 , 6.0
# ******************
# pred, real
# 5.397972 , 6.0
# ******************
# pred, real
# 5.2490783 , 5.0
# ******************
# pred, real
# 5.715282 , 6.0
# ******************
# pred, real
# 5.3128915 , 5.0
# ******************
# pred, real
# 6.051832 , 5.0
# ******************
# pred, real
# 5.9553914 , 5.0
# ******************
# pred, real
# 5.604815 , 6.0
# ******************
# pred, real
# 5.595658 , 6.0
# ******************
# pred, real
# 6.10654 , 6.0
# ******************
# pred, real
# 5.6312675 , 5.0
# ******************
# pred, real
# 5.8631735 , 6.0
# ******************
# pred, real
# 5.9675913 , 7.0
# ******************
# pred, real
# 5.989705 , 6.0
# ******************
# pred, real
# 5.779638 , 6.0
# ******************
# pred, real
# 5.2483964 , 5.0
# ******************
# pred, real
# 6.6509576 , 8.0
# ******************
# pred, real
# 5.617596 , 5.0
# ******************
# pred, real
# 5.6167283 , 6.0
# ******************
# pred, real
# 5.2285333 , 5.0
# ******************
# pred, real
# 5.7342305 , 6.0
# ******************
# pred, real
# 4.9355173 , 4.0
# ******************
# pred, real
# 5.0562224 , 6.0
# ******************
# pred, real
# 6.5630097 , 7.0
# ******************
# pred, real
# 5.490954 , 6.0
# ******************
# pred, real
# 5.8094807 , 7.0
# ******************
# pred, real
# 5.9579263 , 5.0
# ******************
# pred, real
# 6.16826 , 8.0
# ******************
# pred, real
# 5.084199 , 5.0
# ******************
# pred, real
# 5.589838 , 6.0
# ******************
# pred, real
# 5.3761573 , 6.0
# ******************
# pred, real
# 5.2642674 , 5.0
# ******************
# pred, real
# 6.4252276 , 7.0
# ******************
# pred, real
# 5.3536644 , 5.0
# ******************
# pred, real
# 5.2440667 , 4.0
# ******************
# pred, real
# 5.2325897 , 5.0
# ******************
# pred, real
# 6.0458803 , 6.0
# ******************
# pred, real
# 6.6311884 , 7.0
# ******************
# pred, real
# 6.344646 , 6.0
# ******************
# pred, real
# 5.9003453 , 5.0
# ******************
# pred, real
# 5.6943455 , 6.0
# ******************
# pred, real
# 6.735833 , 7.0
# ******************
# pred, real
# 6.5640497 , 6.0
# ******************
# pred, real
# 5.5146737 , 6.0
# ******************
# pred, real
# 6.478062 , 7.0
# ******************
# pred, real
# 6.028281 , 7.0
# ******************
# pred, real
# 6.476326 , 7.0
# ******************
# pred, real
# 5.4556165 , 5.0
# ******************
# pred, real
# 6.3947635 , 6.0
# ******************
# pred, real
# 4.884657 , 5.0
# ******************
# pred, real
# 5.875722 , 6.0
# ******************
# pred, real
# 6.0716467 , 6.0
# ******************
# pred, real
# 5.938426 , 6.0
# ******************
# pred, real
# 6.26929 , 6.0
# ******************
# pred, real
# 5.7061005 , 6.0
# ******************
# pred, real
# 6.258605 , 7.0
# ******************
# pred, real
# 5.6089067 , 5.0
# ******************
# pred, real
# 6.071262 , 6.0
# ******************
# pred, real
# 6.749503 , 7.0
# ******************
# pred, real
# 5.5354347 , 5.0
# ******************
# pred, real
# 5.598858 , 6.0
# ******************
# pred, real
# 6.162379 , 6.0
# ******************
# pred, real
# 5.527183 , 5.0
# ******************
# pred, real
# 6.383958 , 7.0
# ******************
# pred, real
# 6.0270267 , 6.0
# ******************
# pred, real
# 5.498903 , 5.0
# ******************
# pred, real
# 5.390398 , 6.0
# ******************
# pred, real
# 6.1229277 , 7.0
# ******************
# pred, real
# 6.5733094 , 6.0
# ******************
# pred, real
# 5.467524 , 5.0
# ******************
# pred, real
# 5.7348948 , 5.0
# ******************
# pred, real
# 6.290522 , 7.0
# ******************
# pred, real
# 5.7995553 , 4.0
# ******************
# pred, real
# 5.9171367 , 6.0
# ******************
# pred, real
# 6.2892623 , 7.0
# ******************
# pred, real
# 5.5132313 , 5.0
# ******************
# pred, real
# 5.994291 , 6.0
# ******************
# pred, real
# 6.0418234 , 5.0
# ******************
# pred, real
# 6.101735 , 5.0
# ******************
# pred, real
# 5.4063797 , 5.0
# ******************
# pred, real
# 5.717379 , 5.0
# ******************
# pred, real
# 5.5236983 , 6.0
# ******************
# pred, real
# 6.1676445 , 7.0
# ******************
# pred, real
# 5.7050476 , 7.0
# ******************
# pred, real
# 6.034686 , 6.0
# ******************
# pred, real
# 5.1971955 , 5.0
# ******************
# pred, real
# 5.811572 , 7.0
# ******************
# pred, real
# 6.682983 , 8.0
# ******************
# pred, real
# 6.487103 , 6.0
# ******************
# pred, real
# 5.581097 , 6.0
# ******************
# pred, real
# 5.44302 , 5.0
# ******************
# pred, real
# 5.089507 , 5.0
# ******************
# pred, real
# 6.3159404 , 6.0
# ******************
# pred, real
# 5.0562224 , 6.0
# ******************
# pred, real
# 6.095957 , 7.0
# ******************
# pred, real
# 5.336305 , 6.0
# ******************
# pred, real
# 6.762142 , 6.0
# ******************
# pred, real
# 5.912079 , 3.0
# ******************
# pred, real
# 5.292216 , 5.0
# ******************
# pred, real
# 6.0823607 , 6.0
# ******************
# pred, real
# 6.4886446 , 6.0
# ******************
# pred, real
# 5.9145117 , 6.0
# ******************
# pred, real
# 5.479458 , 5.0
# ******************
# pred, real
# 6.583309 , 8.0
# ******************
# pred, real
# 5.6347528 , 7.0
# ******************
# pred, real
# 6.0561185 , 6.0
# ******************
# pred, real
# 6.611396 , 6.0
# ******************
# pred, real
# 5.9849353 , 6.0
# ******************
# pred, real
# 5.597343 , 6.0
# ******************
# pred, real
# 5.592315 , 6.0
# ******************
# pred, real
# 5.504183 , 4.0
# ******************
# pred, real
# 5.696331 , 5.0
# ******************
# pred, real
# 6.5178666 , 7.0
# ******************
# pred, real
# 6.1890693 , 6.0
# ******************
# pred, real
# 6.046144 , 6.0
# ******************
# pred, real
# 5.6168838 , 5.0
# ******************
# pred, real
# 5.6480193 , 6.0
# ******************
# pred, real
# 5.837578 , 6.0
# ******************
# pred, real
# 5.0271306 , 5.0
# ******************
# pred, real
# 5.4781027 , 5.0
# ******************
# pred, real
# 5.98849 , 6.0
# ******************
# pred, real
# 6.418606 , 7.0
# ******************
# pred, real
# 5.3116956 , 5.0
# ******************
# pred, real
# 5.3486423 , 6.0
# ******************
# pred, real
# 6.7129326 , 6.0
# ******************
# pred, real
# 6.3279877 , 6.0
# ******************
# pred, real
# 5.0196667 , 6.0
# ******************
# pred, real
# 5.9603615 , 4.0
# ******************
# pred, real
# 4.2493715 , 4.0
# ******************
# pred, real
# 5.671971 , 6.0
# ******************
# pred, real
# 6.442813 , 5.0
# ******************
# pred, real
# 5.499036 , 5.0
# ******************
# pred, real
# 5.6291785 , 6.0
# ******************
# pred, real
# 5.9911017 , 6.0
# ******************
# pred, real
# 5.560368 , 4.0
# ******************
# pred, real
# 5.4927335 , 6.0
# ******************
# pred, real
# 5.8125267 , 6.0
# ******************
# pred, real
# 6.6985235 , 6.0
# ******************
# pred, real
# 6.313015 , 6.0
# ******************
# pred, real
# 5.1824684 , 6.0
# ******************
# pred, real
# 6.220518 , 6.0
# ******************
# pred, real
# 5.4656453 , 6.0
# ******************
# pred, real
# 5.580409 , 5.0
# ******************
# pred, real
# 5.398514 , 6.0
# ******************
# pred, real
# 5.3513966 , 5.0
# ******************
# pred, real
# 5.527719 , 5.0
# ******************
# pred, real
# 5.6168146 , 7.0
# ******************
# pred, real
# 5.6976123 , 6.0
# ******************
# pred, real
# 5.508008 , 5.0
# ******************
# pred, real
# 6.5170755 , 7.0
# ******************
# pred, real
# 6.17592 , 6.0
# ******************
# pred, real
# 6.383958 , 7.0
# ******************
# pred, real
# 5.4099603 , 5.0
# ******************
# pred, real
# 6.2434845 , 8.0
# ******************
# pred, real
# 5.4445295 , 5.0
# ******************
# pred, real
# 5.7588243 , 6.0
# ******************
# pred, real
# 5.938426 , 6.0
# ******************
# pred, real
# 6.547966 , 7.0
# ******************
# pred, real
# 5.1971955 , 5.0
# ******************
# pred, real
# 6.411133 , 5.0
# ******************
# pred, real
# 5.7632394 , 5.0
# ******************
# pred, real
# 6.5896835 , 7.0
# ******************
# pred, real
# 6.1686893 , 5.0
# ******************
# pred, real
# 6.23645 , 7.0
# ******************
# pred, real
# 6.9822516 , 3.0
# ******************
# pred, real
# 5.1383514 , 6.0
# ******************
# pred, real
# 5.5373173 , 5.0
# ******************
# pred, real
# 5.8576818 , 5.0
# ******************
# pred, real
# 5.6118975 , 5.0
# ******************
# pred, real
# 5.413912 , 6.0
# ******************
# pred, real
# 5.589276 , 6.0
# ******************
# pred, real
# 6.563812 , 7.0
# ******************
# pred, real
# 6.2633023 , 7.0
# ******************
# pred, real
# 6.8499074 , 7.0
# ******************
# pred, real
# 6.4546623 , 7.0
# ******************
# pred, real
# 6.2639027 , 6.0
# ******************
# pred, real
# 6.7639437 , 7.0
# ******************
# pred, real
# 5.6139812 , 5.0
# ******************
# pred, real
# 5.6615825 , 5.0
# ******************
# pred, real
# 6.6979394 , 7.0
# ******************
# pred, real
# 5.9644423 , 6.0
# ******************
# pred, real
# 5.604244 , 6.0
# ******************
# pred, real
# 6.1225266 , 7.0
# ******************
# pred, real
# 5.7830343 , 5.0
# ******************
# pred, real
# 4.7473516 , 5.0
# ******************
# pred, real
# 6.195564 , 6.0
# ******************
# pred, real
# 5.8164515 , 5.0
# ******************
# pred, real
# 5.3265924 , 6.0
# ******************
# pred, real
# 5.0788918 , 5.0
# ******************
# pred, real
# 6.357574 , 6.0
# ******************
# pred, real
# 5.8989215 , 6.0
# ******************
# pred, real
# 6.1229277 , 7.0
# ******************
# pred, real
# 5.8198943 , 7.0
# ******************
# pred, real
# 5.4319763 , 5.0
# ******************
# pred, real
# 6.913478 , 8.0
# ******************
# pred, real
# 5.8662972 , 7.0
# ******************
# pred, real
# 6.0254188 , 7.0
# ******************
# pred, real
# 6.367475 , 7.0
# ******************
# pred, real
# 6.274668 , 8.0
# ******************
# pred, real
# 5.5373173 , 5.0
# ******************
# pred, real
# 5.8889832 , 6.0
# ******************
# pred, real
# 5.6361923 , 6.0
# ******************
# pred, real
# 5.752606 , 6.0
# ******************
# pred, real
# 5.5296445 , 6.0
# ******************
# pred, real
# 6.9561186 , 6.0
# ******************
# pred, real
# 6.109643 , 6.0
# ******************
# pred, real
# 5.7277827 , 7.0
# ******************
# pred, real
# 6.123296 , 7.0
# ******************
# pred, real
# 6.3265214 , 7.0
# ******************
# pred, real
# 7.060284 , 8.0
# ******************
# pred, real
# 6.4145303 , 7.0
# ******************
# pred, real
# 6.2253003 , 7.0
# ******************
# pred, real
# 6.0661197 , 6.0
# ******************
# pred, real
# 6.665334 , 6.0
# ******************
# pred, real
# 5.51335 , 5.0
# ******************
# pred, real
# 5.8970375 , 6.0
# ******************
# pred, real
# 5.4651337 , 5.0
# ******************
# pred, real
# 5.968808 , 6.0
# ******************
# pred, real
# 5.856871 , 6.0
# ******************
# pred, real
# 6.1255627 , 6.0
# ******************
# pred, real
# 6.6721344 , 5.0
# ******************
# pred, real
# 6.019201 , 7.0
# ******************
# pred, real
# 6.1737804 , 6.0
# ******************
# pred, real
# 5.866326 , 6.0
# ******************
# pred, real
# 6.2779903 , 6.0
# ******************
# pred, real
# 5.921633 , 6.0
# ******************
# pred, real
# 5.685268 , 6.0
# ******************
# pred, real
# 5.080892 , 5.0
# ******************
# pred, real
# 5.933827 , 5.0
# ******************
# pred, real
# 6.2814054 , 7.0
# ******************
# pred, real
# 5.7892423 , 6.0
# ******************
# pred, real
# 5.96041 , 5.0
# ******************
# pred, real
# 5.3036356 , 5.0
# ******************
# pred, real
# 5.6373215 , 5.0
# ******************
# pred, real
# 6.3909383 , 7.0
# ******************
# pred, real
# 6.084455 , 6.0
# ******************
# pred, real
# 5.432762 , 6.0
# ******************
# pred, real
# 5.739252 , 5.0
# ******************
# pred, real
# 5.537183 , 5.0
# ******************
# pred, real
# 6.5675864 , 6.0
# ******************
# pred, real
# 5.889731 , 6.0
# ******************
# pred, real
# 5.7696753 , 6.0
# ******************
# pred, real
# 4.602237 , 4.0
# ******************
# pred, real
# 5.976327 , 7.0
# ******************
# pred, real
# 5.4847207 , 5.0
# ******************
# pred, real
# 6.0360546 , 6.0
# ******************
# pred, real
# 6.228585 , 6.0
# ******************
# pred, real
# 4.8822994 , 5.0
# ******************
# pred, real
# 5.180598 , 5.0
# ******************
# pred, real
# 5.4665403 , 5.0
# ******************
# pred, real
# 6.030417 , 6.0
# ******************
# pred, real
# 6.530249 , 6.0
# ******************
# pred, real
# 5.847636 , 4.0
# ******************
# pred, real
# 5.698149 , 6.0
# ******************
# pred, real
# 5.2565346 , 6.0
# ******************
# pred, real
# 6.0928273 , 7.0
# ******************
# pred, real
# 5.9587955 , 6.0
# ******************
# pred, real
# 6.2341466 , 7.0
# ******************
# pred, real
# 5.614201 , 5.0
# ******************
# pred, real
# 6.345132 , 5.0
# ******************
# pred, real
# 6.069761 , 6.0
# ******************
# pred, real
# 6.005199 , 6.0
# ******************
# pred, real
# 5.502038 , 5.0
# ******************
# pred, real
# 6.2293663 , 5.0
# ******************
# pred, real
# 5.923575 , 6.0
# ******************
# pred, real
# 6.1892333 , 8.0
# ******************
# pred, real
# 6.308203 , 6.0
# ******************
# pred, real
# 6.5563726 , 6.0
# ******************
# pred, real
# 6.0685225 , 6.0
# ******************
# pred, real
# 4.9062424 , 4.0
# ******************
# pred, real
# 5.653571 , 5.0
# ******************
# pred, real
# 6.25317 , 7.0
# ******************
# pred, real
# 5.895129 , 5.0
# ******************
# pred, real
# 5.9600773 , 7.0
# ******************
# pred, real
# 6.033963 , 5.0
# ******************
# pred, real
# 5.9155254 , 6.0
# ******************
# pred, real
# 5.952555 , 6.0
# ******************
# pred, real
# 5.562202 , 5.0
# ******************
# pred, real
# 5.8860483 , 5.0
# ******************
# pred, real
# 6.183687 , 7.0
# ******************
# pred, real
# 6.2948313 , 6.0
# ******************
# pred, real
# 6.7856746 , 7.0
# ******************
# pred, real
# 6.268917 , 6.0
# ******************
# pred, real
# 5.908148 , 6.0
# ******************
# pred, real
# 6.0714774 , 7.0
# ******************
# pred, real
# 6.5046644 , 7.0
# ******************
# pred, real
# 5.107018 , 5.0
# ******************
# pred, real
# 6.0862327 , 6.0
# ******************
# pred, real
# 5.77134 , 4.0
# ******************
# pred, real
# 6.051084 , 6.0
# ******************
# pred, real
# 5.4690857 , 6.0
# ******************
# pred, real
# 6.7058086 , 8.0
# ******************
# pred, real
# 5.753809 , 5.0
# ******************
# pred, real
# 5.817795 , 5.0
# ******************
# pred, real
# 5.078491 , 6.0
# ******************
# pred, real
# 5.5002346 , 6.0
# ******************
# pred, real
# 5.6145144 , 4.0
# ******************
# pred, real
# 5.3222694 , 5.0
# ******************
# pred, real
# 5.587652 , 6.0
# ******************
# pred, real
# 6.432449 , 8.0
# ******************
# pred, real
# 5.758514 , 5.0
# ******************
# pred, real
# 5.495096 , 5.0
# ******************
# pred, real
# 5.712175 , 6.0
# ******************
# pred, real
# 6.7257195 , 7.0
# ******************
# pred, real
# 6.504523 , 6.0
# ******************
# pred, real
# 5.1562834 , 6.0
# ******************
# pred, real
# 6.6630163 , 6.0
# ******************
# pred, real
# 5.3177943 , 6.0
# ******************
# pred, real
# 5.3357124 , 5.0
# ******************
# pred, real
# 5.451101 , 6.0
# ******************
# pred, real
# 6.0264335 , 6.0
# ******************
# pred, real
# 5.735325 , 6.0
# ******************
# pred, real
# 6.1708136 , 7.0
# ******************
# pred, real
# 6.0836034 , 6.0
# ******************
# pred, real
# 5.5343075 , 5.0
# ******************
# pred, real
# 5.614201 , 5.0
# ******************
# pred, real
# 5.9607186 , 6.0
# ******************
# pred, real
# 6.1944 , 6.0
# ******************
# pred, real
# 5.681946 , 5.0
# ******************
# pred, real
# 6.2942615 , 5.0
# ******************
# pred, real
# 5.621682 , 5.0
# ******************
# pred, real
# 5.814576 , 7.0
# ******************
# pred, real
# 5.7833047 , 5.0
# ******************
# pred, real
# 6.926242 , 7.0
# ******************
# pred, real
# 6.2263546 , 5.0
# ******************
# pred, real
# 5.787292 , 5.0
# ******************
# pred, real
# 5.4322267 , 6.0
# ******************
# pred, real
# 6.3018265 , 6.0
# ******************
# pred, real
# 5.895408 , 5.0
# ******************
# pred, real
# 6.4043455 , 7.0
# ******************
# pred, real
# 5.2477365 , 5.0
# ******************
# pred, real
# 5.6873307 , 6.0
# ******************
# pred, real
# 5.9395456 , 6.0
# ******************
# pred, real
# 5.5719943 , 5.0
# ******************
# pred, real
# 5.4001865 , 6.0
# ******************
# pred, real
# 5.8392076 , 5.0
# ******************
# pred, real
# 6.4010825 , 7.0
# ******************
# pred, real
# 5.46658 , 6.0
# ******************
# pred, real
# 5.363324 , 5.0
# ******************
# pred, real
# 6.4271183 , 7.0
# ******************
# pred, real
# 5.8444705 , 6.0
# ******************
# pred, real
# 6.037449 , 7.0
# ******************
# pred, real
# 6.384901 , 6.0
# ******************
# pred, real
# 5.229003 , 6.0
# ******************
# pred, real
# 5.5979285 , 6.0
# ******************
# pred, real
# 5.313081 , 5.0
# ******************
# pred, real
# 5.1891575 , 5.0
# ******************
# pred, real
# 6.0498486 , 7.0
# ******************
# pred, real
# 5.3891015 , 6.0
# ******************
# pred, real
# 5.8121467 , 5.0
# ******************
# pred, real
# 5.5553284 , 5.0
# ******************
# pred, real
# 6.154762 , 6.0
# ******************
# pred, real
# 5.7902727 , 5.0
# ******************
# pred, real
# 5.3654723 , 5.0
# ******************
# pred, real
# 5.859741 , 6.0
# ******************
# pred, real
# 6.504779 , 7.0
# ******************
# pred, real
# 5.573206 , 5.0
# ******************
# pred, real
# 6.256001 , 6.0
# ******************
# pred, real
# 5.6126595 , 6.0
# ******************
# pred, real
# 5.581812 , 6.0
# ******************
# pred, real
# 5.7400517 , 5.0
# ******************
# pred, real
# 6.418606 , 7.0
# ******************
# pred, real
# 6.8228335 , 7.0
# ******************
# pred, real
# 5.596089 , 5.0
# ******************
# pred, real
# 6.0998077 , 7.0
# ******************
# pred, real
# 5.6160474 , 6.0
# ******************
# pred, real
# 5.8051176 , 5.0
# ******************
# pred, real
# 6.2002354 , 6.0
# ******************
# pred, real
# 5.6643167 , 5.0
# ******************
# pred, real
# 5.5106554 , 5.0
# ******************
# pred, real
# 5.7925143 , 5.0
# ******************
# pred, real
# 5.7391663 , 5.0
# ******************
# pred, real
# 5.540527 , 5.0
# ******************
# pred, real
# 6.1613617 , 7.0
# ******************
# pred, real
# 5.903897 , 5.0
# ******************
# pred, real
# 5.462119 , 6.0
# ******************
# pred, real
# 5.6023884 , 6.0
# ******************
# pred, real
# 5.8801374 , 6.0
# ******************
# pred, real
# 5.760666 , 6.0
# ******************
# pred, real
# 5.141178 , 5.0
# ******************
# pred, real
# 5.6211977 , 5.0
# ******************
# pred, real
# 6.6784453 , 7.0
# ******************
# pred, real
# 6.182849 , 7.0
# ******************
# pred, real
# 6.2148776 , 7.0
# ******************
# pred, real
# 6.2778373 , 6.0
# ******************
# pred, real
# 5.5975814 , 6.0
# ******************
# pred, real
# 5.6426835 , 5.0
# ******************
# pred, real
# 6.319292 , 6.0
# ******************
# pred, real
# 5.832768 , 6.0
# ******************
# pred, real
# 6.2188606 , 5.0
# ******************
# pred, real
# 5.9731507 , 5.0
# ******************
# pred, real
# 5.7396307 , 5.0
# ******************
# pred, real
# 6.429331 , 6.0
# ******************
# pred, real
# 5.3854547 , 5.0
# ******************
# pred, real
# 6.011344 , 6.0
# ******************
# pred, real
# 6.073767 , 5.0
# ******************
# pred, real
# 6.7204103 , 8.0
# ******************
# pred, real
# 6.141693 , 5.0
# ******************
# pred, real
# 5.1154633 , 5.0
# ******************
# pred, real
# 6.283787 , 7.0
# ******************
# pred, real
# 6.078765 , 7.0
# ******************
# pred, real
# 5.5988274 , 6.0
# ******************
# pred, real
# 5.652057 , 5.0
# ******************
# pred, real
# 6.2601376 , 7.0
# ******************
# pred, real
# 5.568041 , 5.0
# ******************
# pred, real
# 4.7553864 , 6.0
# ******************
# pred, real
# 6.5016246 , 6.0
# ******************
# pred, real
# 6.257891 , 5.0
# ******************
# pred, real
# 6.4532733 , 6.0
# ******************
# pred, real
# 5.744 , 6.0
# ******************
# pred, real
# 6.2135477 , 7.0
# ******************
# pred, real
# 5.939184 , 6.0
# ******************
# pred, real
# 6.596201 , 6.0
# ******************
# pred, real
# 5.5902486 , 6.0
# ******************
# pred, real
# 4.6024685 , 6.0
# ******************
# pred, real
# 6.4853315 , 7.0
# ******************
# pred, real
# 5.7769456 , 6.0
# ******************
# pred, real
# 6.8487873 , 7.0
# ******************
# pred, real
# 6.246095 , 6.0
# ******************
# pred, real
# 5.777075 , 5.0
# ******************
# pred, real
# 6.180635 , 5.0
# ******************
# pred, real
# 5.8893056 , 6.0
# ******************
# pred, real
# 5.397972 , 6.0
# ******************
# pred, real
# 5.1784906 , 5.0
# ******************
# pred, real
# 6.0165124 , 5.0
# ******************
# pred, real
# 6.0488873 , 6.0
# ******************
# pred, real
# 6.0756545 , 6.0
# ******************
# pred, real
# 5.4167576 , 6.0
# ******************
# pred, real
# 5.457401 , 5.0
# ******************
# pred, real
# 6.6625834 , 8.0
# ******************
# pred, real
# 5.455671 , 6.0
# ******************
# pred, real
# 5.5883822 , 5.0
# ******************
# pred, real
# 5.266205 , 6.0
# ******************
# pred, real
# 5.6767955 , 6.0
# ******************
# pred, real
# 5.3376245 , 6.0
# ******************
# pred, real
# 6.988697 , 7.0
# ******************
# pred, real
# 5.391479 , 5.0
# ******************
# pred, real
# 5.2561536 , 6.0
# ******************
# pred, real
# 4.757204 , 5.0
# ******************
# pred, real
# 6.2410383 , 6.0
# ******************
# pred, real
# 5.321114 , 5.0
# ******************
# pred, real
# 5.891966 , 6.0
# ******************
# pred, real
# 5.7151184 , 5.0
# ******************
# pred, real
# 6.0341296 , 6.0
# ******************
# pred, real
# 5.891911 , 6.0
# ******************
# pred, real
# 5.993517 , 7.0
# ******************
# pred, real
# 5.2800827 , 5.0
# ******************
# pred, real
# 5.858489 , 5.0
# ******************
# pred, real
# 6.2749863 , 5.0
# ******************
# pred, real
# 5.782976 , 6.0
# ******************
# pred, real
# 5.8289437 , 6.0
# ******************
# pred, real
# 6.2632256 , 6.0
# ******************
# pred, real
# 5.689868 , 6.0
# ******************
# pred, real
# 5.6278033 , 6.0
# ******************
# pred, real
# 5.4001865 , 6.0
# ******************
# pred, real
# 5.6696105 , 6.0
# ******************
# pred, real
# 5.6873307 , 6.0
# ******************
# pred, real
# 5.2685037 , 5.0
# ******************
# pred, real
# 6.089462 , 7.0
# ******************
# pred, real
# 5.63268 , 5.0
# ******************
# pred, real
# 6.2501063 , 7.0
# ******************
# pred, real
# 6.91082 , 8.0
# ******************
# pred, real
# 6.566061 , 6.0
# ******************
# pred, real
# 5.970805 , 6.0
# ******************
# pred, real
# 5.7977815 , 6.0
# ******************
# pred, real
# 5.280778 , 5.0
# ******************
# pred, real
# 6.580956 , 6.0
# ******************
# pred, real
# 5.6771097 , 5.0
# ******************
# pred, real
# 5.6242776 , 5.0
# ******************
# pred, real
# 6.071714 , 6.0
# ******************
# pred, real
# 5.0579267 , 5.0
# ******************
# pred, real
# 5.6347528 , 7.0
# ******************
# pred, real
# 5.5087347 , 6.0
# ******************
# pred, real
# 4.773034 , 5.0
# ******************
# pred, real
# 6.5282006 , 6.0
# ******************
# pred, real
# 6.233128 , 6.0
# ******************
# pred, real
# 5.770019 , 5.0
# ******************
# pred, real
# 5.7431765 , 6.0
# ******************
# pred, real
# 5.941224 , 6.0
# ******************
# pred, real
# 5.3126907 , 5.0
# ******************
# pred, real
# 6.1297884 , 6.0
# ******************
# pred, real
# 4.5677752 , 5.0
# ******************
# pred, real
# 5.3632884 , 6.0
# ******************
# pred, real
# 5.776323 , 4.0
# ******************
# pred, real
# 6.0437326 , 6.0
# ******************
# pred, real
# 5.960975 , 6.0
# ******************
# pred, real
# 5.6093454 , 5.0
# ******************
# pred, real
# 6.1079326 , 6.0
# ******************
# pred, real
# 5.331732 , 6.0
# ******************
# pred, real
# 5.2509527 , 5.0
# ******************
# pred, real
# 6.4964647 , 6.0
# ******************
# pred, real
# 6.234913 , 6.0
# ******************
# pred, real
# 6.035801 , 5.0
# ******************
# pred, real
# 6.5235343 , 8.0
# ******************
# pred, real
# 5.1828113 , 5.0
# ******************
# pred, real
# 5.462711 , 5.0
# ******************
# pred, real
# 6.6369658 , 6.0
# ******************
# pred, real
# 5.589276 , 6.0
# ******************
# pred, real
# 6.242311 , 6.0
# ******************
# pred, real
# 5.2174406 , 5.0
# ******************
# pred, real
# 6.3100734 , 7.0
# ******************
# pred, real
# 5.7536545 , 6.0
# ******************
# pred, real
# 5.505462 , 5.0
# ******************
# pred, real
# 5.363563 , 5.0
# ******************
# pred, real
# 5.142537 , 6.0
# ******************
# pred, real
# 5.687295 , 4.0
# ******************
# pred, real
# 5.1620274 , 5.0
# ******************
# pred, real
# 6.556537 , 6.0
# ******************
# pred, real
# 5.918001 , 6.0
# ******************
# pred, real
# 5.6361923 , 6.0
# ******************
# pred, real
# 6.100854 , 5.0
# ******************
# pred, real
# 5.277341 , 6.0
# ******************
# pred, real
# 6.534261 , 7.0
# ******************
# pred, real
# 4.920499 , 4.0
# ******************
# pred, real
# 5.1835 , 5.0
# ******************
# pred, real
# 5.4167223 , 5.0
# ******************
# pred, real
# 5.245588 , 5.0
# ******************
# pred, real
# 5.7443614 , 6.0
# ******************
# pred, real
# 6.646309 , 7.0
# ******************
# pred, real
# 6.5161905 , 8.0
# ******************
# pred, real
# 6.0439534 , 5.0
# ******************
# pred, real
# 6.103432 , 6.0
# ******************
# pred, real
# 5.2798767 , 5.0
# ******************
# pred, real
# 6.317885 , 6.0
# ******************
# pred, real
# 6.261846 , 3.0
# ******************
# pred, real
# 5.6249332 , 5.0
# ******************
# pred, real
# 6.0555754 , 5.0
# ******************
# pred, real
# 5.6151695 , 6.0
# ******************
# pred, real
# 5.3630953 , 4.0
# ******************
# pred, real
# 5.466331 , 6.0
# ******************
# pred, real
# 6.4769297 , 6.0
# ******************
# pred, real
# 6.6963267 , 7.0
# ******************
# pred, real
# 5.1898675 , 5.0
# ******************
# pred, real
# 5.679719 , 5.0
# ******************
# pred, real
# 5.792164 , 5.0
# ******************
# pred, real
# 5.325243 , 5.0
# ******************
# pred, real
# 5.814237 , 6.0
# ******************
# pred, real
# 5.3661375 , 5.0
# ******************
# pred, real
# 5.931218 , 4.0
# ******************
# pred, real
# 5.440516 , 6.0
# ******************
# pred, real
# 5.6392612 , 7.0
# ******************
# pred, real
# 6.520093 , 6.0
# ******************
# pred, real
# 5.8500996 , 6.0
# ******************
# pred, real
# 5.660131 , 6.0
# ******************
# pred, real
# 5.357794 , 5.0
# ******************
# pred, real
# 5.591083 , 4.0
# ******************
# pred, real
# 5.363088 , 5.0
# ******************
# pred, real
# 5.345808 , 7.0
# ******************
# pred, real
# 5.1740527 , 5.0
# ******************
# pred, real
# 7.0227337 , 7.0
# ******************
# pred, real
# 6.028892 , 6.0
# ******************
# pred, real
# 6.17592 , 6.0
# ******************
# pred, real
# 5.742251 , 6.0
# ******************
# pred, real
# 5.81758 , 6.0
# ******************
# pred, real
# 4.897216 , 5.0
# ******************
# pred, real
# 5.3656664 , 3.0
# ******************
# pred, real
# 5.917401 , 6.0
# ******************
# pred, real
# 5.73866 , 5.0
# ******************
# pred, real
# 5.8078623 , 5.0
# ******************
# pred, real
# 5.1706157 , 5.0
# ******************
# pred, real
# 5.781067 , 6.0
# ******************
# pred, real
# 5.8965044 , 7.0
# ******************
# pred, real
# 5.5926304 , 6.0
# ******************
# pred, real
# 5.8212905 , 6.0
# ******************
# pred, real
# 5.6756063 , 5.0
# ******************
# pred, real
# 6.3225937 , 7.0
# ******************
# pred, real
# 5.5419703 , 5.0
# ******************
# pred, real
# 5.115553 , 5.0
# ******************
# pred, real
# 6.6003118 , 7.0
# ******************
# pred, real
# 4.811969 , 5.0
# ******************
# pred, real
# 6.10752 , 6.0
# ******************
# pred, real
# 5.725761 , 6.0
# ******************
# pred, real
# 6.956099 , 7.0
# ******************
# pred, real
# 5.6876564 , 5.0
# ******************
# pred, real
# 6.536289 , 7.0
# ******************
# pred, real
# 6.359195 , 7.0
# ******************
# pred, real
# 6.1728206 , 5.0
# ******************
# pred, real
# 6.0303383 , 7.0
# ******************
# pred, real
# 6.8563495 , 6.0
# ******************
# pred, real
# 5.343403 , 5.0
# ******************
# pred, real
# 6.565665 , 7.0
# ******************
# pred, real
# 6.201394 , 7.0
# ******************
# pred, real
# 5.7851334 , 6.0
# ******************
# pred, real
# 5.2800827 , 5.0
# ******************
# pred, real
# 7.002371 , 8.0
# ******************
# pred, real
# 6.2632256 , 6.0
# ******************
# pred, real
# 5.418348 , 5.0
# ******************
# pred, real
# 5.5904937 , 6.0
# ******************
# pred, real
# 5.5892763 , 5.0
# ******************
# pred, real
# 5.415136 , 5.0
# ******************
# pred, real
# 6.271337 , 4.0
# ******************
# pred, real
# 5.3941765 , 5.0
# ******************
# pred, real
# 5.6023884 , 6.0
# ******************
# pred, real
# 5.9751806 , 5.0
# ******************
# pred, real
# 5.8925185 , 5.0
# ******************
# pred, real
# 6.1503563 , 6.0
# ******************
# pred, real
# 5.9955654 , 6.0
# ******************
# pred, real
# 6.259015 , 6.0
# ******************
# pred, real
# 6.0217357 , 7.0
# ******************
# pred, real
# 5.3396826 , 6.0
# ******************
# pred, real
# 5.4227695 , 6.0
# ******************
# pred, real
# 6.0279317 , 6.0
# ******************
# pred, real
# 6.39342 , 7.0
# ******************
# pred, real
# 5.178784 , 5.0
# ******************
# pred, real
# 5.8903894 , 6.0
# ******************
# pred, real
# 5.8126316 , 6.0
# ******************
# pred, real
# 5.5260205 , 5.0
# ******************
# pred, real
# 5.6168146 , 7.0
# ******************
# pred, real
# 5.3228884 , 5.0
# ******************
# pred, real
# 6.271594 , 6.0
# ******************
# pred, real
# 5.6289806 , 8.0
# ******************
# pred, real
# 5.5577564 , 7.0
# ******************
# pred, real
# 5.5439506 , 6.0
# ******************
# pred, real
# 5.4456677 , 6.0
# ******************
# pred, real
# 5.37828 , 6.0
# ******************
# pred, real
# 5.1797137 , 5.0
# ******************
# pred, real
# 6.4781585 , 7.0
# ******************
# pred, real
# 5.645669 , 6.0
# ******************
# pred, real
# 6.2098017 , 6.0
# ******************
# pred, real
# 4.6908092 , 6.0
# ******************
# pred, real
# 5.6168146 , 7.0
# ******************
# pred, real
# 6.238882 , 6.0
# ******************
# pred, real
# 5.5534577 , 6.0
# ******************
# pred, real
# 6.018516 , 6.0
# ******************
# pred, real
# 5.5390196 , 6.0
# ******************
# pred, real
# 5.763383 , 5.0
# ******************
# pred, real
# 6.353799 , 6.0
# ******************
# pred, real
# 5.4297132 , 5.0
# ******************
# pred, real
# 5.637244 , 5.0
# ******************
# pred, real
# 5.5956907 , 6.0
# ******************
# pred, real
# 6.1623616 , 7.0
# ******************
# pred, real
# 6.5728674 , 5.0
# ******************
# pred, real
# 6.844289 , 7.0
# ******************
# pred, real
# 5.9044333 , 5.0
# ******************
# pred, real
# 5.450878 , 7.0
# ******************
# pred, real
# 5.2355723 , 5.0
# ******************
# pred, real
# 5.422314 , 5.0
# ******************
# pred, real
# 5.875235 , 6.0
# ******************
# pred, real
# 5.740388 , 6.0
# ******************
# pred, real
# 5.4286795 , 5.0
# ******************
# pred, real
# 5.729987 , 5.0
# ******************
# pred, real
# 6.154249 , 6.0
# ******************
# pred, real
# 4.725268 , 5.0
# ******************
# pred, real
# 6.535796 , 6.0
# ******************
# pred, real
# 5.5378404 , 6.0
# ******************
# pred, real
# 5.554336 , 5.0
# ******************
# pred, real
# 5.7696753 , 6.0
# ******************
# pred, real
# 5.3460493 , 5.0
# ******************
# pred, real
# 6.5731773 , 6.0
# ******************
# pred, real
# 5.707221 , 5.0
# ******************
# pred, real
# 5.4880667 , 6.0
# ******************
# pred, real
# 5.6954904 , 5.0
# ******************
# pred, real
# 5.6655025 , 6.0
# ******************
# pred, real
# 6.1212735 , 6.0
# ******************
# pred, real
# 6.050116 , 5.0
# ******************
# pred, real
# 5.229744 , 5.0
# ******************
# pred, real
# 6.351191 , 6.0
# ******************
# pred, real
# 6.263459 , 6.0
# ******************
# pred, real
# 6.2595634 , 7.0
# ******************
# pred, real
# 5.531106 , 6.0
# ******************
# pred, real
# 5.681785 , 6.0
# ******************
# pred, real
# 5.835637 , 6.0
# ******************
# pred, real
# 5.442656 , 5.0
# ******************
# pred, real
# 6.318451 , 6.0
# ******************
# pred, real
# 6.0973415 , 5.0
# ******************
# pred, real
# 5.308262 , 5.0
# ******************
# pred, real
# 5.614201 , 5.0
# ******************
# pred, real
# 5.813505 , 6.0
# ******************
# pred, real
# 5.3996725 , 5.0
# ******************
# pred, real
# 5.371282 , 6.0
# ******************
# pred, real
# 6.2843046 , 6.0
# ******************
# pred, real
# 6.334798 , 5.0
# ******************
# pred, real
# 5.806082 , 7.0
# ******************
# pred, real
# 6.735155 , 6.0
# ******************
# pred, real
# 6.1201706 , 7.0
# ******************
# pred, real
# 6.163435 , 6.0
# ******************
# pred, real
# 4.6768007 , 6.0
# ******************
# pred, real
# 6.0603185 , 7.0
# ******************
# pred, real
# 4.515882 , 3.0
# ******************
# pred, real
# 5.0323772 , 5.0
# ******************
# pred, real
# 5.2845697 , 6.0
# ******************
# pred, real
# 5.656448 , 6.0
# ******************
# pred, real
# 6.5105577 , 7.0
# ******************
# pred, real
# 5.584594 , 5.0
# ******************
# pred, real
# 5.7143393 , 5.0
# ******************
# pred, real
# 6.630811 , 8.0
# ******************
# pred, real
# 6.46628 , 7.0
# ******************
# pred, real
# 5.3716645 , 6.0
# ******************
# pred, real
# 5.445988 , 5.0
# ******************
# pred, real
# 6.469033 , 6.0
# ******************
# pred, real
# 6.2615266 , 7.0
# ******************
# pred, real
# 5.653832 , 6.0
# ******************
# pred, real
# 5.3348713 , 4.0
# ******************
# pred, real
# 6.0281835 , 6.0
# ******************
# pred, real
# 6.5060086 , 7.0
# ******************
# pred, real
# 6.4218545 , 8.0
# ******************
# pred, real
# 5.3128915 , 5.0
# ******************
# pred, real
# 6.3902965 , 7.0
# ******************
# pred, real
# 6.2792006 , 5.0
# ******************
# pred, real
# 5.9859376 , 5.0
# ******************
# pred, real
# 5.9547157 , 8.0
# ******************
# pred, real
# 5.6393123 , 6.0
# ******************
# pred, real
# 6.2341466 , 7.0
# ******************
# pred, real
# 5.3812675 , 6.0
# ******************
# pred, real
# 6.323441 , 6.0
# ******************
# pred, real
# 5.9145412 , 6.0
# ******************
# pred, real
# 5.5419164 , 5.0
# ******************
# pred, real
# 5.7065954 , 6.0
# ******************
# pred, real
# 5.569416 , 6.0
# ******************
# pred, real
# 5.530241 , 7.0
# ******************
# pred, real
# 6.6509576 , 8.0
# ******************
# pred, real
# 5.782003 , 5.0
# ******************
# pred, real
# 5.87376 , 6.0
# ******************
# pred, real
# 6.003802 , 5.0
# ******************
# pred, real
# 6.3288074 , 7.0
# ******************
# pred, real
# 6.059069 , 6.0
# ******************
# pred, real
# 5.5374236 , 7.0
# ******************
# pred, real
# 5.6361923 , 6.0
# ******************
# pred, real
# 5.182887 , 5.0
# ******************
# pred, real
# 6.5327516 , 6.0
# ******************
# pred, real
# 5.0650826 , 4.0
# ******************
# pred, real
# 5.9545784 , 6.0
# ******************
# pred, real
# 5.549278 , 7.0
# ******************
# pred, real
# 5.2116814 , 5.0
# ******************
# pred, real
# 5.8807616 , 6.0
# ******************
# pred, real
# 5.7772737 , 5.0
# ******************
# pred, real
# 5.790712 , 5.0
# ******************
# pred, real
# 5.5545483 , 6.0
# ******************
# pred, real
# 6.0196767 , 6.0
# ******************
# pred, real
# 5.2355003 , 5.0
# ******************
# pred, real
# 4.9103394 , 5.0
# ******************
# pred, real
# 6.1542006 , 6.0
# ******************
# pred, real
# 6.1017604 , 6.0
# ******************
# pred, real
# 5.656448 , 6.0
# ******************
# pred, real
# 5.871837 , 6.0
# ******************
# pred, real
# 5.538011 , 5.0
# ******************
# pred, real
# 6.064397 , 5.0
# ******************
# pred, real
# 5.8825474 , 5.0
# ******************
# pred, real
# 6.3105397 , 7.0
# ******************
# pred, real
# 6.4459887 , 5.0
# ******************
# pred, real
# 5.858054 , 4.0
# ******************
# pred, real
# 5.6773143 , 5.0
# ******************
# pred, real
# 5.6711946 , 6.0
# ******************
# pred, real
# 5.7928605 , 6.0
# ******************
# pred, real
# 6.196203 , 7.0
# ******************
# pred, real
# 6.1268873 , 6.0
# ******************
# pred, real
# 5.90461 , 6.0
# ******************
# pred, real
# 6.0215483 , 5.0
# ******************
# pred, real
# 6.5472307 , 6.0
# ******************
# pred, real
# 5.4179044 , 5.0
# ******************
# pred, real
# 5.352428 , 5.0
# ******************
# pred, real
# 5.0446963 , 4.0
# ******************
# pred, real
# 6.0869756 , 5.0
# ******************
# pred, real
# 5.294022 , 5.0
# ******************
# pred, real
# 5.8177853 , 6.0
# ******************
# pred, real
# 6.117005 , 6.0
# ******************
# pred, real
# 6.1421285 , 7.0
# ******************
# pred, real
# 6.329769 , 5.0
# ******************
# pred, real
# 6.552845 , 6.0
# ******************
# pred, real
# 5.8936553 , 6.0
# ******************
# pred, real
# 6.3031297 , 7.0
# ******************
# pred, real
# 5.4896655 , 5.0
# ******************
# pred, real
# 5.8746657 , 6.0
# ******************
# pred, real
# 5.8586755 , 6.0
# ******************
# pred, real
# 6.3029675 , 6.0
# ******************
# pred, real
# 6.380427 , 5.0
# ******************
# pred, real
# 5.8644285 , 6.0
# ******************
# pred, real
# 6.020195 , 5.0
# ******************
# pred, real
# 5.5434732 , 7.0
# ******************
# pred, real
# 5.8449745 , 5.0
# ******************
# pred, real
# 5.9851418 , 5.0
# ******************
# pred, real
# 5.3191953 , 5.0
# ******************
# pred, real
# 5.8177233 , 6.0
# ******************
# pred, real
# 6.218586 , 7.0
# ******************
# pred, real
# 5.9238896 , 8.0
# ******************
# pred, real
# 6.6014657 , 7.0
# ******************
# pred, real
# 5.9930816 , 5.0
# ******************
# pred, real
# 5.225237 , 5.0
# ******************
# pred, real
# 6.5975103 , 6.0
# ******************
# pred, real
# 5.644337 , 6.0
# ******************
# pred, real
# 5.587967 , 6.0
# ******************
# pred, real
# 5.7633853 , 6.0
# ******************
# pred, real
# 5.9330053 , 6.0
# ******************
# pred, real
# 6.5011425 , 7.0
# ******************
# pred, real
# 5.2819433 , 5.0
# ******************
# pred, real
# 6.635573 , 7.0
# ******************
# pred, real
# 5.9154124 , 6.0
# ******************
# pred, real
# 5.7366996 , 6.0
# ******************
# pred, real
# 5.2217183 , 6.0
# ******************
# pred, real
# 5.1708007 , 6.0
# ******************
# pred, real
# 5.4815397 , 5.0
# ******************
# pred, real
# 5.870927 , 6.0
# ******************
# pred, real
# 6.4795218 , 7.0
# ******************
# pred, real
# 5.9668684 , 6.0
# ******************
# pred, real
# 5.213828 , 5.0
# ******************
# pred, real
# 5.816682 , 6.0
# ******************
# pred, real
# 5.4955597 , 6.0
# ******************
# pred, real
# 5.446712 , 7.0
# ******************
# pred, real
# 6.7163663 , 7.0
# ******************
# pred, real
# 5.5745544 , 5.0
# ******************
# pred, real
# 5.904849 , 5.0
# ******************
# pred, real
# 5.7163906 , 5.0
# ******************
# pred, real
# 5.531106 , 6.0
# ******************
# pred, real
# 5.548482 , 6.0
# ******************
# pred, real
# 5.9459867 , 6.0
# ******************
# pred, real
# 5.4249277 , 5.0
# ******************
# pred, real
# 5.696281 , 5.0
# ******************
# pred, real
# 6.1618595 , 6.0
# ******************
# pred, real
# 6.2947354 , 6.0
# ******************
# pred, real
# 5.4099603 , 5.0
# ******************
# pred, real
# 6.018516 , 6.0
# ******************
# pred, real
# 6.8202963 , 8.0
# ******************
# pred, real
# 5.717476 , 4.0
# ******************
# pred, real
# 5.421821 , 6.0
# ******************
# pred, real
# 5.4773817 , 5.0
# ******************
# pred, real
# 5.8034186 , 7.0
# ******************
# pred, real
# 5.673734 , 6.0
# ******************
# pred, real
# 5.3854427 , 5.0
# ******************
# pred, real
# 6.5060086 , 7.0
# ******************
# pred, real
# 6.3281965 , 6.0
# ******************
# pred, real
# 6.108813 , 5.0
# ******************
# pred, real
# 6.3768983 , 8.0
# ******************
# pred, real
# 5.455671 , 6.0
# ******************
# pred, real
# 6.817376 , 8.0
# ******************
# pred, real
# 6.308341 , 7.0
# ******************
# pred, real
# 6.4498415 , 7.0
# ******************
# pred, real
# 6.2815843 , 6.0
# ******************
# pred, real
# 5.4396067 , 5.0
# ******************
# pred, real
# 6.2632422 , 6.0
# ******************
# pred, real
# 6.279074 , 6.0
# ******************
# pred, real
# 6.747769 , 8.0
# ******************
# pred, real
# 5.454216 , 6.0
# ******************
# pred, real
# 6.422996 , 7.0
# ******************
# pred, real
# 5.7110553 , 6.0
# ******************
# pred, real
# 5.9341707 , 6.0
# ******************
# pred, real
# 5.9611936 , 8.0
# ******************
# pred, real
# 5.6997867 , 5.0
# ******************
# pred, real
# 5.748381 , 6.0
# ******************
# pred, real
# 5.5158505 , 7.0
# ******************
# pred, real
# 6.132668 , 6.0
# ******************
# pred, real
# 6.5256667 , 6.0
# ******************
# pred, real
# 5.9068265 , 6.0
# ******************
# pred, real
# 5.858786 , 6.0
# ******************
# pred, real
# 6.118685 , 7.0
# ******************
# pred, real
# 5.6168146 , 7.0
# ******************
# pred, real
# 5.452006 , 6.0
# ******************
# pred, real
# 5.5858555 , 5.0
# ******************
# pred, real
# 6.507036 , 7.0
# ******************
# pred, real
# 5.47254 , 6.0
# ******************
# pred, real
# 5.917294 , 7.0
# ******************
# pred, real
# 7.0247755 , 7.0
# ******************
# pred, real
# 5.8371773 , 6.0
# ******************
# pred, real
# 5.804685 , 6.0
# ******************
# pred, real
# 5.5902486 , 6.0
# ******************
# pred, real
# 6.050883 , 6.0
# ******************
# pred, real
# 5.134706 , 6.0
# ******************
# pred, real
# 5.23925 , 5.0
# ******************
# pred, real
# 5.3274946 , 5.0
# ******************
# pred, real
# 6.0571327 , 6.0
# ******************
# pred, real
# 5.2308316 , 5.0
# ******************
# pred, real
# 5.609264 , 6.0
# ******************
# pred, real
# 5.533898 , 6.0
# ******************
# pred, real
# 5.636403 , 6.0
# ******************
# pred, real
# 5.7735133 , 6.0
# ******************
# pred, real
# 6.256832 , 7.0
# ******************
# pred, real
# 5.283601 , 5.0
# ******************
# pred, real
# 6.5124316 , 7.0
# ******************
# pred, real
# 5.4608326 , 5.0
# ******************
# pred, real
# 5.6185436 , 5.0
# ******************
# pred, real
# 6.247709 , 5.0
# ******************
# pred, real
# 5.8577337 , 5.0
# ******************
# pred, real
# 5.9263215 , 4.0
# ******************
# pred, real
# 6.3128805 , 6.0
# ******************
# pred, real
# 5.805318 , 6.0
# ******************
# pred, real
# 6.0427628 , 6.0
# ******************
# pred, real
# 6.0600705 , 7.0
# ******************
# pred, real
# 6.2197113 , 3.0
# ******************
# pred, real
# 5.386939 , 5.0
# ******************
# pred, real
# 5.6978207 , 6.0
# ******************
# pred, real
# 6.0229855 , 6.0
# ******************
# pred, real
# 6.8212166 , 6.0
# ******************
# pred, real
# 6.134544 , 7.0
# ******************
# pred, real
# 5.1503406 , 5.0
# ******************
# pred, real
# 5.2917533 , 5.0
# ******************
# pred, real
# 6.080037 , 6.0
# ******************
# pred, real
# 5.5008264 , 6.0
# ******************
# pred, real
# 5.641605 , 6.0
# ******************
# pred, real
# 5.5590134 , 5.0
# ******************
# pred, real
# 5.325243 , 5.0
# ******************
# pred, real
# 6.4188943 , 6.0
# ******************
# pred, real
# 5.8320894 , 6.0
# ******************
# pred, real
# 6.187453 , 5.0
# ******************
# pred, real
# 4.979224 , 5.0
# ******************
# pred, real
# 6.369471 , 6.0
# ******************
# pred, real
# 6.1920614 , 6.0
# ******************
# pred, real
# 6.563678 , 7.0
# ******************
# pred, real
# 5.65953 , 7.0
# ******************
# pred, real
# 4.605916 , 5.0
# ******************
# pred, real
# 5.731956 , 6.0
# ******************
# pred, real
# 6.384176 , 7.0
# ******************
# pred, real
# 5.078491 , 6.0
# ******************
# pred, real
# 6.563812 , 7.0
# ******************
# pred, real
# 6.059046 , 6.0
# ******************
# pred, real
# 5.223701 , 5.0
# ******************
# pred, real
# 5.5630355 , 6.0
# ******************
# pred, real
# 5.394984 , 6.0
# ******************
# pred, real
# 5.731617 , 6.0
# ******************
# pred, real
# 6.002691 , 5.0
# ******************
# pred, real
# 6.381772 , 6.0
# ******************
# pred, real
# 6.10773 , 6.0
# ******************
# pred, real
# 6.2930484 , 7.0
# ******************
# pred, real
# 5.7893023 , 6.0
# ******************
# pred, real
# 5.679046 , 6.0
# ******************
# pred, real
# 6.217682 , 6.0
# ******************
# pred, real
# 5.639861 , 6.0
# ******************
# pred, real
# 5.61187 , 6.0
# ******************
# pred, real
# 5.178466 , 5.0
# ******************
# pred, real
# 6.5824113 , 7.0
# ******************
# pred, real
# 6.0928273 , 7.0
# ******************
# pred, real
# 6.3140182 , 7.0
# ******************
# pred, real
# 5.446712 , 7.0
# ******************
# pred, real
# 6.3171363 , 6.0
# ******************
# pred, real
# 6.0454125 , 5.0
# ******************
# pred, real
# 6.1268873 , 6.0
# ******************
# pred, real
# 6.135215 , 7.0
# ******************
# pred, real
# 5.7443614 , 6.0
# ******************
# pred, real
# 6.324763 , 6.0
# ******************
# pred, real
# 5.6168146 , 7.0
# ******************
# pred, real
# 6.0954585 , 6.0
# ******************
# pred, real
# 5.650141 , 5.0
# ******************
# pred, real
# 5.5430155 , 7.0
# ******************
# pred, real
# 6.278778 , 6.0
# ******************
# pred, real
# 5.956364 , 6.0
# ******************
# pred, real
# 6.180635 , 5.0
# ******************
# pred, real
# 5.528577 , 6.0
# ******************
# pred, real
# 5.0769496 , 5.0
# ******************
# pred, real
# 5.74087 , 5.0
# ******************
# pred, real
# 6.892928 , 7.0
# ******************
# pred, real
# 5.415338 , 6.0
# ******************
# pred, real
# 6.02872 , 6.0
# ******************
# pred, real
# 5.5895596 , 5.0
# ******************
# pred, real
# 7.234414 , 7.0
# ******************
# pred, real
# 5.651956 , 5.0
# ******************
# pred, real
# 6.225753 , 7.0
# ******************
# pred, real
# 5.410527 , 6.0
# ******************
# pred, real
# 6.040039 , 6.0
# ******************
# pred, real
# 6.6071877 , 7.0
# ******************
# pred, real
# 6.33182 , 8.0
# ******************
# pred, real
# 6.123403 , 6.0
# ******************
# pred, real
# 5.839656 , 6.0
# ******************
# pred, real
# 6.727242 , 8.0
# ******************
# pred, real
# 4.5102673 , 5.0
# ******************
# pred, real
# 5.032016 , 6.0
# ******************
# pred, real
# 6.759013 , 7.0
# ******************
# pred, real
# 5.9012866 , 6.0
# ******************
# pred, real
# 5.646408 , 7.0
# ******************
# pred, real
# 4.9385433 , 4.0
# ******************
# pred, real
# 5.509488 , 5.0
# ******************
# pred, real
# 5.6426044 , 6.0
# ******************
# pred, real
# 6.640782 , 6.0
# ******************
# pred, real
# 5.870696 , 5.0
# ******************
# pred, real
# 6.193381 , 5.0
# ******************
# pred, real
# 5.8196263 , 6.0

# %% [markdown]
# ## Visualize test predictions

# %%
def plot_preds_vs_reals (list_preds, list_reals):
    ## 
    plt.figure (figsize = (13, 4))
    plt.plot (list_reals, label = 'real', color = 'r')
    plt.plot (list_preds, label = 'pred')
    plt.show ()

# %%
plot_preds_vs_reals (list_preds, list_reals)

# %% [markdown]
# ## Deploy Model
#
# * ONIX and GitHub
