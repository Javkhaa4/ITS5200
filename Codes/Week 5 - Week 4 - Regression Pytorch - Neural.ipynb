# %% [markdown]
# ## Libraries

# %%
## !pip install pandas
## !pip install mlxtend

# %%
import numpy as np
import torch
import pandas as pd
## pandas lib could work csv file

import sklearn
import random
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
import matplotlib.pyplot as plt

from mlxtend.plotting import heatmap
from sklearn.model_selection import train_test_split 
from torch.utils.data import TensorDataset, DataLoader

## standard metrics in regression
## coefficeint in determination
from sklearn.metrics import r2_score

# %% [markdown]
# ## Parameters

# %%
batch_size = 4
learning_rate = 0.001 ##0.001
N_Epochs = 100

epsilon = 0.001

# %% [markdown]
# ## Read data

# %%
path_data = 'data/winequality-white.csv'

WINE_raw_data = pd.read_csv (path_data, delimiter = ";")

## WINE_raw_data -d csv file iig duudaj ugj bn.

# %%
WINE_raw_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
## headers_list

headers_list = WINE_raw_data.columns.values.tolist ()
##csv file iin header deer bga medeelliig avj list helberluu shiljuulj label hiihdee ashiglahad beldej bna

headers_list
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
headers_list2 = ['density',
 'pH',
 'sulphates',
 'alcohol',
 'quality']

# %% [markdown]
# ## Data Analysis
#
# * Correlation Matrix

# %%
cm = np.corrcoef ( WINE_raw_data[headers_list].values.T  )
hm = heatmap (cm, row_names = headers_list, column_names = headers_list, figsize= (20,10))
## heatmap in doorhi turlii medeelliig haruuldag function.
## if value was 1, those values have positive correlation 
## if value was -1, those values have negative correlation
## if value was 0, there is no correlation between 2 values
## doorhi uzuulsen medeellees quality bolon alcohol 2 iin hoorondin hamaaral hamgiin undur bga gesen medeelel harj boloh n, column quality iin hamgiin undur utga avsan n 0.44 alcohol bn

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Process Data

# %%
## Convert Pandas to Numpy
## CSV filed bsan datag Pandas aar unshij avsan bsanaa Numpy ruu hurvuulj deer n ajillahad beldej bn

WINE_raw_data_np = WINE_raw_data.to_numpy()

# %%
WINE_raw_data_np
# Out:
# array([[ 7.  ,  0.27,  0.36, ...,  0.45,  8.8 ,  6.  ],
#        [ 6.3 ,  0.3 ,  0.34, ...,  0.49,  9.5 ,  6.  ],
#        [ 8.1 ,  0.28,  0.4 , ...,  0.44, 10.1 ,  6.  ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  0.46,  9.4 ,  6.  ],
#        [ 5.5 ,  0.29,  0.3 , ...,  0.38, 12.8 ,  7.  ],
#        [ 6.  ,  0.21,  0.38, ...,  0.32, 11.8 ,  6.  ]])

# %%
WINE_raw_data_np.shape
# Out:
# (4898, 12)

# %%
## indexing data

X = WINE_raw_data_np [:, :-1]
## , buh row iig avna. columns aas suuliin negiig songoj avna (slicing)

y = WINE_raw_data_np [:,11:12]

# %%
print (X.shape)
print (y.shape)
# Out:
# (4898, 11)
# (4898, 1)

# %%
random_seed = int (random.random() *100) ## 42

# %%
## split X and y

## ????????

X_train, X_test, y_train, y_test = train_test_split (X, y, test_size = 0.2, random_state = random_seed)

# %%
print (X_train.shape)
print (X_test.shape)
print (y_train.shape)
print (y_test.shape)
# Out:
# (3918, 11)
# (980, 11)
# (3918, 1)
# (980, 1)

# %% [markdown]
# ## Fix in case float64 error

# %%
y_test.dtype ## sometimes torch gives you problem because of data had different data type
# Out:
# dtype('float64')

# %%
## fix data type

X_train = X_train.astype (np.float32)
X_test = X_test.astype (np.float32)
y_train = y_train.astype (np.float32)
y_test = y_test.astype (np.float32)

# %%
X_train.dtype
X_test.dtype
y_train.dtype
y_test.dtype
# Out:
# dtype('float32')

# %%
## convert data to torch from Numpy

X_train_tr = torch.from_numpy (X_train)
X_test_tr  = torch.from_numpy (X_test)
y_train_tr = torch.from_numpy (y_train)
y_test_tr  = torch.from_numpy (y_test)

# %% [markdown]
# ## Normalization
#
# * Normalization
# * Standardization (*)

# %%
## X_scaled = (X - x_means)/X_standard_dev

x_means      = X_train_tr.mean (0, keepdim = True )
x_deviations = X_train_tr.std (0, keepdim = True ) + epsilon

# %%
x_means
# Out:
# tensor([[6.8546e+00, 2.7777e-01, 3.3423e-01, 6.4098e+00, 4.5718e-02, 3.5254e+01,
#          1.3851e+02, 9.9403e-01, 3.1864e+00, 4.9020e-01, 1.0512e+01]])

# %%
x_deviations
# Out:
# tensor([[8.5051e-01, 1.0119e-01, 1.2253e-01, 5.0376e+00, 2.2592e-02, 1.7166e+01,
#          4.2925e+01, 3.9249e-03, 1.5188e-01, 1.1493e-01, 1.2322e+00]])

# %% [markdown]
# ## Create the DataLoader

# %%
train_ds = TensorDataset ( X_train_tr, y_train_tr )

# %%
train_dl = DataLoader (train_ds, batch_size , shuffle=True )

## surgah ugugdluu shuffle hiij holij surgahdaa dahin ashiglana.

# %%
train_dl

# %% [markdown]
# ## Neural Network Architectures

# %%
## input = 11, hidden layer = 8 , output = 1
## Linear Regression

class MLP_Net (nn.Module):
    ## nn class is neural network class
    ## init the class
    def __init__(self, x_means, x_deviations):
        super().__init__()
        
        self.x_means      = x_means       
        self.x_deviations = x_deviations
        
        self.linear1 = nn.Linear (11,128)
        self.act1    = nn.Sigmoid ()
        self.linear2 = nn.Linear (128, 1)
       ## self.dropout = nn.Dropout (0,25)
        
    ## perform inference
    def forward (self, x):
        
        x = (x - self.x_means)/ self.x_deviations ## standardarzation
        
        x = self.linear1 (x)
        x = self.act1 (x)
       ## x = self.dropout (x)
        y_pred= self.linear2 (x)
        
        ## return torch.round (y_pred)
        return y_pred

# %% [markdown]
# ## Training Loop

# %%
def training_loop (N_Epochs, model, loss_fn, opt):
    
    for epoch in range (N_Epochs):
        for xb, yb in train_dl:
            
            y_pred = model (xb)
            loss = loss_fn (y_pred, yb)
            
            opt.zero_grad ()
            loss.backward ()
            opt.step ()
        if epoch % 20 == 0:
            print (epoch, "loss=", loss)

# %%
## model = LinRegNet ( x_means, x_deviations )
model = MLP_Net ( x_means, x_deviations )

opt = torch.optim.Adam ( model.parameters(), lr =learning_rate )
## optimazation - gradient descent

loss_fn = F.mse_loss 
## belen loss function iig duudaj bn. MSE

training_loop (N_Epochs, model, loss_fn, opt)
# Out:
# 0 loss= tensor(1.4484, grad_fn=<MseLossBackward0>)
# 20 loss= tensor(0.2043, grad_fn=<MseLossBackward0>)
# 40 loss= tensor(0.1095, grad_fn=<MseLossBackward0>)
# 60 loss= tensor(0.6732, grad_fn=<MseLossBackward0>)
# 80 loss= tensor(0.9384, grad_fn=<MseLossBackward0>)

# %% [markdown]
# ## Evaluate Model

# %%
y_pred_test = model ( X_test_tr )

# %%
y_pred_test.shape
# Out:
# torch.Size([980, 1])

# %%
## r2_score is predicted x

## y_pred_test

# %%
print ( "Testing R**2: ", r2_score ( y_test_tr.numpy(), y_pred_test.detach().numpy() ) )

## range 0 - 1, best is 1
# Out:
# Testing R**2:  0.38265418950058394

# %%
y_pred_test.shape
# Out:
# torch.Size([980, 1])

# %%
y_test_tr.shape
# Out:
# torch.Size([980, 1])

# %%
len(X_test_tr)
# Out:
# 980

# %%
list_preds = []
list_reals = []

for i in range (len(X_test_tr)):
    print ("******************")
    print ("pred, real")
    np_real =   y_test_tr[i].detach().numpy()
    np_pred = y_pred_test[i].detach().numpy()
    print (np_pred[0],",", np_real[0])
    list_preds.append (  np_pred[0] )
    list_reals.append (  np_real[0] )
# Out:
# ******************
# pred, real
# 6.1713996 , 6.0
# ******************
# pred, real
# 4.5872273 , 5.0
# ******************
# pred, real
# 5.4791455 , 6.0
# ******************
# pred, real
# 6.7941947 , 7.0
# ******************
# pred, real
# 7.21335 , 6.0
# ******************
# pred, real
# 5.9283323 , 6.0
# ******************
# pred, real
# 5.476708 , 6.0
# ******************
# pred, real
# 6.0364203 , 6.0
# ******************
# pred, real
# 5.2176137 , 6.0
# ******************
# pred, real
# 5.8833675 , 5.0
# ******************
# pred, real
# 6.114595 , 7.0
# ******************
# pred, real
# 5.435776 , 6.0
# ******************
# pred, real
# 5.882471 , 6.0
# ******************
# pred, real
# 6.7732487 , 6.0
# ******************
# pred, real
# 6.035133 , 6.0
# ******************
# pred, real
# 5.3407435 , 5.0
# ******************
# pred, real
# 6.0922246 , 6.0
# ******************
# pred, real
# 5.815622 , 5.0
# ******************
# pred, real
# 5.4333334 , 5.0
# ******************
# pred, real
# 5.320097 , 6.0
# ******************
# pred, real
# 5.6219735 , 6.0
# ******************
# pred, real
# 6.332905 , 8.0
# ******************
# pred, real
# 6.4931564 , 6.0
# ******************
# pred, real
# 6.5166683 , 8.0
# ******************
# pred, real
# 5.9996724 , 6.0
# ******************
# pred, real
# 6.1801496 , 7.0
# ******************
# pred, real
# 6.4922614 , 5.0
# ******************
# pred, real
# 6.4594016 , 6.0
# ******************
# pred, real
# 5.82941 , 6.0
# ******************
# pred, real
# 6.1748357 , 6.0
# ******************
# pred, real
# 5.5224814 , 5.0
# ******************
# pred, real
# 5.9470415 , 5.0
# ******************
# pred, real
# 6.0310626 , 7.0
# ******************
# pred, real
# 6.27718 , 6.0
# ******************
# pred, real
# 5.575471 , 8.0
# ******************
# pred, real
# 6.7463527 , 6.0
# ******************
# pred, real
# 6.607322 , 7.0
# ******************
# pred, real
# 5.643583 , 5.0
# ******************
# pred, real
# 5.067077 , 5.0
# ******************
# pred, real
# 5.5020027 , 5.0
# ******************
# pred, real
# 7.0614676 , 8.0
# ******************
# pred, real
# 6.019618 , 6.0
# ******************
# pred, real
# 5.4496584 , 5.0
# ******************
# pred, real
# 6.081942 , 7.0
# ******************
# pred, real
# 6.5042496 , 6.0
# ******************
# pred, real
# 5.520576 , 5.0
# ******************
# pred, real
# 5.3615327 , 6.0
# ******************
# pred, real
# 5.797381 , 7.0
# ******************
# pred, real
# 6.6629996 , 7.0
# ******************
# pred, real
# 5.383451 , 4.0
# ******************
# pred, real
# 5.1483665 , 6.0
# ******************
# pred, real
# 6.906618 , 6.0
# ******************
# pred, real
# 6.6534066 , 8.0
# ******************
# pred, real
# 5.434564 , 6.0
# ******************
# pred, real
# 6.244286 , 6.0
# ******************
# pred, real
# 6.1755414 , 6.0
# ******************
# pred, real
# 5.274398 , 5.0
# ******************
# pred, real
# 6.6885366 , 6.0
# ******************
# pred, real
# 5.7893934 , 6.0
# ******************
# pred, real
# 4.79754 , 5.0
# ******************
# pred, real
# 6.0921984 , 6.0
# ******************
# pred, real
# 6.473013 , 6.0
# ******************
# pred, real
# 5.7291236 , 5.0
# ******************
# pred, real
# 6.0963807 , 6.0
# ******************
# pred, real
# 5.593514 , 6.0
# ******************
# pred, real
# 5.329618 , 5.0
# ******************
# pred, real
# 5.1264954 , 6.0
# ******************
# pred, real
# 6.0701075 , 6.0
# ******************
# pred, real
# 4.459584 , 5.0
# ******************
# pred, real
# 5.811858 , 6.0
# ******************
# pred, real
# 6.109508 , 6.0
# ******************
# pred, real
# 5.6619687 , 6.0
# ******************
# pred, real
# 5.024587 , 5.0
# ******************
# pred, real
# 4.867453 , 5.0
# ******************
# pred, real
# 6.906618 , 6.0
# ******************
# pred, real
# 5.6000366 , 6.0
# ******************
# pred, real
# 6.136848 , 5.0
# ******************
# pred, real
# 6.005585 , 3.0
# ******************
# pred, real
# 5.1618867 , 5.0
# ******************
# pred, real
# 5.7453713 , 5.0
# ******************
# pred, real
# 5.329618 , 5.0
# ******************
# pred, real
# 6.580757 , 7.0
# ******************
# pred, real
# 5.125113 , 5.0
# ******************
# pred, real
# 5.663836 , 5.0
# ******************
# pred, real
# 6.7172437 , 6.0
# ******************
# pred, real
# 6.7181373 , 8.0
# ******************
# pred, real
# 5.405514 , 5.0
# ******************
# pred, real
# 5.9085193 , 6.0
# ******************
# pred, real
# 5.567428 , 5.0
# ******************
# pred, real
# 6.6244645 , 7.0
# ******************
# pred, real
# 5.208976 , 5.0
# ******************
# pred, real
# 5.518128 , 5.0
# ******************
# pred, real
# 6.9718 , 7.0
# ******************
# pred, real
# 5.9628806 , 6.0
# ******************
# pred, real
# 5.3427806 , 6.0
# ******************
# pred, real
# 6.0873785 , 6.0
# ******************
# pred, real
# 6.261083 , 7.0
# ******************
# pred, real
# 6.666134 , 6.0
# ******************
# pred, real
# 5.814738 , 7.0
# ******************
# pred, real
# 5.9328904 , 5.0
# ******************
# pred, real
# 5.871852 , 6.0
# ******************
# pred, real
# 6.46922 , 7.0
# ******************
# pred, real
# 5.567621 , 6.0
# ******************
# pred, real
# 5.4252076 , 5.0
# ******************
# pred, real
# 5.2642164 , 5.0
# ******************
# pred, real
# 5.501394 , 6.0
# ******************
# pred, real
# 6.5490355 , 8.0
# ******************
# pred, real
# 5.2158885 , 4.0
# ******************
# pred, real
# 5.5462923 , 5.0
# ******************
# pred, real
# 5.6415954 , 6.0
# ******************
# pred, real
# 5.2723985 , 6.0
# ******************
# pred, real
# 5.29805 , 5.0
# ******************
# pred, real
# 6.074561 , 6.0
# ******************
# pred, real
# 6.3451138 , 6.0
# ******************
# pred, real
# 5.595504 , 6.0
# ******************
# pred, real
# 5.4137664 , 4.0
# ******************
# pred, real
# 5.7464614 , 5.0
# ******************
# pred, real
# 5.323673 , 5.0
# ******************
# pred, real
# 6.3005385 , 7.0
# ******************
# pred, real
# 6.0076933 , 6.0
# ******************
# pred, real
# 6.526247 , 6.0
# ******************
# pred, real
# 7.321791 , 6.0
# ******************
# pred, real
# 5.502129 , 5.0
# ******************
# pred, real
# 6.4349384 , 6.0
# ******************
# pred, real
# 5.7801614 , 6.0
# ******************
# pred, real
# 6.2852273 , 8.0
# ******************
# pred, real
# 5.4910507 , 5.0
# ******************
# pred, real
# 5.6655326 , 6.0
# ******************
# pred, real
# 5.95649 , 6.0
# ******************
# pred, real
# 6.2578387 , 6.0
# ******************
# pred, real
# 5.2606473 , 4.0
# ******************
# pred, real
# 5.9788127 , 5.0
# ******************
# pred, real
# 5.9814925 , 6.0
# ******************
# pred, real
# 6.4596486 , 5.0
# ******************
# pred, real
# 6.3093123 , 6.0
# ******************
# pred, real
# 5.619308 , 6.0
# ******************
# pred, real
# 6.202435 , 6.0
# ******************
# pred, real
# 6.7623787 , 7.0
# ******************
# pred, real
# 5.160927 , 5.0
# ******************
# pred, real
# 7.041308 , 7.0
# ******************
# pred, real
# 6.083934 , 5.0
# ******************
# pred, real
# 5.904287 , 7.0
# ******************
# pred, real
# 4.9584947 , 5.0
# ******************
# pred, real
# 5.539702 , 6.0
# ******************
# pred, real
# 6.8589096 , 6.0
# ******************
# pred, real
# 6.8412514 , 7.0
# ******************
# pred, real
# 5.385733 , 6.0
# ******************
# pred, real
# 6.941658 , 7.0
# ******************
# pred, real
# 5.244239 , 5.0
# ******************
# pred, real
# 6.716617 , 6.0
# ******************
# pred, real
# 6.23309 , 7.0
# ******************
# pred, real
# 5.5245404 , 5.0
# ******************
# pred, real
# 4.716764 , 5.0
# ******************
# pred, real
# 5.2123976 , 5.0
# ******************
# pred, real
# 6.4865522 , 6.0
# ******************
# pred, real
# 6.3428874 , 7.0
# ******************
# pred, real
# 6.308182 , 7.0
# ******************
# pred, real
# 6.1134324 , 7.0
# ******************
# pred, real
# 6.7986026 , 5.0
# ******************
# pred, real
# 6.1596656 , 6.0
# ******************
# pred, real
# 5.8557 , 6.0
# ******************
# pred, real
# 6.4247727 , 7.0
# ******************
# pred, real
# 6.397464 , 6.0
# ******************
# pred, real
# 5.9617405 , 6.0
# ******************
# pred, real
# 6.101683 , 7.0
# ******************
# pred, real
# 4.8562236 , 3.0
# ******************
# pred, real
# 6.479709 , 6.0
# ******************
# pred, real
# 6.675705 , 6.0
# ******************
# pred, real
# 5.230263 , 6.0
# ******************
# pred, real
# 6.397831 , 6.0
# ******************
# pred, real
# 6.659814 , 6.0
# ******************
# pred, real
# 5.612318 , 6.0
# ******************
# pred, real
# 5.845871 , 6.0
# ******************
# pred, real
# 7.0958667 , 8.0
# ******************
# pred, real
# 5.7419877 , 7.0
# ******************
# pred, real
# 5.571608 , 6.0
# ******************
# pred, real
# 5.942136 , 6.0
# ******************
# pred, real
# 6.4084496 , 6.0
# ******************
# pred, real
# 5.513778 , 6.0
# ******************
# pred, real
# 5.1177087 , 5.0
# ******************
# pred, real
# 5.2463007 , 5.0
# ******************
# pred, real
# 5.719724 , 7.0
# ******************
# pred, real
# 4.9909515 , 5.0
# ******************
# pred, real
# 5.5277066 , 5.0
# ******************
# pred, real
# 6.3567696 , 7.0
# ******************
# pred, real
# 5.3294883 , 6.0
# ******************
# pred, real
# 5.915769 , 6.0
# ******************
# pred, real
# 6.694163 , 7.0
# ******************
# pred, real
# 5.0725336 , 5.0
# ******************
# pred, real
# 5.486301 , 6.0
# ******************
# pred, real
# 7.2950296 , 7.0
# ******************
# pred, real
# 5.1464934 , 5.0
# ******************
# pred, real
# 5.468435 , 5.0
# ******************
# pred, real
# 5.725745 , 6.0
# ******************
# pred, real
# 5.4431434 , 5.0
# ******************
# pred, real
# 5.867768 , 6.0
# ******************
# pred, real
# 7.086466 , 6.0
# ******************
# pred, real
# 5.7586484 , 6.0
# ******************
# pred, real
# 6.7641087 , 8.0
# ******************
# pred, real
# 5.6526875 , 3.0
# ******************
# pred, real
# 5.7668495 , 6.0
# ******************
# pred, real
# 5.274398 , 5.0
# ******************
# pred, real
# 5.261524 , 4.0
# ******************
# pred, real
# 5.481978 , 5.0
# ******************
# pred, real
# 6.8725133 , 7.0
# ******************
# pred, real
# 5.589833 , 6.0
# ******************
# pred, real
# 5.5249815 , 5.0
# ******************
# pred, real
# 6.5086226 , 6.0
# ******************
# pred, real
# 5.210886 , 5.0
# ******************
# pred, real
# 6.521537 , 6.0
# ******************
# pred, real
# 5.7716923 , 6.0
# ******************
# pred, real
# 5.5284758 , 7.0
# ******************
# pred, real
# 5.845235 , 5.0
# ******************
# pred, real
# 6.2216887 , 6.0
# ******************
# pred, real
# 5.307467 , 5.0
# ******************
# pred, real
# 5.252197 , 5.0
# ******************
# pred, real
# 5.7099485 , 5.0
# ******************
# pred, real
# 6.1649127 , 6.0
# ******************
# pred, real
# 6.1029277 , 5.0
# ******************
# pred, real
# 5.349475 , 5.0
# ******************
# pred, real
# 5.8547645 , 7.0
# ******************
# pred, real
# 5.899409 , 7.0
# ******************
# pred, real
# 6.284133 , 6.0
# ******************
# pred, real
# 5.5672474 , 4.0
# ******************
# pred, real
# 5.1582294 , 6.0
# ******************
# pred, real
# 6.44161 , 6.0
# ******************
# pred, real
# 6.012193 , 6.0
# ******************
# pred, real
# 5.128801 , 5.0
# ******************
# pred, real
# 6.5517473 , 7.0
# ******************
# pred, real
# 7.1821685 , 7.0
# ******************
# pred, real
# 7.087468 , 8.0
# ******************
# pred, real
# 6.6946225 , 7.0
# ******************
# pred, real
# 5.743997 , 5.0
# ******************
# pred, real
# 6.899859 , 8.0
# ******************
# pred, real
# 5.851395 , 5.0
# ******************
# pred, real
# 5.199343 , 6.0
# ******************
# pred, real
# 5.7588587 , 6.0
# ******************
# pred, real
# 5.8253407 , 6.0
# ******************
# pred, real
# 5.4359956 , 6.0
# ******************
# pred, real
# 5.236036 , 5.0
# ******************
# pred, real
# 5.156591 , 5.0
# ******************
# pred, real
# 5.273399 , 5.0
# ******************
# pred, real
# 5.719358 , 5.0
# ******************
# pred, real
# 4.3909583 , 5.0
# ******************
# pred, real
# 6.5432696 , 8.0
# ******************
# pred, real
# 5.7072983 , 6.0
# ******************
# pred, real
# 6.7218275 , 6.0
# ******************
# pred, real
# 6.1016397 , 6.0
# ******************
# pred, real
# 5.688095 , 6.0
# ******************
# pred, real
# 5.5306277 , 7.0
# ******************
# pred, real
# 6.2108397 , 6.0
# ******************
# pred, real
# 5.912949 , 6.0
# ******************
# pred, real
# 5.037043 , 5.0
# ******************
# pred, real
# 7.0242796 , 7.0
# ******************
# pred, real
# 5.4272084 , 5.0
# ******************
# pred, real
# 6.121099 , 7.0
# ******************
# pred, real
# 5.500007 , 5.0
# ******************
# pred, real
# 5.259212 , 5.0
# ******************
# pred, real
# 6.1485214 , 5.0
# ******************
# pred, real
# 5.822514 , 6.0
# ******************
# pred, real
# 5.495212 , 6.0
# ******************
# pred, real
# 5.9500885 , 6.0
# ******************
# pred, real
# 5.577619 , 5.0
# ******************
# pred, real
# 5.4508214 , 5.0
# ******************
# pred, real
# 6.84603 , 7.0
# ******************
# pred, real
# 5.8962684 , 8.0
# ******************
# pred, real
# 6.642316 , 7.0
# ******************
# pred, real
# 5.859411 , 5.0
# ******************
# pred, real
# 4.9216313 , 5.0
# ******************
# pred, real
# 6.2784805 , 6.0
# ******************
# pred, real
# 5.558105 , 7.0
# ******************
# pred, real
# 5.635541 , 5.0
# ******************
# pred, real
# 5.533501 , 5.0
# ******************
# pred, real
# 5.037378 , 4.0
# ******************
# pred, real
# 5.9305596 , 6.0
# ******************
# pred, real
# 5.0643964 , 5.0
# ******************
# pred, real
# 6.0127177 , 6.0
# ******************
# pred, real
# 7.1247745 , 7.0
# ******************
# pred, real
# 6.890618 , 7.0
# ******************
# pred, real
# 5.652122 , 5.0
# ******************
# pred, real
# 6.6161203 , 8.0
# ******************
# pred, real
# 6.166425 , 6.0
# ******************
# pred, real
# 5.597428 , 5.0
# ******************
# pred, real
# 6.4001327 , 6.0
# ******************
# pred, real
# 6.448826 , 7.0
# ******************
# pred, real
# 6.07816 , 6.0
# ******************
# pred, real
# 5.363323 , 5.0
# ******************
# pred, real
# 6.2257237 , 7.0
# ******************
# pred, real
# 5.818636 , 5.0
# ******************
# pred, real
# 5.7124844 , 7.0
# ******************
# pred, real
# 5.6002426 , 5.0
# ******************
# pred, real
# 6.5758266 , 7.0
# ******************
# pred, real
# 4.716351 , 5.0
# ******************
# pred, real
# 5.094752 , 5.0
# ******************
# pred, real
# 5.625464 , 6.0
# ******************
# pred, real
# 6.4931564 , 6.0
# ******************
# pred, real
# 5.512734 , 5.0
# ******************
# pred, real
# 6.339846 , 7.0
# ******************
# pred, real
# 5.1019115 , 5.0
# ******************
# pred, real
# 6.318797 , 6.0
# ******************
# pred, real
# 6.7185864 , 6.0
# ******************
# pred, real
# 6.518703 , 7.0
# ******************
# pred, real
# 6.31991 , 6.0
# ******************
# pred, real
# 5.987909 , 5.0
# ******************
# pred, real
# 5.567578 , 5.0
# ******************
# pred, real
# 6.1788797 , 7.0
# ******************
# pred, real
# 6.209281 , 6.0
# ******************
# pred, real
# 5.3393407 , 5.0
# ******************
# pred, real
# 7.1594477 , 6.0
# ******************
# pred, real
# 6.4175544 , 6.0
# ******************
# pred, real
# 6.867134 , 7.0
# ******************
# pred, real
# 5.2939625 , 5.0
# ******************
# pred, real
# 6.0260944 , 7.0
# ******************
# pred, real
# 5.6598887 , 5.0
# ******************
# pred, real
# 6.712007 , 6.0
# ******************
# pred, real
# 5.1434464 , 5.0
# ******************
# pred, real
# 6.2160788 , 5.0
# ******************
# pred, real
# 6.1055293 , 6.0
# ******************
# pred, real
# 5.6310067 , 6.0
# ******************
# pred, real
# 6.732649 , 7.0
# ******************
# pred, real
# 6.4931564 , 6.0
# ******************
# pred, real
# 5.911138 , 6.0
# ******************
# pred, real
# 5.856851 , 6.0
# ******************
# pred, real
# 6.113751 , 6.0
# ******************
# pred, real
# 6.0573554 , 6.0
# ******************
# pred, real
# 6.445552 , 6.0
# ******************
# pred, real
# 5.387965 , 5.0
# ******************
# pred, real
# 5.9033294 , 5.0
# ******************
# pred, real
# 6.2553196 , 6.0
# ******************
# pred, real
# 5.8442802 , 6.0
# ******************
# pred, real
# 6.1755414 , 6.0
# ******************
# pred, real
# 6.5526457 , 7.0
# ******************
# pred, real
# 6.5383325 , 6.0
# ******************
# pred, real
# 5.516437 , 5.0
# ******************
# pred, real
# 5.8380694 , 6.0
# ******************
# pred, real
# 5.616461 , 5.0
# ******************
# pred, real
# 5.1028166 , 6.0
# ******************
# pred, real
# 6.38228 , 5.0
# ******************
# pred, real
# 4.815412 , 5.0
# ******************
# pred, real
# 6.5389447 , 6.0
# ******************
# pred, real
# 6.58019 , 6.0
# ******************
# pred, real
# 5.567621 , 6.0
# ******************
# pred, real
# 6.1687646 , 6.0
# ******************
# pred, real
# 5.2835274 , 5.0
# ******************
# pred, real
# 6.717344 , 6.0
# ******************
# pred, real
# 5.5071783 , 5.0
# ******************
# pred, real
# 5.6212034 , 5.0
# ******************
# pred, real
# 5.9532266 , 6.0
# ******************
# pred, real
# 5.829656 , 6.0
# ******************
# pred, real
# 5.715594 , 6.0
# ******************
# pred, real
# 6.2301974 , 6.0
# ******************
# pred, real
# 5.901691 , 6.0
# ******************
# pred, real
# 6.0260944 , 7.0
# ******************
# pred, real
# 6.8645945 , 7.0
# ******************
# pred, real
# 5.110535 , 5.0
# ******************
# pred, real
# 5.8421965 , 5.0
# ******************
# pred, real
# 5.464483 , 5.0
# ******************
# pred, real
# 6.299007 , 5.0
# ******************
# pred, real
# 6.0390506 , 6.0
# ******************
# pred, real
# 6.82225 , 7.0
# ******************
# pred, real
# 6.9063115 , 7.0
# ******************
# pred, real
# 6.591249 , 6.0
# ******************
# pred, real
# 7.0872025 , 8.0
# ******************
# pred, real
# 6.7316203 , 6.0
# ******************
# pred, real
# 6.1960354 , 6.0
# ******************
# pred, real
# 5.8025155 , 6.0
# ******************
# pred, real
# 6.5308433 , 7.0
# ******************
# pred, real
# 6.7899585 , 7.0
# ******************
# pred, real
# 7.086466 , 6.0
# ******************
# pred, real
# 5.360792 , 4.0
# ******************
# pred, real
# 5.87837 , 5.0
# ******************
# pred, real
# 5.266749 , 5.0
# ******************
# pred, real
# 5.524115 , 5.0
# ******************
# pred, real
# 5.765127 , 6.0
# ******************
# pred, real
# 6.630852 , 7.0
# ******************
# pred, real
# 5.0552354 , 5.0
# ******************
# pred, real
# 5.25338 , 5.0
# ******************
# pred, real
# 6.2986064 , 6.0
# ******************
# pred, real
# 6.172479 , 6.0
# ******************
# pred, real
# 5.8421965 , 5.0
# ******************
# pred, real
# 5.7299557 , 6.0
# ******************
# pred, real
# 6.26512 , 5.0
# ******************
# pred, real
# 6.1395187 , 7.0
# ******************
# pred, real
# 5.807214 , 6.0
# ******************
# pred, real
# 7.1955056 , 8.0
# ******************
# pred, real
# 6.5281277 , 5.0
# ******************
# pred, real
# 4.451067 , 5.0
# ******************
# pred, real
# 5.9291654 , 7.0
# ******************
# pred, real
# 7.076082 , 7.0
# ******************
# pred, real
# 5.4299746 , 6.0
# ******************
# pred, real
# 6.11765 , 6.0
# ******************
# pred, real
# 5.3541427 , 6.0
# ******************
# pred, real
# 5.1713586 , 6.0
# ******************
# pred, real
# 5.2309027 , 5.0
# ******************
# pred, real
# 5.439862 , 6.0
# ******************
# pred, real
# 6.3022985 , 6.0
# ******************
# pred, real
# 5.9611907 , 5.0
# ******************
# pred, real
# 5.260576 , 6.0
# ******************
# pred, real
# 5.391093 , 5.0
# ******************
# pred, real
# 6.303593 , 4.0
# ******************
# pred, real
# 7.1280694 , 7.0
# ******************
# pred, real
# 6.0649805 , 8.0
# ******************
# pred, real
# 5.3624997 , 6.0
# ******************
# pred, real
# 5.3541164 , 5.0
# ******************
# pred, real
# 5.682112 , 5.0
# ******************
# pred, real
# 5.886222 , 6.0
# ******************
# pred, real
# 6.357217 , 5.0
# ******************
# pred, real
# 6.429169 , 8.0
# ******************
# pred, real
# 6.5294547 , 8.0
# ******************
# pred, real
# 4.9964886 , 4.0
# ******************
# pred, real
# 6.203518 , 6.0
# ******************
# pred, real
# 6.318797 , 6.0
# ******************
# pred, real
# 5.9483333 , 6.0
# ******************
# pred, real
# 5.2986045 , 6.0
# ******************
# pred, real
# 5.787317 , 5.0
# ******************
# pred, real
# 5.8493643 , 6.0
# ******************
# pred, real
# 5.8410296 , 6.0
# ******************
# pred, real
# 5.6657023 , 6.0
# ******************
# pred, real
# 6.880892 , 8.0
# ******************
# pred, real
# 5.735922 , 5.0
# ******************
# pred, real
# 5.611487 , 5.0
# ******************
# pred, real
# 6.028008 , 6.0
# ******************
# pred, real
# 5.4965014 , 6.0
# ******************
# pred, real
# 6.1009116 , 5.0
# ******************
# pred, real
# 5.6511903 , 5.0
# ******************
# pred, real
# 6.2769327 , 7.0
# ******************
# pred, real
# 5.1046844 , 6.0
# ******************
# pred, real
# 6.7961884 , 7.0
# ******************
# pred, real
# 5.0555453 , 6.0
# ******************
# pred, real
# 5.223988 , 5.0
# ******************
# pred, real
# 6.313523 , 6.0
# ******************
# pred, real
# 6.5106287 , 6.0
# ******************
# pred, real
# 5.2302327 , 5.0
# ******************
# pred, real
# 5.636364 , 5.0
# ******************
# pred, real
# 6.322792 , 6.0
# ******************
# pred, real
# 6.2744226 , 6.0
# ******************
# pred, real
# 5.5672016 , 5.0
# ******************
# pred, real
# 5.442081 , 5.0
# ******************
# pred, real
# 6.7991586 , 6.0
# ******************
# pred, real
# 6.5066066 , 7.0
# ******************
# pred, real
# 6.1937966 , 6.0
# ******************
# pred, real
# 5.3872924 , 5.0
# ******************
# pred, real
# 5.9265637 , 7.0
# ******************
# pred, real
# 6.086779 , 6.0
# ******************
# pred, real
# 6.2399764 , 7.0
# ******************
# pred, real
# 5.617679 , 5.0
# ******************
# pred, real
# 5.431133 , 8.0
# ******************
# pred, real
# 6.648707 , 6.0
# ******************
# pred, real
# 5.84005 , 6.0
# ******************
# pred, real
# 5.683307 , 6.0
# ******************
# pred, real
# 6.514544 , 8.0
# ******************
# pred, real
# 5.304276 , 6.0
# ******************
# pred, real
# 5.501394 , 6.0
# ******************
# pred, real
# 6.7189107 , 6.0
# ******************
# pred, real
# 5.457769 , 6.0
# ******************
# pred, real
# 6.0383487 , 7.0
# ******************
# pred, real
# 6.3965793 , 7.0
# ******************
# pred, real
# 5.4386873 , 5.0
# ******************
# pred, real
# 6.9686675 , 7.0
# ******************
# pred, real
# 5.8951826 , 6.0
# ******************
# pred, real
# 6.1330657 , 5.0
# ******************
# pred, real
# 6.183707 , 7.0
# ******************
# pred, real
# 5.16114 , 5.0
# ******************
# pred, real
# 5.461288 , 5.0
# ******************
# pred, real
# 5.8247614 , 5.0
# ******************
# pred, real
# 5.6371117 , 6.0
# ******************
# pred, real
# 5.020144 , 5.0
# ******************
# pred, real
# 6.786343 , 8.0
# ******************
# pred, real
# 6.452629 , 5.0
# ******************
# pred, real
# 6.520739 , 7.0
# ******************
# pred, real
# 4.98524 , 5.0
# ******************
# pred, real
# 5.962607 , 6.0
# ******************
# pred, real
# 7.0093017 , 7.0
# ******************
# pred, real
# 5.4595857 , 5.0
# ******************
# pred, real
# 6.211018 , 6.0
# ******************
# pred, real
# 6.287269 , 6.0
# ******************
# pred, real
# 7.0823317 , 6.0
# ******************
# pred, real
# 6.655894 , 7.0
# ******************
# pred, real
# 5.9650483 , 6.0
# ******************
# pred, real
# 6.7043242 , 7.0
# ******************
# pred, real
# 6.625488 , 5.0
# ******************
# pred, real
# 6.0977254 , 6.0
# ******************
# pred, real
# 5.919066 , 6.0
# ******************
# pred, real
# 6.1687646 , 6.0
# ******************
# pred, real
# 5.8814006 , 7.0
# ******************
# pred, real
# 6.0453115 , 4.0
# ******************
# pred, real
# 6.182547 , 6.0
# ******************
# pred, real
# 6.591759 , 6.0
# ******************
# pred, real
# 6.6844 , 7.0
# ******************
# pred, real
# 6.4024415 , 4.0
# ******************
# pred, real
# 5.279784 , 6.0
# ******************
# pred, real
# 6.651792 , 6.0
# ******************
# pred, real
# 6.357217 , 5.0
# ******************
# pred, real
# 5.694392 , 5.0
# ******************
# pred, real
# 5.6986756 , 5.0
# ******************
# pred, real
# 6.0497813 , 6.0
# ******************
# pred, real
# 4.994628 , 5.0
# ******************
# pred, real
# 5.7956414 , 6.0
# ******************
# pred, real
# 6.475936 , 6.0
# ******************
# pred, real
# 5.910438 , 6.0
# ******************
# pred, real
# 5.737944 , 5.0
# ******************
# pred, real
# 5.7582192 , 6.0
# ******************
# pred, real
# 5.3112574 , 5.0
# ******************
# pred, real
# 6.897495 , 7.0
# ******************
# pred, real
# 5.789412 , 6.0
# ******************
# pred, real
# 6.2936153 , 7.0
# ******************
# pred, real
# 6.694163 , 7.0
# ******************
# pred, real
# 4.922683 , 6.0
# ******************
# pred, real
# 6.1635623 , 7.0
# ******************
# pred, real
# 7.1443458 , 7.0
# ******************
# pred, real
# 6.3537173 , 6.0
# ******************
# pred, real
# 5.593786 , 6.0
# ******************
# pred, real
# 5.7972856 , 5.0
# ******************
# pred, real
# 5.2370152 , 5.0
# ******************
# pred, real
# 6.9812536 , 6.0
# ******************
# pred, real
# 5.5013814 , 5.0
# ******************
# pred, real
# 5.457312 , 5.0
# ******************
# pred, real
# 5.502129 , 5.0
# ******************
# pred, real
# 5.190511 , 4.0
# ******************
# pred, real
# 5.7552686 , 5.0
# ******************
# pred, real
# 6.7623787 , 7.0
# ******************
# pred, real
# 6.8515844 , 7.0
# ******************
# pred, real
# 5.979161 , 6.0
# ******************
# pred, real
# 5.4835997 , 5.0
# ******************
# pred, real
# 5.4298835 , 5.0
# ******************
# pred, real
# 5.466617 , 5.0
# ******************
# pred, real
# 6.7807064 , 6.0
# ******************
# pred, real
# 6.3108873 , 6.0
# ******************
# pred, real
# 7.0319858 , 6.0
# ******************
# pred, real
# 5.5421195 , 6.0
# ******************
# pred, real
# 4.974097 , 5.0
# ******************
# pred, real
# 6.904641 , 7.0
# ******************
# pred, real
# 6.4802666 , 7.0
# ******************
# pred, real
# 5.407452 , 6.0
# ******************
# pred, real
# 6.9822664 , 7.0
# ******************
# pred, real
# 5.901954 , 6.0
# ******************
# pred, real
# 6.2263865 , 7.0
# ******************
# pred, real
# 5.926324 , 6.0
# ******************
# pred, real
# 6.6550326 , 7.0
# ******************
# pred, real
# 5.1418667 , 5.0
# ******************
# pred, real
# 6.0383487 , 7.0
# ******************
# pred, real
# 5.9066787 , 5.0
# ******************
# pred, real
# 5.578462 , 5.0
# ******************
# pred, real
# 5.6038933 , 6.0
# ******************
# pred, real
# 7.1800237 , 8.0
# ******************
# pred, real
# 5.058475 , 5.0
# ******************
# pred, real
# 5.7335 , 6.0
# ******************
# pred, real
# 6.447707 , 6.0
# ******************
# pred, real
# 5.682037 , 5.0
# ******************
# pred, real
# 5.5654683 , 5.0
# ******************
# pred, real
# 5.8788056 , 6.0
# ******************
# pred, real
# 6.200262 , 6.0
# ******************
# pred, real
# 7.3944454 , 7.0
# ******************
# pred, real
# 6.6846175 , 7.0
# ******************
# pred, real
# 5.5464144 , 5.0
# ******************
# pred, real
# 5.6194205 , 6.0
# ******************
# pred, real
# 6.319679 , 7.0
# ******************
# pred, real
# 6.659337 , 7.0
# ******************
# pred, real
# 5.7714086 , 5.0
# ******************
# pred, real
# 6.3671136 , 6.0
# ******************
# pred, real
# 6.107468 , 6.0
# ******************
# pred, real
# 6.3769507 , 7.0
# ******************
# pred, real
# 4.8268867 , 4.0
# ******************
# pred, real
# 6.771073 , 7.0
# ******************
# pred, real
# 5.815622 , 5.0
# ******************
# pred, real
# 6.038799 , 7.0
# ******************
# pred, real
# 6.556804 , 8.0
# ******************
# pred, real
# 5.0933137 , 5.0
# ******************
# pred, real
# 4.9244037 , 6.0
# ******************
# pred, real
# 5.454822 , 5.0
# ******************
# pred, real
# 5.6568036 , 5.0
# ******************
# pred, real
# 5.9270253 , 6.0
# ******************
# pred, real
# 6.7043242 , 7.0
# ******************
# pred, real
# 5.192507 , 5.0
# ******************
# pred, real
# 5.8157372 , 6.0
# ******************
# pred, real
# 6.205377 , 6.0
# ******************
# pred, real
# 6.105139 , 7.0
# ******************
# pred, real
# 5.1707 , 5.0
# ******************
# pred, real
# 6.4538226 , 6.0
# ******************
# pred, real
# 6.8995614 , 7.0
# ******************
# pred, real
# 7.297874 , 8.0
# ******************
# pred, real
# 4.9833646 , 6.0
# ******************
# pred, real
# 5.9650483 , 6.0
# ******************
# pred, real
# 6.2324347 , 6.0
# ******************
# pred, real
# 6.744969 , 7.0
# ******************
# pred, real
# 5.7703667 , 6.0
# ******************
# pred, real
# 6.454639 , 6.0
# ******************
# pred, real
# 6.5796537 , 6.0
# ******************
# pred, real
# 6.113002 , 5.0
# ******************
# pred, real
# 5.050467 , 5.0
# ******************
# pred, real
# 6.441276 , 6.0
# ******************
# pred, real
# 5.8463945 , 6.0
# ******************
# pred, real
# 6.526247 , 6.0
# ******************
# pred, real
# 6.405544 , 7.0
# ******************
# pred, real
# 6.126144 , 6.0
# ******************
# pred, real
# 6.2227464 , 7.0
# ******************
# pred, real
# 5.7229486 , 6.0
# ******************
# pred, real
# 5.227407 , 5.0
# ******************
# pred, real
# 5.5452332 , 6.0
# ******************
# pred, real
# 5.376392 , 4.0
# ******************
# pred, real
# 6.0670066 , 7.0
# ******************
# pred, real
# 5.9731755 , 6.0
# ******************
# pred, real
# 6.065146 , 5.0
# ******************
# pred, real
# 5.857936 , 7.0
# ******************
# pred, real
# 5.5991416 , 5.0
# ******************
# pred, real
# 6.3552303 , 8.0
# ******************
# pred, real
# 6.220563 , 5.0
# ******************
# pred, real
# 5.7951026 , 6.0
# ******************
# pred, real
# 6.3460307 , 6.0
# ******************
# pred, real
# 5.789412 , 6.0
# ******************
# pred, real
# 5.1939116 , 6.0
# ******************
# pred, real
# 5.7878256 , 5.0
# ******************
# pred, real
# 6.452629 , 5.0
# ******************
# pred, real
# 6.5854535 , 8.0
# ******************
# pred, real
# 6.0182767 , 6.0
# ******************
# pred, real
# 5.356123 , 5.0
# ******************
# pred, real
# 6.167265 , 6.0
# ******************
# pred, real
# 5.671374 , 6.0
# ******************
# pred, real
# 6.4994454 , 7.0
# ******************
# pred, real
# 5.884621 , 4.0
# ******************
# pred, real
# 5.7196984 , 5.0
# ******************
# pred, real
# 6.0554185 , 6.0
# ******************
# pred, real
# 5.7466416 , 6.0
# ******************
# pred, real
# 5.3057466 , 5.0
# ******************
# pred, real
# 6.5676174 , 6.0
# ******************
# pred, real
# 6.1593304 , 6.0
# ******************
# pred, real
# 5.2931104 , 6.0
# ******************
# pred, real
# 5.6572857 , 6.0
# ******************
# pred, real
# 6.2710147 , 6.0
# ******************
# pred, real
# 6.9729457 , 7.0
# ******************
# pred, real
# 5.485563 , 6.0
# ******************
# pred, real
# 6.617741 , 6.0
# ******************
# pred, real
# 6.206547 , 5.0
# ******************
# pred, real
# 5.233681 , 6.0
# ******************
# pred, real
# 6.7352104 , 6.0
# ******************
# pred, real
# 5.568857 , 6.0
# ******************
# pred, real
# 5.9477234 , 5.0
# ******************
# pred, real
# 5.2541647 , 6.0
# ******************
# pred, real
# 5.925486 , 6.0
# ******************
# pred, real
# 6.3622475 , 7.0
# ******************
# pred, real
# 6.4005237 , 6.0
# ******************
# pred, real
# 6.134956 , 6.0
# ******************
# pred, real
# 5.6692758 , 6.0
# ******************
# pred, real
# 6.042669 , 6.0
# ******************
# pred, real
# 6.03602 , 6.0
# ******************
# pred, real
# 5.407285 , 5.0
# ******************
# pred, real
# 4.6977687 , 5.0
# ******************
# pred, real
# 5.742091 , 6.0
# ******************
# pred, real
# 5.9748454 , 6.0
# ******************
# pred, real
# 5.222194 , 5.0
# ******************
# pred, real
# 6.2645106 , 6.0
# ******************
# pred, real
# 6.6377225 , 6.0
# ******************
# pred, real
# 5.2943225 , 6.0
# ******************
# pred, real
# 5.9617405 , 6.0
# ******************
# pred, real
# 6.359082 , 6.0
# ******************
# pred, real
# 6.130115 , 5.0
# ******************
# pred, real
# 7.1999364 , 6.0
# ******************
# pred, real
# 5.81984 , 6.0
# ******************
# pred, real
# 5.3562694 , 5.0
# ******************
# pred, real
# 5.4368286 , 6.0
# ******************
# pred, real
# 6.2839794 , 6.0
# ******************
# pred, real
# 5.2541647 , 6.0
# ******************
# pred, real
# 5.3564773 , 6.0
# ******************
# pred, real
# 6.5597253 , 6.0
# ******************
# pred, real
# 6.3055015 , 6.0
# ******************
# pred, real
# 5.3592787 , 5.0
# ******************
# pred, real
# 6.5326066 , 8.0
# ******************
# pred, real
# 6.3252425 , 6.0
# ******************
# pred, real
# 4.9657235 , 4.0
# ******************
# pred, real
# 5.8432064 , 7.0
# ******************
# pred, real
# 6.5395703 , 6.0
# ******************
# pred, real
# 5.2958884 , 6.0
# ******************
# pred, real
# 5.3646827 , 4.0
# ******************
# pred, real
# 5.5237975 , 6.0
# ******************
# pred, real
# 5.3564773 , 6.0
# ******************
# pred, real
# 6.779515 , 6.0
# ******************
# pred, real
# 5.9277463 , 7.0
# ******************
# pred, real
# 5.7035737 , 5.0
# ******************
# pred, real
# 6.5612726 , 5.0
# ******************
# pred, real
# 5.9420347 , 6.0
# ******************
# pred, real
# 5.4388223 , 5.0
# ******************
# pred, real
# 4.994628 , 5.0
# ******************
# pred, real
# 4.8899045 , 4.0
# ******************
# pred, real
# 6.396964 , 7.0
# ******************
# pred, real
# 6.8087745 , 7.0
# ******************
# pred, real
# 5.771506 , 7.0
# ******************
# pred, real
# 5.6078496 , 4.0
# ******************
# pred, real
# 6.6655354 , 7.0
# ******************
# pred, real
# 6.231912 , 6.0
# ******************
# pred, real
# 5.4082723 , 5.0
# ******************
# pred, real
# 6.241607 , 6.0
# ******************
# pred, real
# 6.0176845 , 6.0
# ******************
# pred, real
# 6.8295956 , 6.0
# ******************
# pred, real
# 5.977576 , 7.0
# ******************
# pred, real
# 5.9958806 , 5.0
# ******************
# pred, real
# 5.4691634 , 5.0
# ******************
# pred, real
# 4.9909515 , 5.0
# ******************
# pred, real
# 5.416163 , 6.0
# ******************
# pred, real
# 5.323673 , 5.0
# ******************
# pred, real
# 5.915893 , 4.0
# ******************
# pred, real
# 5.281409 , 5.0
# ******************
# pred, real
# 7.0638094 , 7.0
# ******************
# pred, real
# 6.2936745 , 6.0
# ******************
# pred, real
# 6.075955 , 7.0
# ******************
# pred, real
# 5.9814925 , 6.0
# ******************
# pred, real
# 6.349728 , 6.0
# ******************
# pred, real
# 5.741204 , 6.0
# ******************
# pred, real
# 6.7175865 , 6.0
# ******************
# pred, real
# 6.0529604 , 5.0
# ******************
# pred, real
# 6.1582756 , 6.0
# ******************
# pred, real
# 6.2254353 , 6.0
# ******************
# pred, real
# 6.252705 , 6.0
# ******************
# pred, real
# 4.9536557 , 5.0
# ******************
# pred, real
# 6.0649805 , 8.0
# ******************
# pred, real
# 5.325833 , 5.0
# ******************
# pred, real
# 5.8781466 , 6.0
# ******************
# pred, real
# 6.420839 , 7.0
# ******************
# pred, real
# 5.327991 , 5.0
# ******************
# pred, real
# 6.7344203 , 7.0
# ******************
# pred, real
# 6.9758024 , 7.0
# ******************
# pred, real
# 6.0474663 , 6.0
# ******************
# pred, real
# 6.1484146 , 6.0
# ******************
# pred, real
# 5.6244693 , 5.0
# ******************
# pred, real
# 5.409508 , 5.0
# ******************
# pred, real
# 7.0407763 , 6.0
# ******************
# pred, real
# 6.381518 , 6.0
# ******************
# pred, real
# 5.7432594 , 5.0
# ******************
# pred, real
# 5.4728656 , 5.0
# ******************
# pred, real
# 5.247068 , 5.0
# ******************
# pred, real
# 6.3623495 , 6.0
# ******************
# pred, real
# 5.317468 , 5.0
# ******************
# pred, real
# 5.9481506 , 7.0
# ******************
# pred, real
# 5.983662 , 6.0
# ******************
# pred, real
# 4.405834 , 4.0
# ******************
# pred, real
# 6.6420813 , 6.0
# ******************
# pred, real
# 6.5538554 , 8.0
# ******************
# pred, real
# 7.041308 , 7.0
# ******************
# pred, real
# 5.529923 , 5.0
# ******************
# pred, real
# 5.7092514 , 5.0
# ******************
# pred, real
# 6.175543 , 6.0
# ******************
# pred, real
# 5.769916 , 7.0
# ******************
# pred, real
# 6.717319 , 6.0
# ******************
# pred, real
# 6.384701 , 6.0
# ******************
# pred, real
# 5.31995 , 5.0
# ******************
# pred, real
# 5.731979 , 6.0
# ******************
# pred, real
# 7.1699657 , 8.0
# ******************
# pred, real
# 6.241607 , 6.0
# ******************
# pred, real
# 5.522334 , 5.0
# ******************
# pred, real
# 6.2862844 , 6.0
# ******************
# pred, real
# 5.485869 , 5.0
# ******************
# pred, real
# 5.5237975 , 6.0
# ******************
# pred, real
# 5.3784094 , 4.0
# ******************
# pred, real
# 5.4468875 , 6.0
# ******************
# pred, real
# 6.554581 , 7.0
# ******************
# pred, real
# 6.3750377 , 6.0
# ******************
# pred, real
# 4.831441 , 6.0
# ******************
# pred, real
# 5.957191 , 6.0
# ******************
# pred, real
# 4.273265 , 3.0
# ******************
# pred, real
# 6.163523 , 7.0
# ******************
# pred, real
# 5.539221 , 6.0
# ******************
# pred, real
# 5.6806474 , 6.0
# ******************
# pred, real
# 5.3410172 , 5.0
# ******************
# pred, real
# 5.6178775 , 5.0
# ******************
# pred, real
# 5.964763 , 5.0
# ******************
# pred, real
# 5.5295825 , 4.0
# ******************
# pred, real
# 6.323164 , 6.0
# ******************
# pred, real
# 5.042052 , 4.0
# ******************
# pred, real
# 5.499042 , 5.0
# ******************
# pred, real
# 7.1774487 , 6.0
# ******************
# pred, real
# 7.1774487 , 6.0
# ******************
# pred, real
# 5.269216 , 6.0
# ******************
# pred, real
# 6.472159 , 5.0
# ******************
# pred, real
# 5.0643754 , 5.0
# ******************
# pred, real
# 5.095116 , 5.0
# ******************
# pred, real
# 5.852373 , 5.0
# ******************
# pred, real
# 6.758053 , 7.0
# ******************
# pred, real
# 5.4311137 , 6.0
# ******************
# pred, real
# 5.193832 , 6.0
# ******************
# pred, real
# 5.964502 , 6.0
# ******************
# pred, real
# 4.5076165 , 5.0
# ******************
# pred, real
# 6.485508 , 6.0
# ******************
# pred, real
# 5.703295 , 5.0
# ******************
# pred, real
# 5.891504 , 6.0
# ******************
# pred, real
# 7.005879 , 6.0
# ******************
# pred, real
# 6.123149 , 7.0
# ******************
# pred, real
# 6.2555814 , 6.0
# ******************
# pred, real
# 6.4218307 , 8.0
# ******************
# pred, real
# 4.68003 , 4.0
# ******************
# pred, real
# 6.03156 , 5.0
# ******************
# pred, real
# 5.8214283 , 6.0
# ******************
# pred, real
# 6.4824 , 6.0
# ******************
# pred, real
# 5.3767233 , 5.0
# ******************
# pred, real
# 5.3471045 , 5.0
# ******************
# pred, real
# 5.265896 , 6.0
# ******************
# pred, real
# 6.0395217 , 6.0
# ******************
# pred, real
# 6.207763 , 6.0
# ******************
# pred, real
# 5.916183 , 6.0
# ******************
# pred, real
# 4.6643386 , 5.0
# ******************
# pred, real
# 6.1745563 , 6.0
# ******************
# pred, real
# 5.391941 , 5.0
# ******************
# pred, real
# 6.6490254 , 6.0
# ******************
# pred, real
# 7.289581 , 6.0
# ******************
# pred, real
# 5.528076 , 5.0
# ******************
# pred, real
# 5.276535 , 5.0
# ******************
# pred, real
# 5.280867 , 4.0
# ******************
# pred, real
# 6.1800017 , 6.0
# ******************
# pred, real
# 6.261992 , 7.0
# ******************
# pred, real
# 5.9690537 , 6.0
# ******************
# pred, real
# 6.148066 , 6.0
# ******************
# pred, real
# 6.5150976 , 7.0
# ******************
# pred, real
# 6.5242805 , 7.0
# ******************
# pred, real
# 6.8068285 , 8.0
# ******************
# pred, real
# 5.8222637 , 6.0
# ******************
# pred, real
# 6.6950207 , 7.0
# ******************
# pred, real
# 5.2583046 , 5.0
# ******************
# pred, real
# 5.6814547 , 6.0
# ******************
# pred, real
# 6.629748 , 7.0
# ******************
# pred, real
# 5.173809 , 5.0
# ******************
# pred, real
# 5.0917387 , 6.0
# ******************
# pred, real
# 5.545314 , 6.0
# ******************
# pred, real
# 5.330591 , 6.0
# ******************
# pred, real
# 5.6490474 , 5.0
# ******************
# pred, real
# 5.4955516 , 5.0
# ******************
# pred, real
# 5.810471 , 5.0
# ******************
# pred, real
# 6.2129765 , 5.0
# ******************
# pred, real
# 5.9369845 , 6.0
# ******************
# pred, real
# 4.9685774 , 5.0
# ******************
# pred, real
# 5.8848023 , 6.0
# ******************
# pred, real
# 6.7182612 , 7.0
# ******************
# pred, real
# 5.6753235 , 5.0
# ******************
# pred, real
# 4.8296704 , 5.0
# ******************
# pred, real
# 5.4653296 , 6.0
# ******************
# pred, real
# 6.411601 , 7.0
# ******************
# pred, real
# 5.1620946 , 5.0
# ******************
# pred, real
# 5.7099485 , 5.0
# ******************
# pred, real
# 5.6543565 , 6.0
# ******************
# pred, real
# 5.423304 , 5.0
# ******************
# pred, real
# 5.9690537 , 6.0
# ******************
# pred, real
# 6.339926 , 6.0
# ******************
# pred, real
# 6.0673566 , 6.0
# ******************
# pred, real
# 5.642511 , 5.0
# ******************
# pred, real
# 6.8438096 , 6.0
# ******************
# pred, real
# 6.58388 , 8.0
# ******************
# pred, real
# 6.5686975 , 6.0
# ******************
# pred, real
# 5.93883 , 6.0
# ******************
# pred, real
# 6.9604464 , 6.0
# ******************
# pred, real
# 5.725474 , 6.0
# ******************
# pred, real
# 5.3671336 , 5.0
# ******************
# pred, real
# 5.7703667 , 6.0
# ******************
# pred, real
# 6.9708037 , 7.0
# ******************
# pred, real
# 5.0531125 , 6.0
# ******************
# pred, real
# 6.2590327 , 7.0
# ******************
# pred, real
# 5.9555693 , 6.0
# ******************
# pred, real
# 5.3828855 , 6.0
# ******************
# pred, real
# 6.855841 , 7.0
# ******************
# pred, real
# 6.925647 , 8.0
# ******************
# pred, real
# 6.2389193 , 6.0
# ******************
# pred, real
# 5.977576 , 7.0
# ******************
# pred, real
# 6.039766 , 6.0
# ******************
# pred, real
# 5.832887 , 6.0
# ******************
# pred, real
# 5.3510528 , 5.0
# ******************
# pred, real
# 6.8499374 , 7.0
# ******************
# pred, real
# 5.7346244 , 6.0
# ******************
# pred, real
# 6.372168 , 7.0
# ******************
# pred, real
# 6.772409 , 6.0
# ******************
# pred, real
# 5.678824 , 6.0
# ******************
# pred, real
# 6.557838 , 6.0
# ******************
# pred, real
# 6.5476503 , 7.0
# ******************
# pred, real
# 6.069652 , 7.0
# ******************
# pred, real
# 6.5674825 , 7.0
# ******************
# pred, real
# 6.384107 , 7.0
# ******************
# pred, real
# 6.898544 , 6.0
# ******************
# pred, real
# 6.01516 , 5.0
# ******************
# pred, real
# 5.705437 , 6.0
# ******************
# pred, real
# 6.5510983 , 5.0
# ******************
# pred, real
# 6.396793 , 7.0
# ******************
# pred, real
# 7.0538507 , 7.0
# ******************
# pred, real
# 5.5672016 , 5.0
# ******************
# pred, real
# 5.9691443 , 7.0
# ******************
# pred, real
# 7.8242664 , 7.0
# ******************
# pred, real
# 5.3342175 , 5.0
# ******************
# pred, real
# 6.3848515 , 6.0
# ******************
# pred, real
# 4.9161096 , 4.0
# ******************
# pred, real
# 6.671838 , 5.0
# ******************
# pred, real
# 5.901606 , 7.0
# ******************
# pred, real
# 5.3526354 , 5.0
# ******************
# pred, real
# 5.4771476 , 5.0
# ******************
# pred, real
# 5.0744615 , 6.0
# ******************
# pred, real
# 5.7789497 , 6.0
# ******************
# pred, real
# 6.2783937 , 6.0
# ******************
# pred, real
# 6.140117 , 6.0
# ******************
# pred, real
# 5.7366853 , 6.0
# ******************
# pred, real
# 6.9259353 , 6.0
# ******************
# pred, real
# 6.4596562 , 6.0
# ******************
# pred, real
# 6.0263247 , 6.0
# ******************
# pred, real
# 6.1953454 , 5.0
# ******************
# pred, real
# 6.0208764 , 6.0
# ******************
# pred, real
# 6.3876324 , 6.0
# ******************
# pred, real
# 5.0685515 , 5.0
# ******************
# pred, real
# 6.3742304 , 7.0
# ******************
# pred, real
# 5.229188 , 5.0
# ******************
# pred, real
# 6.6967597 , 6.0
# ******************
# pred, real
# 5.5443377 , 6.0
# ******************
# pred, real
# 6.5116944 , 8.0
# ******************
# pred, real
# 5.867768 , 6.0
# ******************
# pred, real
# 6.5476503 , 7.0
# ******************
# pred, real
# 5.9669776 , 6.0
# ******************
# pred, real
# 6.3450933 , 7.0
# ******************
# pred, real
# 5.6884956 , 6.0
# ******************
# pred, real
# 6.1802793 , 5.0
# ******************
# pred, real
# 6.6656017 , 7.0
# ******************
# pred, real
# 5.507701 , 5.0
# ******************
# pred, real
# 6.423943 , 6.0
# ******************
# pred, real
# 6.0321364 , 6.0
# ******************
# pred, real
# 6.851273 , 6.0
# ******************
# pred, real
# 5.5280232 , 5.0
# ******************
# pred, real
# 5.00223 , 6.0
# ******************
# pred, real
# 6.344084 , 6.0
# ******************
# pred, real
# 5.51173 , 5.0
# ******************
# pred, real
# 6.9319143 , 7.0
# ******************
# pred, real
# 6.734876 , 7.0
# ******************
# pred, real
# 6.336945 , 6.0
# ******************
# pred, real
# 6.6654353 , 6.0
# ******************
# pred, real
# 5.029964 , 4.0
# ******************
# pred, real
# 6.2183843 , 8.0
# ******************
# pred, real
# 5.7433 , 6.0
# ******************
# pred, real
# 6.041352 , 6.0
# ******************
# pred, real
# 5.9933233 , 5.0
# ******************
# pred, real
# 6.06727 , 7.0
# ******************
# pred, real
# 6.1943393 , 7.0
# ******************
# pred, real
# 6.4939795 , 6.0
# ******************
# pred, real
# 5.62989 , 6.0
# ******************
# pred, real
# 6.254251 , 6.0
# ******************
# pred, real
# 5.910954 , 5.0
# ******************
# pred, real
# 6.2186317 , 6.0
# ******************
# pred, real
# 5.416777 , 5.0
# ******************
# pred, real
# 6.4447665 , 6.0
# ******************
# pred, real
# 6.8305335 , 6.0
# ******************
# pred, real
# 7.3900857 , 8.0
# ******************
# pred, real
# 6.5045953 , 6.0
# ******************
# pred, real
# 6.0766654 , 5.0
# ******************
# pred, real
# 6.392019 , 6.0
# ******************
# pred, real
# 5.198444 , 5.0
# ******************
# pred, real
# 4.2521005 , 6.0
# ******************
# pred, real
# 5.876812 , 6.0
# ******************
# pred, real
# 5.689216 , 6.0
# ******************
# pred, real
# 6.0390067 , 6.0
# ******************
# pred, real
# 5.3957343 , 5.0
# ******************
# pred, real
# 5.7824874 , 7.0
# ******************
# pred, real
# 5.311623 , 5.0
# ******************
# pred, real
# 6.826063 , 7.0
# ******************
# pred, real
# 5.325352 , 4.0
# ******************
# pred, real
# 4.861418 , 5.0
# ******************
# pred, real
# 6.758053 , 7.0
# ******************
# pred, real
# 6.598435 , 7.0
# ******************
# pred, real
# 6.035543 , 6.0
# ******************
# pred, real
# 6.786343 , 8.0
# ******************
# pred, real
# 5.5811095 , 5.0
# ******************
# pred, real
# 7.116649 , 7.0
# ******************
# pred, real
# 6.33923 , 5.0
# ******************
# pred, real
# 5.694614 , 5.0
# ******************
# pred, real
# 6.939025 , 7.0
# ******************
# pred, real
# 6.0454993 , 5.0
# ******************
# pred, real
# 6.0919414 , 6.0
# ******************
# pred, real
# 5.3926644 , 6.0
# ******************
# pred, real
# 6.0712037 , 6.0
# ******************
# pred, real
# 6.925647 , 8.0
# ******************
# pred, real
# 5.4713435 , 5.0
# ******************
# pred, real
# 6.8760314 , 6.0
# ******************
# pred, real
# 6.20291 , 7.0
# ******************
# pred, real
# 6.544596 , 6.0
# ******************
# pred, real
# 6.053434 , 5.0
# ******************
# pred, real
# 6.019618 , 6.0
# ******************
# pred, real
# 6.350287 , 6.0
# ******************
# pred, real
# 5.2053027 , 5.0
# ******************
# pred, real
# 5.1154857 , 4.0
# ******************
# pred, real
# 6.460177 , 7.0
# ******************
# pred, real
# 6.259817 , 6.0
# ******************
# pred, real
# 6.2521424 , 6.0
# ******************
# pred, real
# 5.067159 , 5.0

# %% [markdown]
# ## Visualize test predictions

# %%
def plot_preds_vs_reals (list_preds, list_reals):
    ## 
    plt.figure (figsize = (13, 4))
    plt.plot (list_reals, label = 'real', color = 'r')
    plt.plot (list_preds, label = 'pred')
    plt.show ()

# %%
plot_preds_vs_reals (list_preds, list_reals)

# %% [markdown]
# ## Deploy Model
#
# * ONIX and GitHub
